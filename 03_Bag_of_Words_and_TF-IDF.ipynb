# %% [markdown]
# # Bag of Words and TF-IDF
# With our data clean and lemmatized, we can now start analysing it. First, we'll create a Bag of Words (BoW) for each summary. Then we will run a Term Frequency - Inverse Document Frequency analysis on the set to examine differences in word use.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
from string import punctuation
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag
from nltk.stem import WordNetLemmatizer

from IPython.display import clear_output
from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
path_to_data = "Data/cleaned_summaries_and_genres.csv"
df = pd.read_csv(path_to_data, index_col=0)
df
# Out:
#                                                  summary  \
# 0      old major old boar manor farm call animal farm...
# 1      old major old boar manor farm call animal farm...
# 2      old major old boar manor farm call animal farm...
# 3      alex teenager live nearfuture england lead gan...
# 4      alex teenager live nearfuture england lead gan...
# ...                                                  ...
# 26536  series follow character nick stone exmilitary ...
# 26537  series follow character nick stone exmilitary ...
# 26538  reader first meet rapp covert operation iran d...
# 26539  reader first meet rapp covert operation iran d...
# 26540  makar devushkin varvara dobroselova second cou...
#
#                        genre
# 0      Children's literature
# 1        Speculative fiction
# 2                    Fiction
# 3            Science Fiction
# 4        Speculative fiction
# ...                      ...
# 26536                Fiction
# 26537               Suspense
# 26538               Thriller
# 26539                Fiction
# 26540    Speculative fiction
#
# [26541 rows x 2 columns]

# %% [markdown]
# ### Term Frequency with CountVectorizer
# Using sklearn's CountVectorizer, we'll generate a sparse matrix of words from our summaries. This will likely take a long time, so we'll time it, too.

# %%
start = datetime.now()
vectorizer = CountVectorizer()

# fit the count vectorizer
vectorizer.fit(df['summary'])

# transform our set
vector = vectorizer.transform(df['summary'])

print('Complete. Total time elapsed: {} seconds.'.format((datetime.now()-start).total_seconds()))
# Out:
# Complete. Total time elapsed: 9.879003 seconds.

# %%
vector.shape
# Out:
# (26541, 116360)

# %% [markdown]
# ### Inverse Document Frequency
# I also just realized that I could skip CountVectorizer entirely and just use sklearn's TfidvVectorizer.

# %%
start = datetime.now()
tfidf_vectorizer = TfidfVectorizer()
tfidf = tfidf_vectorizer.fit_transform(df['summary'])
print('Complete. Total time elapsed: {} seconds.'.format((datetime.now()-start).total_seconds()))
# Out:
# Complete. Total time elapsed: 5.439611 seconds.

# %%
tfidf.shape
# Out:
# (26541, 116360)

# %%
tfidf_vectorizer.inverse_transform(tfidf)
# Out:
# [array(['propaganda', 'malleable', 'dogma', 'political', 'simply',
#         'demonstrate', 'orwell', 'revision', 'habit', 'evil', 'prevent',
#         'together', 'uniting', 'within', 'keep', 'suppose', 'purpose',
#         'twist', 'ironic', 'maxim', 'eventually', 'cause', 'without',
#         'bolded', 'follow', 'add', 'sheet', 'append', 'excess',
#         'lawbreaking', 'accusation', 'clear', 'secretly', 'later', 'shall',
#         'friend', 'wing', 'legs', 'four', 'enemy', 'leg', 'upon', 'go',
#         'whatever', 'original', 'society', 'belief', 'people', 'exercise',
#         'order', 'revise', 'government', 'soviet', 'allusion',
#         'humanisation', 'account', 'alter', 'employ', 'trading', 'bed',
#         'sleep', 'alcohol', 'drink', 'vice', 'indulge', 'soon', 'formally',
#         'actual', 'ideas', 'adapt', 'difference', 'tell', 'like', 'look',
#         'realise', 'pilkington', 'break', 'argument', 'match', 'poker',
#         'face', 'conversation', 'overhear', 'revolution', 'related',
#         'tradition', 'practice', 'abolishes', 'world', 'class', 'labour',
#         'alliance', 'country', 'fed', 'least', 'hardestworking',
#         'congratulate', 'area', 'party', 'dinner', 'hold', 'others',
#         'phrase', 'single', 'reduce', 'clothes', 'wear', 'whip', 'carry',
#         'upright', 'walk', 'learn', 'pass', 'year', 'medical', 'best',
#         'hand', 'death', 'tale', 'recount', 'repaint', 'owner', 'previous',
#         'hospital', 'purchase', 'report', 'futile', 'rescue', 'mount',
#         'knacker', 'belongs', 'notice', 'well', 'could', 'donkey',
#         'cynical', 'benjamin', 'give', 'care', 'explain', 'surgeon',
#         'veterinary', 'van', 'send', 'collapse', 'harder', 'continue',
#         'injury', 'despite', 'wound', 'workhorse', 'boxer', 'include',
#         'many', 'cost', 'great', 'battle', 'win', 'though', 'restore',
#         'blow', 'powder', 'blast', 'attack', 'neighbouring', 'one',
#         'frederick', 'improvement', 'show', 'number', 'invent', 'memory',
#         'poor', 'good', 'convinced', 'remain', 'man', 'lifestyle',
#         'appear', 'glorify', 'anthem', 'benefit', 'alteration', 'pigs',
#         'even', 'make', 'statement', 'every', 'justifies', 'glorifying',
#         'villainising', 'history', 'rewrite', 'privilege', 'reserve',
#         'control', 'impose', 'power', 'abuse', 'rival', 'consort',
#         'accuse', 'kill', 'purge', 'begin', 'scapegoat', 'become', 'thin',
#         'wall', 'suggest', 'farmer', 'neighbour', 'scorn', 'although',
#         'destroy', 'convince', 'annihilate', 'find', 'storm', 'violent',
#         'life', 'easy', 'promise', 'hard', 'work', 'idea', 'credit',
#         'claim', 'mouthpiece', 'squealer', 'name', 'use', 'committee',
#         'replace', 'structure', 'governance', 'change', 'enacts', 'leader',
#         'declares', 'away', 'chase', 'windmill', 'build', 'plan',
#         'announces', 'struggle', 'privately', 'train', 'dog', 'pup',
#         'take', 'health', 'personal', 'ostensibly', 'item', 'special',
#         'aside', 'set', 'leadership', 'position', 'elevate', 'smoothly',
#         'run', 'plentiful', 'food', 'write', 'read', 'attempt', 'equal',
#         'important', 'animalism', 'commandment', 'seven', 'adopt',
#         'rename', 'jones', 'mr', 'irresponsible', 'drunken', 'drive',
#         'revolt', 'philosophy', 'dream', 'turn', 'command', 'assume',
#         'napoleon', 'snowball', 'pig', 'young', 'two', 'dy', 'england',
#         'beast', 'song', 'revolutionary', 'teach', 'parasite', 'human',
#         'compare', 'meeting', 'animal', 'call', 'farm', 'manor', 'boar',
#         'major', 'old'], dtype='<U110'),
#  array(['propaganda', 'malleable', 'dogma', 'political', 'simply',
#         'demonstrate', 'orwell', 'revision', 'habit', 'evil', 'prevent',
#         'together', 'uniting', 'within', 'keep', 'suppose', 'purpose',
#         'twist', 'ironic', 'maxim', 'eventually', 'cause', 'without',
#         'bolded', 'follow', 'add', 'sheet', 'append', 'excess',
#         'lawbreaking', 'accusation', 'clear', 'secretly', 'later', 'shall',
#         'friend', 'wing', 'legs', 'four', 'enemy', 'leg', 'upon', 'go',
#         'whatever', 'original', 'society', 'belief', 'people', 'exercise',
#         'order', 'revise', 'government', 'soviet', 'allusion',
#         'humanisation', 'account', 'alter', 'employ', 'trading', 'bed',
#         'sleep', 'alcohol', 'drink', 'vice', 'indulge', 'soon', 'formally',
#         'actual', 'ideas', 'adapt', 'difference', 'tell', 'like', 'look',
#         'realise', 'pilkington', 'break', 'argument', 'match', 'poker',
#         'face', 'conversation', 'overhear', 'revolution', 'related',
#         'tradition', 'practice', 'abolishes', 'world', 'class', 'labour',
#         'alliance', 'country', 'fed', 'least', 'hardestworking',
#         'congratulate', 'area', 'party', 'dinner', 'hold', 'others',
#         'phrase', 'single', 'reduce', 'clothes', 'wear', 'whip', 'carry',
#         'upright', 'walk', 'learn', 'pass', 'year', 'medical', 'best',
#         'hand', 'death', 'tale', 'recount', 'repaint', 'owner', 'previous',
#         'hospital', 'purchase', 'report', 'futile', 'rescue', 'mount',
#         'knacker', 'belongs', 'notice', 'well', 'could', 'donkey',
#         'cynical', 'benjamin', 'give', 'care', 'explain', 'surgeon',
#         'veterinary', 'van', 'send', 'collapse', 'harder', 'continue',
#         'injury', 'despite', 'wound', 'workhorse', 'boxer', 'include',
#         'many', 'cost', 'great', 'battle', 'win', 'though', 'restore',
#         'blow', 'powder', 'blast', 'attack', 'neighbouring', 'one',
#         'frederick', 'improvement', 'show', 'number', 'invent', 'memory',
#         'poor', 'good', 'convinced', 'remain', 'man', 'lifestyle',
#         'appear', 'glorify', 'anthem', 'benefit', 'alteration', 'pigs',
#         'even', 'make', 'statement', 'every', 'justifies', 'glorifying',
#         'villainising', 'history', 'rewrite', 'privilege', 'reserve',
#         'control', 'impose', 'power', 'abuse', 'rival', 'consort',
#         'accuse', 'kill', 'purge', 'begin', 'scapegoat', 'become', 'thin',
#         'wall', 'suggest', 'farmer', 'neighbour', 'scorn', 'although',
#         'destroy', 'convince', 'annihilate', 'find', 'storm', 'violent',
#         'life', 'easy', 'promise', 'hard', 'work', 'idea', 'credit',
#         'claim', 'mouthpiece', 'squealer', 'name', 'use', 'committee',
#         'replace', 'structure', 'governance', 'change', 'enacts', 'leader',
#         'declares', 'away', 'chase', 'windmill', 'build', 'plan',
#         'announces', 'struggle', 'privately', 'train', 'dog', 'pup',
#         'take', 'health', 'personal', 'ostensibly', 'item', 'special',
#         'aside', 'set', 'leadership', 'position', 'elevate', 'smoothly',
#         'run', 'plentiful', 'food', 'write', 'read', 'attempt', 'equal',
#         'important', 'animalism', 'commandment', 'seven', 'adopt',
#         'rename', 'jones', 'mr', 'irresponsible', 'drunken', 'drive',
#         'revolt', 'philosophy', 'dream', 'turn', 'command', 'assume',
#         'napoleon', 'snowball', 'pig', 'young', 'two', 'dy', 'england',
#         'beast', 'song', 'revolutionary', 'teach', 'parasite', 'human',
#         'compare', 'meeting', 'animal', 'call', 'farm', 'manor', 'boar',
#         'major', 'old'], dtype='<U110'),
#  array(['propaganda', 'malleable', 'dogma', 'political', 'simply',
#         'demonstrate', 'orwell', 'revision', 'habit', 'evil', 'prevent',
#         'together', 'uniting', 'within', 'keep', 'suppose', 'purpose',
#         'twist', 'ironic', 'maxim', 'eventually', 'cause', 'without',
#         'bolded', 'follow', 'add', 'sheet', 'append', 'excess',
#         'lawbreaking', 'accusation', 'clear', 'secretly', 'later', 'shall',
#         'friend', 'wing', 'legs', 'four', 'enemy', 'leg', 'upon', 'go',
#         'whatever', 'original', 'society', 'belief', 'people', 'exercise',
#         'order', 'revise', 'government', 'soviet', 'allusion',
#         'humanisation', 'account', 'alter', 'employ', 'trading', 'bed',
#         'sleep', 'alcohol', 'drink', 'vice', 'indulge', 'soon', 'formally',
#         'actual', 'ideas', 'adapt', 'difference', 'tell', 'like', 'look',
#         'realise', 'pilkington', 'break', 'argument', 'match', 'poker',
#         'face', 'conversation', 'overhear', 'revolution', 'related',
#         'tradition', 'practice', 'abolishes', 'world', 'class', 'labour',
#         'alliance', 'country', 'fed', 'least', 'hardestworking',
#         'congratulate', 'area', 'party', 'dinner', 'hold', 'others',
#         'phrase', 'single', 'reduce', 'clothes', 'wear', 'whip', 'carry',
#         'upright', 'walk', 'learn', 'pass', 'year', 'medical', 'best',
#         'hand', 'death', 'tale', 'recount', 'repaint', 'owner', 'previous',
#         'hospital', 'purchase', 'report', 'futile', 'rescue', 'mount',
#         'knacker', 'belongs', 'notice', 'well', 'could', 'donkey',
#         'cynical', 'benjamin', 'give', 'care', 'explain', 'surgeon',
#         'veterinary', 'van', 'send', 'collapse', 'harder', 'continue',
#         'injury', 'despite', 'wound', 'workhorse', 'boxer', 'include',
#         'many', 'cost', 'great', 'battle', 'win', 'though', 'restore',
#         'blow', 'powder', 'blast', 'attack', 'neighbouring', 'one',
#         'frederick', 'improvement', 'show', 'number', 'invent', 'memory',
#         'poor', 'good', 'convinced', 'remain', 'man', 'lifestyle',
#         'appear', 'glorify', 'anthem', 'benefit', 'alteration', 'pigs',
#         'even', 'make', 'statement', 'every', 'justifies', 'glorifying',
#         'villainising', 'history', 'rewrite', 'privilege', 'reserve',
#         'control', 'impose', 'power', 'abuse', 'rival', 'consort',
#         'accuse', 'kill', 'purge', 'begin', 'scapegoat', 'become', 'thin',
#         'wall', 'suggest', 'farmer', 'neighbour', 'scorn', 'although',
#         'destroy', 'convince', 'annihilate', 'find', 'storm', 'violent',
#         'life', 'easy', 'promise', 'hard', 'work', 'idea', 'credit',
#         'claim', 'mouthpiece', 'squealer', 'name', 'use', 'committee',
#         'replace', 'structure', 'governance', 'change', 'enacts', 'leader',
#         'declares', 'away', 'chase', 'windmill', 'build', 'plan',
#         'announces', 'struggle', 'privately', 'train', 'dog', 'pup',
#         'take', 'health', 'personal', 'ostensibly', 'item', 'special',
#         'aside', 'set', 'leadership', 'position', 'elevate', 'smoothly',
#         'run', 'plentiful', 'food', 'write', 'read', 'attempt', 'equal',
#         'important', 'animalism', 'commandment', 'seven', 'adopt',
#         'rename', 'jones', 'mr', 'irresponsible', 'drunken', 'drive',
#         'revolt', 'philosophy', 'dream', 'turn', 'command', 'assume',
#         'napoleon', 'snowball', 'pig', 'young', 'two', 'dy', 'england',
#         'beast', 'song', 'revolutionary', 'teach', 'parasite', 'human',
#         'compare', 'meeting', 'animal', 'call', 'farm', 'manor', 'boar',
#         'major', 'old'], dtype='<U110'),
#  array(['fatalistically', 'view', 'prospect', 'son', 'future',
#         'likelihood', 'contemplates', 'family', 'seek', 'inspires',
#         'settled', 'marry', 'chance', 'outgrow', 'trio', 'new', 'chapter',
#         'final', 'right', 'cure', 'reverse', 'conditioning', 'daydream',
#         'picture', 'snap', 'photographer', 'side', 'agrees', 'wellpaying',
#         'offer', 'institution', 'mental', 'pack', 'safely', 'create',
#         'publicity', 'bad', 'counter', 'anxious', 'court', 'wake',
#         'window', 'high', 'leap', 'prompt', 'barrage', 'relentless',
#         'subject', 'near', 'flatblock', 'lock', 'remove', 'confession',
#         'extract', 'manages', 'associate', 'radical', 'alexanders', 'ago',
#         'happening', 'role', 'reelect', 'incumbent', 'thereby',
#         'brutality', 'symbol', 'critic', 'horrid', 'persist', 'fragrant',
#         'living', 'decide', 'gangrape', 'inflict', 'die', 'mrs',
#         'sequence', 'question', 'shelter', 'alexander', 'reveal',
#         'recognize', 'mask', 'story', 'half', 'first', 'invade', 'house',
#         'late', 'realize', 'door', 'daze', 'town', 'outside', 'billyboy',
#         'former', 'none', 'come', 'policeman', 'help', 'revenge', 'keen',
#         'book', 'earlier', 'encounter', 'accidentally', 'suicide',
#         'commit', 'way', 'painless', 'hope', 'enters', 'street', 'wanders',
#         'lodger', 'room', 'rent', 'since', 'release', 'result', 'pleased',
#         'scene', 'official', 'free', 'strip', 'accuses', 'inclination',
#         'sexual', 'predatory', 'arouse', 'presence', 'whose',
#         'scantilyclad', 'abase', 'bully', 'wallop', 'vip', 'group',
#         'effectiveness', 'beloved', 'listen', 'unable', 'renders',
#         'symphony', 'fifth', 'beethovens', 'films', 'soundtrack',
#         'consequence', 'unintended', 'think', 'mere', 'nausea', 'bout',
#         'cripple', 'suffer', 'condition', 'film', 'graphically', 'watch',
#         'sick', 'feel', 'injection', 'receive', 'therapy', 'aversion',
#         'form', 'technique', 'ludovico', 'treatment',
#         'behaviourmodification', 'experimental', 'undergo', 'agree',
#         'cellmate', 'troublesome', 'blame', 'cellmates', 'fellow',
#         'passage', 'scripture', 'actually', 'faith', 'stirring', 'study',
#         'bible', 'mistake', 'chaplain', 'hymn', 'sing', 'service',
#         'stereo', 'religious', 'chapel', 'get', 'murder', 'prison',
#         'sentence', 'arrive', 'police', 'step', 'front', 'incapacitate',
#         'block', 'escape', 'elderly', 'pathos', 'tragic', 'end', 'farce',
#         'start', 'breakin', 'woman', 'wealthy', 'burgle', 'georgies',
#         'insist', 'generosity', 'fight', 'dims', 'slash', 'rebellion',
#         'quells', 'job', 'mansized', 'pull', 'demand', 'challenge', 'mood',
#         'mutinous', 'rape', 'drug', 'administers', 'parent', 'girl',
#         'tenyearold', 'pair', 'meet', 'advisor', 'postcorrective',
#         'deltoid', 'pr', 'visit', 'unexpected', 'day', 'next', 'school',
#         'skip', 'violence', 'orgiastic', 'fantasize', 'volume', 'top',
#         'classical', 'flat', 'dreary', 'apparent', 'strain', 'behaviour',
#         'crude', 'punishes', 'bar', 'milk', 'back', 'shred', 'theme',
#         'main', 'state', 'paragraph', 'contemptuously', 'orange',
#         'clockwork', 'manuscript', 'writer', 'touch', 'metafictional',
#         'rap', 'husband', 'beat', 'couple', 'maul', 'cottage', 'isolated',
#         'car', 'steal', 'countryside', 'joyride', 'scuffle', 'derelict',
#         'panhandle', 'stomp', 'unconscious', 'bloody', 'wife', 'leave',
#         'store', 'rob', 'library', 'public', 'home', 'scholar', 'assault',
#         'mayhem', 'night', 'hype', 'milkplus', 'cocktail', 'milkdrug',
#         'milkbar', 'korova', 'hangout', 'favorite', 'sit', 'ludwig',
#         'lovely', 'beethoven', 'fond', 'particularly', 'music',
#         'sophisticated', 'quickwitted', 'intelligent', 'also',
#         'delinquent', 'juvenile', 'harden', 'sociopath', 'characterize',
#         'taste', 'along', 'play', 'mostly', 'pete', 'secondincommand',
#         'ambitious', 'georgie', 'muscle', 'bruiser', 'slowwitted', 'dim',
#         'nadsat', 'slang', 'anglorussian', 'novel', 'droogs', 'alexs',
#         'ultraviolence', 'random', 'opportunistic', 'orgies', 'nightly',
#         'gang', 'lead', 'nearfuture', 'live', 'teenager', 'alex',
#         'demonstrate', 'prevent', 'within', 'eventually', 'follow',
#         'friend', 'wing', 'society', 'government', 'drink', 'indulge',
#         'break', 'wear', 'walk', 'learn', 'year', 'hand', 'death', 'owner',
#         'hospital', 'rescue', 'well', 'van', 'collapse', 'continue',
#         'injury', 'despite', 'though', 'attack', 'one', 'show', 'memory',
#         'even', 'make', 'rival', 'kill', 'begin', 'become', 'find',
#         'violent', 'hard', 'work', 'idea', 'name', 'use', 'take',
#         'leadership', 'read', 'attempt', 'turn', 'young', 'two', 'england',
#         'call', 'old'], dtype='<U110'),
#  array(['fatalistically', 'view', 'prospect', 'son', 'future',
#         'likelihood', 'contemplates', 'family', 'seek', 'inspires',
#         'settled', 'marry', 'chance', 'outgrow', 'trio', 'new', 'chapter',
#         'final', 'right', 'cure', 'reverse', 'conditioning', 'daydream',
#         'picture', 'snap', 'photographer', 'side', 'agrees', 'wellpaying',
#         'offer', 'institution', 'mental', 'pack', 'safely', 'create',
#         'publicity', 'bad', 'counter', 'anxious', 'court', 'wake',
#         'window', 'high', 'leap', 'prompt', 'barrage', 'relentless',
#         'subject', 'near', 'flatblock', 'lock', 'remove', 'confession',
#         'extract', 'manages', 'associate', 'radical', 'alexanders', 'ago',
#         'happening', 'role', 'reelect', 'incumbent', 'thereby',
#         'brutality', 'symbol', 'critic', 'horrid', 'persist', 'fragrant',
#         'living', 'decide', 'gangrape', 'inflict', 'die', 'mrs',
#         'sequence', 'question', 'shelter', 'alexander', 'reveal',
#         'recognize', 'mask', 'story', 'half', 'first', 'invade', 'house',
#         'late', 'realize', 'door', 'daze', 'town', 'outside', 'billyboy',
#         'former', 'none', 'come', 'policeman', 'help', 'revenge', 'keen',
#         'book', 'earlier', 'encounter', 'accidentally', 'suicide',
#         'commit', 'way', 'painless', 'hope', 'enters', 'street', 'wanders',
#         'lodger', 'room', 'rent', 'since', 'release', 'result', 'pleased',
#         'scene', 'official', 'free', 'strip', 'accuses', 'inclination',
#         'sexual', 'predatory', 'arouse', 'presence', 'whose',
#         'scantilyclad', 'abase', 'bully', 'wallop', 'vip', 'group',
#         'effectiveness', 'beloved', 'listen', 'unable', 'renders',
#         'symphony', 'fifth', 'beethovens', 'films', 'soundtrack',
#         'consequence', 'unintended', 'think', 'mere', 'nausea', 'bout',
#         'cripple', 'suffer', 'condition', 'film', 'graphically', 'watch',
#         'sick', 'feel', 'injection', 'receive', 'therapy', 'aversion',
#         'form', 'technique', 'ludovico', 'treatment',
#         'behaviourmodification', 'experimental', 'undergo', 'agree',
#         'cellmate', 'troublesome', 'blame', 'cellmates', 'fellow',
#         'passage', 'scripture', 'actually', 'faith', 'stirring', 'study',
#         'bible', 'mistake', 'chaplain', 'hymn', 'sing', 'service',
#         'stereo', 'religious', 'chapel', 'get', 'murder', 'prison',
#         'sentence', 'arrive', 'police', 'step', 'front', 'incapacitate',
#         'block', 'escape', 'elderly', 'pathos', 'tragic', 'end', 'farce',
#         'start', 'breakin', 'woman', 'wealthy', 'burgle', 'georgies',
#         'insist', 'generosity', 'fight', 'dims', 'slash', 'rebellion',
#         'quells', 'job', 'mansized', 'pull', 'demand', 'challenge', 'mood',
#         'mutinous', 'rape', 'drug', 'administers', 'parent', 'girl',
#         'tenyearold', 'pair', 'meet', 'advisor', 'postcorrective',
#         'deltoid', 'pr', 'visit', 'unexpected', 'day', 'next', 'school',
#         'skip', 'violence', 'orgiastic', 'fantasize', 'volume', 'top',
#         'classical', 'flat', 'dreary', 'apparent', 'strain', 'behaviour',
#         'crude', 'punishes', 'bar', 'milk', 'back', 'shred', 'theme',
#         'main', 'state', 'paragraph', 'contemptuously', 'orange',
#         'clockwork', 'manuscript', 'writer', 'touch', 'metafictional',
#         'rap', 'husband', 'beat', 'couple', 'maul', 'cottage', 'isolated',
#         'car', 'steal', 'countryside', 'joyride', 'scuffle', 'derelict',
#         'panhandle', 'stomp', 'unconscious', 'bloody', 'wife', 'leave',
#         'store', 'rob', 'library', 'public', 'home', 'scholar', 'assault',
#         'mayhem', 'night', 'hype', 'milkplus', 'cocktail', 'milkdrug',
#         'milkbar', 'korova', 'hangout', 'favorite', 'sit', 'ludwig',
#         'lovely', 'beethoven', 'fond', 'particularly', 'music',
#         'sophisticated', 'quickwitted', 'intelligent', 'also',
#         'delinquent', 'juvenile', 'harden', 'sociopath', 'characterize',
#         'taste', 'along', 'play', 'mostly', 'pete', 'secondincommand',
#         'ambitious', 'georgie', 'muscle', 'bruiser', 'slowwitted', 'dim',
#         'nadsat', 'slang', 'anglorussian', 'novel', 'droogs', 'alexs',
#         'ultraviolence', 'random', 'opportunistic', 'orgies', 'nightly',
#         'gang', 'lead', 'nearfuture', 'live', 'teenager', 'alex',
#         'demonstrate', 'prevent', 'within', 'eventually', 'follow',
#         'friend', 'wing', 'society', 'government', 'drink', 'indulge',
#         'break', 'wear', 'walk', 'learn', 'year', 'hand', 'death', 'owner',
#         'hospital', 'rescue', 'well', 'van', 'collapse', 'continue',
#         'injury', 'despite', 'though', 'attack', 'one', 'show', 'memory',
#         'even', 'make', 'rival', 'kill', 'begin', 'become', 'find',
#         'violent', 'hard', 'work', 'idea', 'name', 'use', 'take',
#         'leadership', 'read', 'attempt', 'turn', 'young', 'two', 'england',
#         'call', 'old'], dtype='<U110'),
#  array(['fatalistically', 'view', 'prospect', 'son', 'future',
#         'likelihood', 'contemplates', 'family', 'seek', 'inspires',
#         'settled', 'marry', 'chance', 'outgrow', 'trio', 'new', 'chapter',
#         'final', 'right', 'cure', 'reverse', 'conditioning', 'daydream',
#         'picture', 'snap', 'photographer', 'side', 'agrees', 'wellpaying',
#         'offer', 'institution', 'mental', 'pack', 'safely', 'create',
#         'publicity', 'bad', 'counter', 'anxious', 'court', 'wake',
#         'window', 'high', 'leap', 'prompt', 'barrage', 'relentless',
#         'subject', 'near', 'flatblock', 'lock', 'remove', 'confession',
#         'extract', 'manages', 'associate', 'radical', 'alexanders', 'ago',
#         'happening', 'role', 'reelect', 'incumbent', 'thereby',
#         'brutality', 'symbol', 'critic', 'horrid', 'persist', 'fragrant',
#         'living', 'decide', 'gangrape', 'inflict', 'die', 'mrs',
#         'sequence', 'question', 'shelter', 'alexander', 'reveal',
#         'recognize', 'mask', 'story', 'half', 'first', 'invade', 'house',
#         'late', 'realize', 'door', 'daze', 'town', 'outside', 'billyboy',
#         'former', 'none', 'come', 'policeman', 'help', 'revenge', 'keen',
#         'book', 'earlier', 'encounter', 'accidentally', 'suicide',
#         'commit', 'way', 'painless', 'hope', 'enters', 'street', 'wanders',
#         'lodger', 'room', 'rent', 'since', 'release', 'result', 'pleased',
#         'scene', 'official', 'free', 'strip', 'accuses', 'inclination',
#         'sexual', 'predatory', 'arouse', 'presence', 'whose',
#         'scantilyclad', 'abase', 'bully', 'wallop', 'vip', 'group',
#         'effectiveness', 'beloved', 'listen', 'unable', 'renders',
#         'symphony', 'fifth', 'beethovens', 'films', 'soundtrack',
#         'consequence', 'unintended', 'think', 'mere', 'nausea', 'bout',
#         'cripple', 'suffer', 'condition', 'film', 'graphically', 'watch',
#         'sick', 'feel', 'injection', 'receive', 'therapy', 'aversion',
#         'form', 'technique', 'ludovico', 'treatment',
#         'behaviourmodification', 'experimental', 'undergo', 'agree',
#         'cellmate', 'troublesome', 'blame', 'cellmates', 'fellow',
#         'passage', 'scripture', 'actually', 'faith', 'stirring', 'study',
#         'bible', 'mistake', 'chaplain', 'hymn', 'sing', 'service',
#         'stereo', 'religious', 'chapel', 'get', 'murder', 'prison',
#         'sentence', 'arrive', 'police', 'step', 'front', 'incapacitate',
#         'block', 'escape', 'elderly', 'pathos', 'tragic', 'end', 'farce',
#         'start', 'breakin', 'woman', 'wealthy', 'burgle', 'georgies',
#         'insist', 'generosity', 'fight', 'dims', 'slash', 'rebellion',
#         'quells', 'job', 'mansized', 'pull', 'demand', 'challenge', 'mood',
#         'mutinous', 'rape', 'drug', 'administers', 'parent', 'girl',
#         'tenyearold', 'pair', 'meet', 'advisor', 'postcorrective',
#         'deltoid', 'pr', 'visit', 'unexpected', 'day', 'next', 'school',
#         'skip', 'violence', 'orgiastic', 'fantasize', 'volume', 'top',
#         'classical', 'flat', 'dreary', 'apparent', 'strain', 'behaviour',
#         'crude', 'punishes', 'bar', 'milk', 'back', 'shred', 'theme',
#         'main', 'state', 'paragraph', 'contemptuously', 'orange',
#         'clockwork', 'manuscript', 'writer', 'touch', 'metafictional',
#         'rap', 'husband', 'beat', 'couple', 'maul', 'cottage', 'isolated',
#         'car', 'steal', 'countryside', 'joyride', 'scuffle', 'derelict',
#         'panhandle', 'stomp', 'unconscious', 'bloody', 'wife', 'leave',
#         'store', 'rob', 'library', 'public', 'home', 'scholar', 'assault',
#         'mayhem', 'night', 'hype', 'milkplus', 'cocktail', 'milkdrug',
#         'milkbar', 'korova', 'hangout', 'favorite', 'sit', 'ludwig',
#         'lovely', 'beethoven', 'fond', 'particularly', 'music',
#         'sophisticated', 'quickwitted', 'intelligent', 'also',
#         'delinquent', 'juvenile', 'harden', 'sociopath', 'characterize',
#         'taste', 'along', 'play', 'mostly', 'pete', 'secondincommand',
#         'ambitious', 'georgie', 'muscle', 'bruiser', 'slowwitted', 'dim',
#         'nadsat', 'slang', 'anglorussian', 'novel', 'droogs', 'alexs',
#         'ultraviolence', 'random', 'opportunistic', 'orgies', 'nightly',
#         'gang', 'lead', 'nearfuture', 'live', 'teenager', 'alex',
#         'demonstrate', 'prevent', 'within', 'eventually', 'follow',
#         'friend', 'wing', 'society', 'government', 'drink', 'indulge',
#         'break', 'wear', 'walk', 'learn', 'year', 'hand', 'death', 'owner',
#         'hospital', 'rescue', 'well', 'van', 'collapse', 'continue',
#         'injury', 'despite', 'though', 'attack', 'one', 'show', 'memory',
#         'even', 'make', 'rival', 'kill', 'begin', 'become', 'find',
#         'violent', 'hard', 'work', 'idea', 'name', 'use', 'take',
#         'leadership', 'read', 'attempt', 'turn', 'young', 'two', 'england',
#         'call', 'old'], dtype='<U110'),
#  array(['despise', 'admire', 'reach', 'reflect', 'shoot', 'mad', 'event',
#         'objective', 'present', 'chronicle', 'narrator', 'reveals',
#         'loved', 'reunite', 'february', 'rieuxs', 'heroic', 'contract',
#         'flees', 'employee', 'dealing', 'shady', 'profit', 'distress',
#         'imminent', 'celebrate', 'retreat', 'full', 'january', 'decline',
#         'recovery', 'paper', 'burn', 'instructs', 'catch', 'sea', 'swim',
#         'men', 'dead', 'separate', 'less', 'elect', 'period', 'camp',
#         'isolation', 'fatal', 'prove', 'still', 'disease', 'conform',
#         'ill', 'possible', 'congregation', 'urge', 'believe', 'everything',
#         'deny', 'either', 'require', 'christian', 'test', 'child',
#         'innocent', 'problem', 'address', 'sermon', 'second', 'volunteer',
#         'horror', 'greatly', 'suffers', 'othons', 'save', 'time',
#         'antiplague', 'castels', 'towards', 'left', 'ashamed', 'say',
#         'stay', 'symptom', 'portray', 'actor', 'eurydice', 'orpheus',
#         'opera', 'gluck', 'performance', 'attend', 'danger', 'everybody',
#         'connect', 'sense', 'flourish', 'seem', 'victim', 'regard',
#         'heart', 'wifes', 'sanatorium', 'hears', 'mercy', 'october',
#         'september', 'physically', 'emotionally', 'waste', 'despondent',
#         'exile', 'increase', 'endure', 'passively', 'inhabitant',
#         'decease', 'feeling', 'concern', 'little', 'ceremony', 'speed',
#         'conduct', 'funeral', 'curfew', 'law', 'martial', 'scale', 'small',
#         'loot', 'sentry', 'arm', 'shot', 'try', 'worsen', 'midaugust',
#         'decides', 'mind', 'sympathetic', 'see', 'allow', 'love',
#         'informs', 'patient', 'exhaustively', 'grand', 'joseph', 'servant',
#         'civil', 'tarrou', 'jean', 'vacationer', 'meanwhile', 'smuggler',
#         'arrest', 'fearful', 'yet', 'remorseful', 'cottard',
#         'circumstance', 'normal', 'do', 'would', 'drove', 'religion',
#         'ears', 'fall', 'diatribe', 'nature', 'sinful', 'citizen',
#         'punish', 'god', 'act', 'stature', 'advance', 'opportunity',
#         'paneloux', 'father', 'another', 'smuggle', 'may', 'criminal',
#         'befriends', 'request', 'refuse', 'paris', 'lover', 'join', 'city',
#         'devise', 'rambert', 'raymond', 'various', 'introverted',
#         'isolate', 'townspeople', 'spirit', 'depress', 'activity',
#         'affect', 'separation', 'communicate', 'mean', 'telegram', 'short',
#         'urgent', 'restrict', 'line', 'telephone', 'suspend', 'mail',
#         'prohibit', 'travel', 'rail', 'shut', 'gate', 'declare',
#         'officially', 'outbreak', 'seal', '30', 'jump', 'daily', 'deplete',
#         'emergency', 'countrys', 'case', 'exist', 'treat', 'enough',
#         'finally', 'serum', 'supply', 'supervise', 'strictly', 'burial',
#         'corps', 'quarantine', 'desperate', 'rise', 'toll', 'three',
#         'fill', '80', 'open', 'ward', 'seriousness', 'downplays',
#         'optimistic', 'language', 'post', 'measure', 'enact', 'action',
#         'appropriate', 'quibble', 'serious', 'situation', 'accept', 'slow',
#         'othon', 'prefect', 'epidemic', 'becomes', 'ensue', 'quickly',
#         'however', 'basis', 'dismiss', 'theory', 'doctor', 'approach',
#         'sweep', 'conclusion', 'illness', 'castel', 'colleague',
#         'consults', 'fever', 'confidante', 'michel', 'concierge',
#         'building', 'strangely', 'apartment', 'comfortably', 'rieux',
#         'bernard', 'dr', 'character', 'bubonic', 'spread', 'catalyst',
#         'unaware', 'cremation', 'collection', 'pressure', 'respond',
#         'authority', 'incident', 'newspaper', 'local', 'afterward',
#         'develop', 'hysteria', 'populace', 'unnoticed', 'initially', 'rat',
#         'thousand', 'oran', 'part', 'five', 'divide', 'plague', 'text',
#         'view', 'son', 'family', 'chance', 'new', 'decide', 'die', 'story',
#         'first', 'late', 'town', 'outside', 'come', 'help', 'suicide',
#         'street', 'since', 'official', 'group', 'suffer', 'condition',
#         'feel', 'fellow', 'faith', 'service', 'sentence', 'arrive',
#         'escape', 'end', 'start', 'wealthy', 'fight', 'meet', 'visit',
#         'unexpected', 'day', 'violence', 'apparent', 'main', 'wife',
#         'leave', 'public', 'home', 'also', 'harden', 'live', 'together',
#         'within', 'eventually', 'cause', 'friend', 'go', 'people', 'order',
#         'government', 'bed', 'soon', 'tell', 'look', 'break', 'face',
#         'others', 'hand', 'death', 'hospital', 'report', 'notice', 'well',
#         'give', 'collapse', 'continue', 'despite', 'include', 'many',
#         'one', 'number', 'remain', 'make', 'reserve', 'control', 'impose',
#         'begin', 'suggest', 'life', 'work', 'use', 'change', 'away',
#         'build', 'plan', 'struggle', 'take', 'special', 'attempt', 'turn',
#         'young', 'two', 'dy', 'human', 'call', 'major'], dtype='<U110'),
#  array(['despise', 'admire', 'reach', 'reflect', 'shoot', 'mad', 'event',
#         'objective', 'present', 'chronicle', 'narrator', 'reveals',
#         'loved', 'reunite', 'february', 'rieuxs', 'heroic', 'contract',
#         'flees', 'employee', 'dealing', 'shady', 'profit', 'distress',
#         'imminent', 'celebrate', 'retreat', 'full', 'january', 'decline',
#         'recovery', 'paper', 'burn', 'instructs', 'catch', 'sea', 'swim',
#         'men', 'dead', 'separate', 'less', 'elect', 'period', 'camp',
#         'isolation', 'fatal', 'prove', 'still', 'disease', 'conform',
#         'ill', 'possible', 'congregation', 'urge', 'believe', 'everything',
#         'deny', 'either', 'require', 'christian', 'test', 'child',
#         'innocent', 'problem', 'address', 'sermon', 'second', 'volunteer',
#         'horror', 'greatly', 'suffers', 'othons', 'save', 'time',
#         'antiplague', 'castels', 'towards', 'left', 'ashamed', 'say',
#         'stay', 'symptom', 'portray', 'actor', 'eurydice', 'orpheus',
#         'opera', 'gluck', 'performance', 'attend', 'danger', 'everybody',
#         'connect', 'sense', 'flourish', 'seem', 'victim', 'regard',
#         'heart', 'wifes', 'sanatorium', 'hears', 'mercy', 'october',
#         'september', 'physically', 'emotionally', 'waste', 'despondent',
#         'exile', 'increase', 'endure', 'passively', 'inhabitant',
#         'decease', 'feeling', 'concern', 'little', 'ceremony', 'speed',
#         'conduct', 'funeral', 'curfew', 'law', 'martial', 'scale', 'small',
#         'loot', 'sentry', 'arm', 'shot', 'try', 'worsen', 'midaugust',
#         'decides', 'mind', 'sympathetic', 'see', 'allow', 'love',
#         'informs', 'patient', 'exhaustively', 'grand', 'joseph', 'servant',
#         'civil', 'tarrou', 'jean', 'vacationer', 'meanwhile', 'smuggler',
#         'arrest', 'fearful', 'yet', 'remorseful', 'cottard',
#         'circumstance', 'normal', 'do', 'would', 'drove', 'religion',
#         'ears', 'fall', 'diatribe', 'nature', 'sinful', 'citizen',
#         'punish', 'god', 'act', 'stature', 'advance', 'opportunity',
#         'paneloux', 'father', 'another', 'smuggle', 'may', 'criminal',
#         'befriends', 'request', 'refuse', 'paris', 'lover', 'join', 'city',
#         'devise', 'rambert', 'raymond', 'various', 'introverted',
#         'isolate', 'townspeople', 'spirit', 'depress', 'activity',
#         'affect', 'separation', 'communicate', 'mean', 'telegram', 'short',
#         'urgent', 'restrict', 'line', 'telephone', 'suspend', 'mail',
#         'prohibit', 'travel', 'rail', 'shut', 'gate', 'declare',
#         'officially', 'outbreak', 'seal', '30', 'jump', 'daily', 'deplete',
#         'emergency', 'countrys', 'case', 'exist', 'treat', 'enough',
#         'finally', 'serum', 'supply', 'supervise', 'strictly', 'burial',
#         'corps', 'quarantine', 'desperate', 'rise', 'toll', 'three',
#         'fill', '80', 'open', 'ward', 'seriousness', 'downplays',
#         'optimistic', 'language', 'post', 'measure', 'enact', 'action',
#         'appropriate', 'quibble', 'serious', 'situation', 'accept', 'slow',
#         'othon', 'prefect', 'epidemic', 'becomes', 'ensue', 'quickly',
#         'however', 'basis', 'dismiss', 'theory', 'doctor', 'approach',
#         'sweep', 'conclusion', 'illness', 'castel', 'colleague',
#         'consults', 'fever', 'confidante', 'michel', 'concierge',
#         'building', 'strangely', 'apartment', 'comfortably', 'rieux',
#         'bernard', 'dr', 'character', 'bubonic', 'spread', 'catalyst',
#         'unaware', 'cremation', 'collection', 'pressure', 'respond',
#         'authority', 'incident', 'newspaper', 'local', 'afterward',
#         'develop', 'hysteria', 'populace', 'unnoticed', 'initially', 'rat',
#         'thousand', 'oran', 'part', 'five', 'divide', 'plague', 'text',
#         'view', 'son', 'family', 'chance', 'new', 'decide', 'die', 'story',
#         'first', 'late', 'town', 'outside', 'come', 'help', 'suicide',
#         'street', 'since', 'official', 'group', 'suffer', 'condition',
#         'feel', 'fellow', 'faith', 'service', 'sentence', 'arrive',
#         'escape', 'end', 'start', 'wealthy', 'fight', 'meet', 'visit',
#         'unexpected', 'day', 'violence', 'apparent', 'main', 'wife',
#         'leave', 'public', 'home', 'also', 'harden', 'live', 'together',
#         'within', 'eventually', 'cause', 'friend', 'go', 'people', 'order',
#         'government', 'bed', 'soon', 'tell', 'look', 'break', 'face',
#         'others', 'hand', 'death', 'hospital', 'report', 'notice', 'well',
#         'give', 'collapse', 'continue', 'despite', 'include', 'many',
#         'one', 'number', 'remain', 'make', 'reserve', 'control', 'impose',
#         'begin', 'suggest', 'life', 'work', 'use', 'change', 'away',
#         'build', 'plan', 'struggle', 'take', 'special', 'attempt', 'turn',
#         'young', 'two', 'dy', 'human', 'call', 'major'], dtype='<U110'),
#  array(['impossible', 'depth', 'strand', 'race', 'several', 'extinction',
#         'potentially', 'trillion', 'uninvolved', 'wrecking', 'enclose',
#         'lightyears', 'extends', 'initiate', 'defeat', 'ally', 'homeworld',
#         'destruction', 'godshatter', 'process', 'activate', 'necessary',
#         'investigate', 'ii', 'band', 'vessel', 'design', 'trace',
#         'organization', 'vrinimi', 'bergsndot', 'ravna', 'agent', 'nuwen',
#         'pham', 'seemingly', 'construct', 'benign', 'network', 'node',
#         'relay', 'signal', 'war', 'impend', 'upper', 'gain', 'ask',
#         'woodcarver', 'bring', 'wander', 'scriber', 'pilgrim', 'johanna',
#         'sister', 'jefris', 'communication', 'radio', 'cannon', 'exploit',
#         'intend', 'olsndot', 'jefri', 'boy', 'capture', 'steel', 'contact',
#         'faction', 'seize', 'force', 'unload', 'adult', 'survive', 'fail',
#         'box', 'coldsleep', 'sleeper', 'tine', 'dub', 'creature',
#         'doglike', 'medievallevel', 'planet', 'distant', 'land', 'fear',
#         'universe', 'thing', 'countermeasure', 'threat', 'unharmed',
#         'destroys', 'harm', 'information', 'contains', 'manifest', 'cargo',
#         'device', 'storage', 'discovers', 'suspicious', 'ship', 'flee',
#         'researcher', 'awaken', '10000', 'exceed', 'minute', 'flowering',
#         'shortly', 'unfathomable', 'nighomnipotent', 'transcendent',
#         'culminate', 'stage', 'developmental', 'accelerate',
#         'exponentially', 'superintelligence', 'evolution', 'description',
#         'imaginative', 'posse', 'ability', 'system', 'computer',
#         'infiltrate', 'learns', 'rapidly', 'blight', 'know', 'encode',
#         'superintelligent', 'dormant', 'compromise', 'gradually', 'lab',
#         'facility', 'realm', 'straumli', 'civilization', 'rich',
#         'unimaginable', 'possibility', 'archive', 'data',
#         'fivebillionyearold', 'investigates', 'expedition', 'entity',
#         'posthuman', 'powerful', 'vast', 'incomprehensibly', 'populate',
#         'halo', 'contain', 'transcend', 'outermost', 'ftl', 'ai',
#         'technology', 'futuristic', 'support', 'beyond', 'potential',
#         'behavior', 'real', 'equivalent', 'roughly', 'advanced',
#         'supporting', 'incapable', 'core', 'galactic', 'surround',
#         'depths', 'unthinking', 'innermost', 'advancement',
#         'technological', 'biological', 'degree', 'physic', 'different',
#         'constrain', 'zone', 'layer', 'concentric', 'milky', 'around',
#         'space', 'posit', 'reach', 'employee', 'distress', 'child',
#         'second', 'say', 'danger', 'law', 'mind', 'allow', 'act',
#         'advance', 'travel', 'slow', 'develop', 'initially', 'thousand',
#         'divide', 'seek', 'final', 'offer', 'pack', 'high', 'living',
#         'die', 'reveal', 'recognize', 'realize', 'help', 'way', 'release',
#         'group', 'mere', 'form', 'actually', 'arrive', 'escape', 'end',
#         'start', 'wealthy', 'next', 'also', 'ambitious', 'novel', 'lead',
#         'live', 'within', 'eventually', 'cause', 'later', 'order', 'world',
#         'hold', 'single', 'carry', 'year', 'hand', 'death', 'owner',
#         'rescue', 'could', 'give', 'many', 'cost', 'attack', 'one', 'man',
#         'even', 'control', 'power', 'rival', 'kill', 'begin', 'destroy',
#         'life', 'name', 'change', 'attempt', 'assume', 'young', 'two',
#         'human', 'call', 'major', 'old'], dtype='<U110'),
#  array(['impossible', 'depth', 'strand', 'race', 'several', 'extinction',
#         'potentially', 'trillion', 'uninvolved', 'wrecking', 'enclose',
#         'lightyears', 'extends', 'initiate', 'defeat', 'ally', 'homeworld',
#         'destruction', 'godshatter', 'process', 'activate', 'necessary',
#         'investigate', 'ii', 'band', 'vessel', 'design', 'trace',
#         'organization', 'vrinimi', 'bergsndot', 'ravna', 'agent', 'nuwen',
#         'pham', 'seemingly', 'construct', 'benign', 'network', 'node',
#         'relay', 'signal', 'war', 'impend', 'upper', 'gain', 'ask',
#         'woodcarver', 'bring', 'wander', 'scriber', 'pilgrim', 'johanna',
#         'sister', 'jefris', 'communication', 'radio', 'cannon', 'exploit',
#         'intend', 'olsndot', 'jefri', 'boy', 'capture', 'steel', 'contact',
#         'faction', 'seize', 'force', 'unload', 'adult', 'survive', 'fail',
#         'box', 'coldsleep', 'sleeper', 'tine', 'dub', 'creature',
#         'doglike', 'medievallevel', 'planet', 'distant', 'land', 'fear',
#         'universe', 'thing', 'countermeasure', 'threat', 'unharmed',
#         'destroys', 'harm', 'information', 'contains', 'manifest', 'cargo',
#         'device', 'storage', 'discovers', 'suspicious', 'ship', 'flee',
#         'researcher', 'awaken', '10000', 'exceed', 'minute', 'flowering',
#         'shortly', 'unfathomable', 'nighomnipotent', 'transcendent',
#         'culminate', 'stage', 'developmental', 'accelerate',
#         'exponentially', 'superintelligence', 'evolution', 'description',
#         'imaginative', 'posse', 'ability', 'system', 'computer',
#         'infiltrate', 'learns', 'rapidly', 'blight', 'know', 'encode',
#         'superintelligent', 'dormant', 'compromise', 'gradually', 'lab',
#         'facility', 'realm', 'straumli', 'civilization', 'rich',
#         'unimaginable', 'possibility', 'archive', 'data',
#         'fivebillionyearold', 'investigates', 'expedition', 'entity',
#         'posthuman', 'powerful', 'vast', 'incomprehensibly', 'populate',
#         'halo', 'contain', 'transcend', 'outermost', 'ftl', 'ai',
#         'technology', 'futuristic', 'support', 'beyond', 'potential',
#         'behavior', 'real', 'equivalent', 'roughly', 'advanced',
#         'supporting', 'incapable', 'core', 'galactic', 'surround',
#         'depths', 'unthinking', 'innermost', 'advancement',
#         'technological', 'biological', 'degree', 'physic', 'different',
#         'constrain', 'zone', 'layer', 'concentric', 'milky', 'around',
#         'space', 'posit', 'reach', 'employee', 'distress', 'child',
#         'second', 'say', 'danger', 'law', 'mind', 'allow', 'act',
#         'advance', 'travel', 'slow', 'develop', 'initially', 'thousand',
#         'divide', 'seek', 'final', 'offer', 'pack', 'high', 'living',
#         'die', 'reveal', 'recognize', 'realize', 'help', 'way', 'release',
#         'group', 'mere', 'form', 'actually', 'arrive', 'escape', 'end',
#         'start', 'wealthy', 'next', 'also', 'ambitious', 'novel', 'lead',
#         'live', 'within', 'eventually', 'cause', 'later', 'order', 'world',
#         'hold', 'single', 'carry', 'year', 'hand', 'death', 'owner',
#         'rescue', 'could', 'give', 'many', 'cost', 'attack', 'one', 'man',
#         'even', 'control', 'power', 'rival', 'kill', 'begin', 'destroy',
#         'life', 'name', 'change', 'attempt', 'assume', 'young', 'two',
#         'human', 'call', 'major', 'old'], dtype='<U110'),
#  array(['impossible', 'depth', 'strand', 'race', 'several', 'extinction',
#         'potentially', 'trillion', 'uninvolved', 'wrecking', 'enclose',
#         'lightyears', 'extends', 'initiate', 'defeat', 'ally', 'homeworld',
#         'destruction', 'godshatter', 'process', 'activate', 'necessary',
#         'investigate', 'ii', 'band', 'vessel', 'design', 'trace',
#         'organization', 'vrinimi', 'bergsndot', 'ravna', 'agent', 'nuwen',
#         'pham', 'seemingly', 'construct', 'benign', 'network', 'node',
#         'relay', 'signal', 'war', 'impend', 'upper', 'gain', 'ask',
#         'woodcarver', 'bring', 'wander', 'scriber', 'pilgrim', 'johanna',
#         'sister', 'jefris', 'communication', 'radio', 'cannon', 'exploit',
#         'intend', 'olsndot', 'jefri', 'boy', 'capture', 'steel', 'contact',
#         'faction', 'seize', 'force', 'unload', 'adult', 'survive', 'fail',
#         'box', 'coldsleep', 'sleeper', 'tine', 'dub', 'creature',
#         'doglike', 'medievallevel', 'planet', 'distant', 'land', 'fear',
#         'universe', 'thing', 'countermeasure', 'threat', 'unharmed',
#         'destroys', 'harm', 'information', 'contains', 'manifest', 'cargo',
#         'device', 'storage', 'discovers', 'suspicious', 'ship', 'flee',
#         'researcher', 'awaken', '10000', 'exceed', 'minute', 'flowering',
#         'shortly', 'unfathomable', 'nighomnipotent', 'transcendent',
#         'culminate', 'stage', 'developmental', 'accelerate',
#         'exponentially', 'superintelligence', 'evolution', 'description',
#         'imaginative', 'posse', 'ability', 'system', 'computer',
#         'infiltrate', 'learns', 'rapidly', 'blight', 'know', 'encode',
#         'superintelligent', 'dormant', 'compromise', 'gradually', 'lab',
#         'facility', 'realm', 'straumli', 'civilization', 'rich',
#         'unimaginable', 'possibility', 'archive', 'data',
#         'fivebillionyearold', 'investigates', 'expedition', 'entity',
#         'posthuman', 'powerful', 'vast', 'incomprehensibly', 'populate',
#         'halo', 'contain', 'transcend', 'outermost', 'ftl', 'ai',
#         'technology', 'futuristic', 'support', 'beyond', 'potential',
#         'behavior', 'real', 'equivalent', 'roughly', 'advanced',
#         'supporting', 'incapable', 'core', 'galactic', 'surround',
#         'depths', 'unthinking', 'innermost', 'advancement',
#         'technological', 'biological', 'degree', 'physic', 'different',
#         'constrain', 'zone', 'layer', 'concentric', 'milky', 'around',
#         'space', 'posit', 'reach', 'employee', 'distress', 'child',
#         'second', 'say', 'danger', 'law', 'mind', 'allow', 'act',
#         'advance', 'travel', 'slow', 'develop', 'initially', 'thousand',
#         'divide', 'seek', 'final', 'offer', 'pack', 'high', 'living',
#         'die', 'reveal', 'recognize', 'realize', 'help', 'way', 'release',
#         'group', 'mere', 'form', 'actually', 'arrive', 'escape', 'end',
#         'start', 'wealthy', 'next', 'also', 'ambitious', 'novel', 'lead',
#         'live', 'within', 'eventually', 'cause', 'later', 'order', 'world',
#         'hold', 'single', 'carry', 'year', 'hand', 'death', 'owner',
#         'rescue', 'could', 'give', 'many', 'cost', 'attack', 'one', 'man',
#         'even', 'control', 'power', 'rival', 'kill', 'begin', 'destroy',
#         'life', 'name', 'change', 'attempt', 'assume', 'young', 'two',
#         'human', 'call', 'major', 'old'], dtype='<U110'),
#  array(['impossible', 'depth', 'strand', 'race', 'several', 'extinction',
#         'potentially', 'trillion', 'uninvolved', 'wrecking', 'enclose',
#         'lightyears', 'extends', 'initiate', 'defeat', 'ally', 'homeworld',
#         'destruction', 'godshatter', 'process', 'activate', 'necessary',
#         'investigate', 'ii', 'band', 'vessel', 'design', 'trace',
#         'organization', 'vrinimi', 'bergsndot', 'ravna', 'agent', 'nuwen',
#         'pham', 'seemingly', 'construct', 'benign', 'network', 'node',
#         'relay', 'signal', 'war', 'impend', 'upper', 'gain', 'ask',
#         'woodcarver', 'bring', 'wander', 'scriber', 'pilgrim', 'johanna',
#         'sister', 'jefris', 'communication', 'radio', 'cannon', 'exploit',
#         'intend', 'olsndot', 'jefri', 'boy', 'capture', 'steel', 'contact',
#         'faction', 'seize', 'force', 'unload', 'adult', 'survive', 'fail',
#         'box', 'coldsleep', 'sleeper', 'tine', 'dub', 'creature',
#         'doglike', 'medievallevel', 'planet', 'distant', 'land', 'fear',
#         'universe', 'thing', 'countermeasure', 'threat', 'unharmed',
#         'destroys', 'harm', 'information', 'contains', 'manifest', 'cargo',
#         'device', 'storage', 'discovers', 'suspicious', 'ship', 'flee',
#         'researcher', 'awaken', '10000', 'exceed', 'minute', 'flowering',
#         'shortly', 'unfathomable', 'nighomnipotent', 'transcendent',
#         'culminate', 'stage', 'developmental', 'accelerate',
#         'exponentially', 'superintelligence', 'evolution', 'description',
#         'imaginative', 'posse', 'ability', 'system', 'computer',
#         'infiltrate', 'learns', 'rapidly', 'blight', 'know', 'encode',
#         'superintelligent', 'dormant', 'compromise', 'gradually', 'lab',
#         'facility', 'realm', 'straumli', 'civilization', 'rich',
#         'unimaginable', 'possibility', 'archive', 'data',
#         'fivebillionyearold', 'investigates', 'expedition', 'entity',
#         'posthuman', 'powerful', 'vast', 'incomprehensibly', 'populate',
#         'halo', 'contain', 'transcend', 'outermost', 'ftl', 'ai',
#         'technology', 'futuristic', 'support', 'beyond', 'potential',
#         'behavior', 'real', 'equivalent', 'roughly', 'advanced',
#         'supporting', 'incapable', 'core', 'galactic', 'surround',
#         'depths', 'unthinking', 'innermost', 'advancement',
#         'technological', 'biological', 'degree', 'physic', 'different',
#         'constrain', 'zone', 'layer', 'concentric', 'milky', 'around',
#         'space', 'posit', 'reach', 'employee', 'distress', 'child',
#         'second', 'say', 'danger', 'law', 'mind', 'allow', 'act',
#         'advance', 'travel', 'slow', 'develop', 'initially', 'thousand',
#         'divide', 'seek', 'final', 'offer', 'pack', 'high', 'living',
# ...
#         'senior', 'commission', 'described', 'chinese', 'grass',
#         'margaret', 'variety', 'fast', 'atmosphere', 'brave', 'focus',
#         'elder', 'bachelor', 'organize', 'johnson', 'perform', 'largely',
#         'independent', 'filipino', 'british', 'liver', 'eat', 'ghost',
#         'tongue', 'richard', 'gun', 'fictional', 'european', 'air',
#         'custom', 'expression', 'tense', 'twenty', 'acquire', 'describes',
#         'red', 'big', 'field', 'hundred', 'charles', 'fort', 'conflict',
#         'guard', 'nephew', 'sword', 'river', 'hear', 'flame', 'past',
#         'literally', 'shoulder', 'never', 'brief', 'mistress', 'concerned',
#         'unit', 'particular', 'enable', 'inherit', 'dagger', 'detail',
#         'evidence', 'traditional', 'dynasty', 'enter', 'marries', 'moon',
#         'already', 'slave', 'strike', 'road', 'trader', 'morning', 'early',
#         'note', 'stab', 'establish', 'earth', 'describe', 'tie', 'english',
#         'letter', 'relationship', 'coast', 'emotional', 'maintain',
#         'poison', 'fleet', 'midst', 'cover', 'succeed', 'long', 'emotion',
#         'word', 'deliver', 'native', 'chaos', 'resolve', 'brother', 'lose',
#         'author', 'eye', 'place', 'base', 'month', 'blade', 'crew', 'fish',
#         'last', 'provide', 'deal', 'region', 'return', 'lord', 'person',
#         'accident', 'much', 'mother', 'know', 'rich', 'real', 'event',
#         'full', 'innocent', 'second', 'time', 'sense', 'seem', 'heart',
#         'small', 'see', 'father', 'another', 'spirit', 'however', 'local',
#         'son', 'marry', 'safely', 'high', 'subject', 'manages', 'die',
#         'story', 'half', 'late', 'book', 'way', 'street', 'since',
#         'presence', 'sick', 'actually', 'service', 'arrive', 'end',
#         'woman', 'wealthy', 'day', 'next', 'school', 'state', 'wife',
#         'assault', 'also', 'play', 'novel', 'lead', 'simply', 'within',
#         'keep', 'follow', 'enemy', 'government', 'break', 'tradition',
#         'carry', 'year', 'hand', 'death', 'many', 'great', 'battle', 'one',
#         'good', 'history', 'power', 'become', 'although', 'life', 'claim',
#         'name', 'use', 'change', 'take', 'read', 'attempt', 'young', 'two',
#         'england', 'teach', 'old'], dtype='<U110'),
#  array(['castrated', 'spearmen', 'drugmaddened', 'cerberus', 'disembody',
#         'nephthys', 'entrails', 'augur', 'scrier', 'vivisect', 'ddonori',
#         'fogshrouded', 'agnostic', 'litany', 'selfimmolation',
#         'interlocking', 'inexhaustibly', 'blis', 'eating', 'catafalque',
#         'paperweight', 'wallmounted', 'furnishing', 'geography',
#         'detriment', 'overpopulation', 'famine', 'plenty', 'cultivate',
#         'anubis', 'overthrown', 'skagganauk', 'horseshadow', 'typhon',
#         'osiris', 'fights', 'thoths', 'thoth', 'enjoyment', 'warlord',
#         'weave', 'stag', 'delegate', 'solely', 'obliterate', 'abyss',
#         'fertile', 'balance', 'bliss', '14', 'respectively', 'hammer',
#         'threeheaded', 'vacuum', 'sometimes', 'annihilation', 'glove',
#         'canine', 'cave', 'safekeeping', 'skull', 'smash', 'audience',
#         'resembles', 'six', 'being', 'neglect', 'atmosphere', 'burst',
#         'predict', 'victor', 'anomaly', 'proliferation', 'enjoy',
#         'alternate', 'dominance', 'nervous', 'prayer', 'cast',
#         'administer', 'champion', 'numerous', 'devastate', 'unleashes',
#         'hole', 'shoe', 'administration', 'amongst', 'station', 'sun',
#         'dark', 'money', 'dance', 'personality', 'scatter', 'raid',
#         'rebellious', 'worship', 'invisible', 'utterly', 'galaxy',
#         'speaker', 'brain', 'examine', 'and', 'vanishes', 'pleasure',
#         'curious', 'rug', 'cry', 'black', 'scream', 'past', 'fire',
#         'something', 'hide', 'answer', 'duty', 'indeed', 'worry', 'never',
#         'whole', 'proper', 'threaten', 'revive', 'possibly', 'century',
#         'rule', 'priest', 'armor', 'horse', 'unnamed', 'motion', 'consume',
#         'apparently', 'lie', 'presume', 'maintain', 'godlike', 'cover',
#         'term', 'weapon', 'mysterious', 'prisoner', 'charge', 'immortal',
#         'brother', 'among', 'point', 'angel', 'place', 'via', 'speak',
#         'abandon', 'inhabit', 'across', 'malevolent', 'safe', 'nearly',
#         'ever', 'protect', 'prince', 'choice', 'common', 'much', 'race',
#         'several', 'trace', 'capture', 'force', 'survive', 'dub',
#         'creature', 'planet', 'distant', 'universe', 'thing', 'contains',
#         'awaken', 'system', 'know', 'dormant', 'powerful', 'contain',
#         'real', 'different', 'event', 'sea', 'dead', 'either', 'require',
#         'time', 'see', 'love', 'meanwhile', 'normal', 'god', 'father',
#         'another', 'city', 'various', 'jump', 'fill', 'thousand', 'plague',
#         'son', 'future', 'family', 'question', 'house', 'town', 'help',
#         'suicide', 'commit', 'way', 'room', 'whose', 'watch', 'receive',
#         'agree', 'get', 'front', 'fight', 'job', 'pair', 'wife', 'night',
#         'intelligent', 'also', 'within', 'keep', 'without', 'enemy', 'go',
#         'people', 'drink', 'like', 'world', 'others', 'reduce', 'death',
#         'give', 'include', 'battle', 'blast', 'attack', 'one', 'good',
#         'man', 'appear', 'make', 'power', 'kill', 'become', 'destroy',
#         'find', 'life', 'work', 'name', 'use', 'dog', 'take', 'special',
#         'set', 'two', 'call', 'old'], dtype='<U110'),
#  array(['castrated', 'spearmen', 'drugmaddened', 'cerberus', 'disembody',
#         'nephthys', 'entrails', 'augur', 'scrier', 'vivisect', 'ddonori',
#         'fogshrouded', 'agnostic', 'litany', 'selfimmolation',
#         'interlocking', 'inexhaustibly', 'blis', 'eating', 'catafalque',
#         'paperweight', 'wallmounted', 'furnishing', 'geography',
#         'detriment', 'overpopulation', 'famine', 'plenty', 'cultivate',
#         'anubis', 'overthrown', 'skagganauk', 'horseshadow', 'typhon',
#         'osiris', 'fights', 'thoths', 'thoth', 'enjoyment', 'warlord',
#         'weave', 'stag', 'delegate', 'solely', 'obliterate', 'abyss',
#         'fertile', 'balance', 'bliss', '14', 'respectively', 'hammer',
#         'threeheaded', 'vacuum', 'sometimes', 'annihilation', 'glove',
#         'canine', 'cave', 'safekeeping', 'skull', 'smash', 'audience',
#         'resembles', 'six', 'being', 'neglect', 'atmosphere', 'burst',
#         'predict', 'victor', 'anomaly', 'proliferation', 'enjoy',
#         'alternate', 'dominance', 'nervous', 'prayer', 'cast',
#         'administer', 'champion', 'numerous', 'devastate', 'unleashes',
#         'hole', 'shoe', 'administration', 'amongst', 'station', 'sun',
#         'dark', 'money', 'dance', 'personality', 'scatter', 'raid',
#         'rebellious', 'worship', 'invisible', 'utterly', 'galaxy',
#         'speaker', 'brain', 'examine', 'and', 'vanishes', 'pleasure',
#         'curious', 'rug', 'cry', 'black', 'scream', 'past', 'fire',
#         'something', 'hide', 'answer', 'duty', 'indeed', 'worry', 'never',
#         'whole', 'proper', 'threaten', 'revive', 'possibly', 'century',
#         'rule', 'priest', 'armor', 'horse', 'unnamed', 'motion', 'consume',
#         'apparently', 'lie', 'presume', 'maintain', 'godlike', 'cover',
#         'term', 'weapon', 'mysterious', 'prisoner', 'charge', 'immortal',
#         'brother', 'among', 'point', 'angel', 'place', 'via', 'speak',
#         'abandon', 'inhabit', 'across', 'malevolent', 'safe', 'nearly',
#         'ever', 'protect', 'prince', 'choice', 'common', 'much', 'race',
#         'several', 'trace', 'capture', 'force', 'survive', 'dub',
#         'creature', 'planet', 'distant', 'universe', 'thing', 'contains',
#         'awaken', 'system', 'know', 'dormant', 'powerful', 'contain',
#         'real', 'different', 'event', 'sea', 'dead', 'either', 'require',
#         'time', 'see', 'love', 'meanwhile', 'normal', 'god', 'father',
#         'another', 'city', 'various', 'jump', 'fill', 'thousand', 'plague',
#         'son', 'future', 'family', 'question', 'house', 'town', 'help',
#         'suicide', 'commit', 'way', 'room', 'whose', 'watch', 'receive',
#         'agree', 'get', 'front', 'fight', 'job', 'pair', 'wife', 'night',
#         'intelligent', 'also', 'within', 'keep', 'without', 'enemy', 'go',
#         'people', 'drink', 'like', 'world', 'others', 'reduce', 'death',
#         'give', 'include', 'battle', 'blast', 'attack', 'one', 'good',
#         'man', 'appear', 'make', 'power', 'kill', 'become', 'destroy',
#         'find', 'life', 'work', 'name', 'use', 'dog', 'take', 'special',
#         'set', 'two', 'call', 'old'], dtype='<U110'),
#  array(['reemerged', 'transcribe', 'knotly', 'pieixoto', 'keynote', '2195',
#         'gileadean', 'transcription', 'ofglens', 'ofglen', 'offreds',
#         'furtively', 'aspects', 'theocracy', 'circumscribe', 'category',
#         'gileads', 'indoctrination', 'interspersed', 'unwoman',
#         'patronymic', 'offred', 'orthodoxy', 'testamentinspired',
#         'compulsorily', 'militarized', 'theocratic', 'suspends',
#         'extremist', 'islamic', 'pervasive', 'ideologically',
#         'theocraticorganized', 'nativist', 'homophobic', 'racist',
#         'handmaid', 'tape', 'consolidate', 'cosmetic', 'banking',
#         'hierarchical', 'stag', 'coup', 'canada', 'contraband',
#         'electronic', 'degradation', 'gilead', 'mayday', 'regime',
#         'highranking', 'constitution', 'reorganize', 'uncertain',
#         'republic', 'allows', 'forbid', 'assignment', 'driver',
#         'interaction', 'collectively', 'probable', 'she', 'found',
#         'divulge', 'reproductive', 'symposium', 'ritual', 'reestablish',
#         'pretext', 'cassette', 'implies', 'portion', 'cooperation', 'nick',
#         'freeze', 'jacob', 'policy', 'truly', 'congress', 'concludes',
#         'commander', 'rendezvous', 'launch', 'frequently', 'dictatorship',
#         'subversive', 'fred', 'ambiguous', 'enjoy', 'illegal',
#         'undesirable', 'asset', 'epilogue', 'pose', 'terrorist',
#         'formerly', 'dangerous', 'social', 'fashion', 'occur', 'thirty',
#         'advantage', 'thought', 'narrative', 'describes', 'style',
#         'brothel', 'wade', 'president', 'america', 'era', 'united',
#         'overthrow', 'speaker', 'expose', 'intent', 'magazine', 'black',
#         'past', 'accord', 'movement', 'response', 'literally', 'discard',
#         'resistance', 'individual', 'hidden', 'news', 'evidence',
#         'concubine', 'rule', 'record', 'third', 'freedom', 'autonomy',
#         'reading', 'american', 'member', 'professor', 'describe',
#         'disappearance', 'border', 'newly', 'effort', 'relationship',
#         'legal', 'sterile', 'intercourse', 'pregnant', 'birth', 'sex',
#         'flashback', 'physical', 'discover', 'exchange', 'underground',
#         'military', 'native', 'secret', 'almost', 'arranges', 'among',
#         'conclude', 'lose', 'move', 'point', 'ecological', 'eye',
#         'initial', 'onto', 'able', 'return', 'daughter', 'refer', 'trust',
#         'person', 'must', 'far', 'large', 'several', 'potentially',
#         'agent', 'network', 'capture', 'fail', 'distant', 'information',
#         'shortly', 'learns', 'know', 'different', 'event', 'present',
#         'decline', 'men', 'period', 'believe', 'christian', 'time',
#         'ceremony', 'try', 'see', 'religion', 'another', 'activity',
#         'declare', 'case', 'quickly', 'however', 'colleague', 'character',
#         'part', 'view', 'son', 'future', 'contemplates', 'family', 'new',
#         'final', 'right', 'create', 'near', 'critic', 'story', 'first',
#         'book', 'suicide', 'enters', 'since', 'result', 'official',
#         'strip', 'sexual', 'form', 'blame', 'study', 'religious', 'get',
#         'police', 'escape', 'woman', 'meet', 'state', 'metafictional',
#         'husband', 'wife', 'also', 'along', 'novel', 'live', 'within',
#         'keep', 'suppose', 'purpose', 'follow', 'secretly', 'later', 'go',
#         'society', 'belief', 'order', 'government', 'tell', 'revolution',
#         'class', 'country', 'tale', 'give', 'explain', 'van', 'collapse',
#         'despite', 'include', 'many', 'restore', 'attack', 'one', 'memory',
#         'even', 'power', 'kill', 'begin', 'become', 'suggest', 'although',
#         'find', 'life', 'claim', 'structure', 'away', 'take', 'set', 'run',
#         'write', 'read', 'attempt', 'equal', 'drive', 'meeting', 'call',
#         'old'], dtype='<U110'),
#  array(['reemerged', 'transcribe', 'knotly', 'pieixoto', 'keynote', '2195',
#         'gileadean', 'transcription', 'ofglens', 'ofglen', 'offreds',
#         'furtively', 'aspects', 'theocracy', 'circumscribe', 'category',
#         'gileads', 'indoctrination', 'interspersed', 'unwoman',
#         'patronymic', 'offred', 'orthodoxy', 'testamentinspired',
#         'compulsorily', 'militarized', 'theocratic', 'suspends',
#         'extremist', 'islamic', 'pervasive', 'ideologically',
#         'theocraticorganized', 'nativist', 'homophobic', 'racist',
#         'handmaid', 'tape', 'consolidate', 'cosmetic', 'banking',
#         'hierarchical', 'stag', 'coup', 'canada', 'contraband',
#         'electronic', 'degradation', 'gilead', 'mayday', 'regime',
#         'highranking', 'constitution', 'reorganize', 'uncertain',
#         'republic', 'allows', 'forbid', 'assignment', 'driver',
#         'interaction', 'collectively', 'probable', 'she', 'found',
#         'divulge', 'reproductive', 'symposium', 'ritual', 'reestablish',
#         'pretext', 'cassette', 'implies', 'portion', 'cooperation', 'nick',
#         'freeze', 'jacob', 'policy', 'truly', 'congress', 'concludes',
#         'commander', 'rendezvous', 'launch', 'frequently', 'dictatorship',
#         'subversive', 'fred', 'ambiguous', 'enjoy', 'illegal',
#         'undesirable', 'asset', 'epilogue', 'pose', 'terrorist',
#         'formerly', 'dangerous', 'social', 'fashion', 'occur', 'thirty',
#         'advantage', 'thought', 'narrative', 'describes', 'style',
#         'brothel', 'wade', 'president', 'america', 'era', 'united',
#         'overthrow', 'speaker', 'expose', 'intent', 'magazine', 'black',
#         'past', 'accord', 'movement', 'response', 'literally', 'discard',
#         'resistance', 'individual', 'hidden', 'news', 'evidence',
#         'concubine', 'rule', 'record', 'third', 'freedom', 'autonomy',
#         'reading', 'american', 'member', 'professor', 'describe',
#         'disappearance', 'border', 'newly', 'effort', 'relationship',
#         'legal', 'sterile', 'intercourse', 'pregnant', 'birth', 'sex',
#         'flashback', 'physical', 'discover', 'exchange', 'underground',
#         'military', 'native', 'secret', 'almost', 'arranges', 'among',
#         'conclude', 'lose', 'move', 'point', 'ecological', 'eye',
#         'initial', 'onto', 'able', 'return', 'daughter', 'refer', 'trust',
#         'person', 'must', 'far', 'large', 'several', 'potentially',
#         'agent', 'network', 'capture', 'fail', 'distant', 'information',
#         'shortly', 'learns', 'know', 'different', 'event', 'present',
#         'decline', 'men', 'period', 'believe', 'christian', 'time',
#         'ceremony', 'try', 'see', 'religion', 'another', 'activity',
#         'declare', 'case', 'quickly', 'however', 'colleague', 'character',
#         'part', 'view', 'son', 'future', 'contemplates', 'family', 'new',
#         'final', 'right', 'create', 'near', 'critic', 'story', 'first',
#         'book', 'suicide', 'enters', 'since', 'result', 'official',
#         'strip', 'sexual', 'form', 'blame', 'study', 'religious', 'get',
#         'police', 'escape', 'woman', 'meet', 'state', 'metafictional',
#         'husband', 'wife', 'also', 'along', 'novel', 'live', 'within',
#         'keep', 'suppose', 'purpose', 'follow', 'secretly', 'later', 'go',
#         'society', 'belief', 'order', 'government', 'tell', 'revolution',
#         'class', 'country', 'tale', 'give', 'explain', 'van', 'collapse',
#         'despite', 'include', 'many', 'restore', 'attack', 'one', 'memory',
#         'even', 'power', 'kill', 'begin', 'become', 'suggest', 'although',
#         'find', 'life', 'claim', 'structure', 'away', 'take', 'set', 'run',
#         'write', 'read', 'attempt', 'equal', 'drive', 'meeting', 'call',
#         'old'], dtype='<U110'),
#  ...]
