# %% [markdown]
# With our cleaned corpora ready, we can now begin the process of building our model. Next we vectorize the words by the Bag of Words approach to prepare for Term Frequency - Inverse Document Frequency (TF-IDF) analysis.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
from datetime import datetime

from nltk.tokenize import word_tokenize

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
# from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
path_to_data = "Data/bookshelf_data.csv"
text_details = pd.read_csv(path_to_data, index_col=0)
text_details.head()
# Out:
#                                           Title  \
# 0       The Extermination of the American Bison
# 1                          Deadfalls and Snares
# 2                   Artistic Anatomy of Animals
# 3                            Birds, Illustrated
# 4  On Snake-Poison: Its Action and Its Antidote
#
#                                      Author  \
# 0                       William T. Hornaday
# 1                             A. R. Harding
# 2                             Édouard Cuyer
# 3  Color Photography, Vol. 1, No. 1 Various
# 4                                A. Mueller
#
#                                     Link     ID Bookshelf  \
# 0  http://www.gutenberg.org/ebooks/17748  17748    Animal
# 1  http://www.gutenberg.org/ebooks/34110  34110    Animal
# 2  http://www.gutenberg.org/ebooks/38315  38315    Animal
# 3  http://www.gutenberg.org/ebooks/30221  30221    Animal
# 4  http://www.gutenberg.org/ebooks/32947  32947    Animal
#
#                                                 Text
# 0  [Illustration: (Inscription) Mr. Theodore Roos...
# 1  DEADFALLS AND SNARES [Frontispiece: A GOOD DEA...
# 2  +---------------------------------------------...
# 3  FROM: THE PRESIDENT OF THE NATIONAL TEACHERS' ...
# 4  [Illustration] ON SNAKE-POISON. ITS ACTION AND...

# %%
# we only need the Bookshelf column to serve as the target for our Text series, so let's extract that as y
y = text_details.Bookshelf

# now we encode our labels into integers so that our model can work with them
le = LabelEncoder()
y = le.fit_transform(y)

# %%
le.classes_
# Out:
# array(['6', 'Adventure', 'Africa', 'American', 'Anarchism', 'Animal',
#        'Animals-Domestic', 'Animals-Wild', 'Animals-Wild-Birds',
#        'Animals-Wild-Insects', 'Animals-Wild-Mammals',
#        'Animals-Wild-Reptiles', 'Animals-Wild-Trapping', 'Anthropology',
#        'Archaeology', 'Architecture', 'Argentina', 'Art', 'Astronomy',
#        'Atheism', 'Australia', "Bahá'í", 'Bibliomania', 'Biographies',
#        'Biology', 'Boer', 'Botany', 'British', 'Buddhism', 'Bulgaria',
#        'CIA', 'Camping', 'Canada', 'Canon', 'Chemistry', "Child's",
#        "Children's", 'Christianity', 'Christmas', 'Classical',
#        'Cookbooks', 'Crafts', 'Crime', 'Current', 'Czech', 'Detective',
#        'Ecology', 'Education', 'Egypt', 'Engineering', 'English',
#        'Erotic', 'FR', 'Fantasy', 'Folklore', 'France', 'General',
#        'Geology', 'German', 'Germany', 'Gothic', 'Greece', 'Harvard',
#        'Hinduism', 'Historical', 'Horror', 'Humor', 'IT', 'India',
#        'Islam', 'Italy', 'Journal', 'Judaism', 'Language', 'Latter',
#        'Manufacturing', 'Maps', 'Mathematics', 'Microbiology',
#        'Microscopy', 'Music', 'Mycology', 'Mystery', 'Mythology',
#        'Natural', 'New', 'Norway', 'Noteworthy', 'Opera', 'Paganism',
#        'Philosophy', 'Physics', 'Physiology', 'Precursors', 'Psychology',
#        'Racism', 'Reference', 'Romantic', 'School', 'Science',
#        'Scientific', 'Slavery', 'Sociology', 'South', 'Spanish',
#        'Suffrage', 'Technology', 'The', 'Transportation', 'Travel', 'US',
#        'United', 'Western', 'Witchcraft', "Women's", 'Woodwork', 'World',
#        'Zoology'], dtype=object)

# %%
path_to_data = "Data/cleaned_texts.csv"
texts = pd.read_csv(path_to_data, index_col=0, squeeze=True)
texts.head()
# Out:
# 0    illustration inscription mr theodore roosevelt...
# 1    deadfalls snare frontispiece good deadfall dea...
# 2    transcriber note transcription use etext texts...
# 3    president national teacher association state n...
# 4    illustration snakepoison action antidote muell...
# Name: 0, dtype: object

# %%
len(texts)
# Out:
# 2355

# %%
tokenized_texts = texts.apply(word_tokenize)
print(len(tokenized_texts))
print(tokenized_texts[0])

# tokenized_texts will also serve as our X, so let's assign that now
X = tokenized_texts
# Out:
# 2355
# ['illustration', 'inscription', 'mr', 'theodore', 'roosevelt', 'author', 'hunt', 'trip', 'ranchman', 'compliment', 'author', 'wt', 'hornaday', 'smithsonian', 'institution', 'united', 'state', 'national', 'museum', 'extermination', 'american', 'bison', 'william', 'hornaday', 'superintendent', 'national', 'zoological', 'park', 'report', 'national', 'museum', '188687', 'page', '369548', 'plate', 'ixxii', 'washington', 'government', 'printing', 'office', '1889', 'illustration', 'group', 'american', 'bison', 'national', 'museum', 'collect', 'mount', 'w', 'hornaday', 'content', 'prefatory', 'note', 'part', 'ithe', 'life', 'history', 'bison', 'discovery', 'specie', 'ii', 'geographical', 'distribution', 'iii', 'abundance', 'iv', 'character', 'specie', '1', 'buffalo', 'rank', 'amongst', 'ruminant', '2', 'change', 'form', 'captivity', '3', 'mount', 'specimen', 'museum', '4', 'calf', '5', 'yearling', '6', 'spike', 'bull', '7', 'adult', 'bull', '8', 'cow', 'third', 'year', '9', 'adult', 'cow', '10', 'wood', 'mountain', 'buffalo', '11', 'shed', 'winter', 'pelage', 'v', 'habit', 'buffalo', 'vi', 'food', 'buffalo', 'vii', 'mental', 'capacity', 'disposition', 'buffalo', 'viii', 'value', 'mankind', 'ix', 'economic', 'value', 'bison', 'western', 'cattlegrowers', '1', 'bison', 'captivity', 'domestication', '2', 'need', 'improvement', 'range', 'cattle', '3', 'character', 'buffalodomestic', 'hybrid', '4', 'bison', 'beast', 'burden', '5', 'list', 'bison', 'herd', 'individual', 'captivity', 'part', 'iithe', 'extermination', 'cause', 'extermination', 'ii', 'method', 'slaughter', '1', 'still', 'hunt', '2', 'chase', 'horseback', '3', 'impound', '4', 'surround', '5', 'decoy', 'drive', '6', 'hunt', 'snowshoe', 'iii', 'progress', 'extermination', 'period', 'desultory', 'destruction', 'b', 'period', 'systematic', 'slaughter', '1', 'red', 'river', 'halfbreeds', '2', 'country', 'sioux', '3', 'western', 'railway', 'part', 'extermination', 'buffalo', '4', 'division', 'universal', 'herd', '5', 'destruction', 'southern', 'herd', '6', 'statistic', 'slaughter', '7', 'destruction', 'northern', 'herd', 'iv', 'legislation', 'prevent', 'useless', 'slaughter', 'v', 'completeness', 'wild', 'buffalos', 'extirpation', 'vi', 'effect', 'disappearance', 'bison', 'vii', 'preservation', 'specie', 'absolute', 'extinction', 'part', 'iiithe', 'smithsonian', 'expedition', 'specimen', 'exploration', 'specimen', 'ii', 'hunt', 'iii', 'mount', 'group', 'national', 'museum', 'index', 'list', 'illustration', 'group', 'buffalo', 'national', 'museum', 'head', 'bull', 'buffalo', 'slaughter', 'buffalo', 'kansa', 'pacific', 'railroad', 'buffalo', 'cow', 'calf', 'yearling', 'spike', 'bull', 'bull', 'buffalo', 'bull', 'buffalo', 'rear', 'view', 'development', 'buffalo', 'horn', 'dead', 'bull', 'buffalo', 'skinner', 'work', 'five', 'minute', 'work', 'scene', 'northern', 'buffalo', 'range', 'halfbreed', 'calf', 'halfbreed', 'buffalo', 'domestic', 'cow', 'young', 'halfbreed', 'bull', 'stillhunt', 'chase', 'horseback', 'cree', 'indian', 'impound', 'buffalo', 'surround', 'indians', 'snowshoe', 'hunt', 'buffalo', 'million', 'go', 'trophy', 'hunt', 'map', 'sketch', 'map', 'hunt', 'buffalo', 'map', 'illustrate', 'extermination', 'american', 'bison', 'prefatory', 'note', 'hop', 'follow', 'historical', 'account', 'discovery', 'partial', 'utilization', 'almost', 'complete', 'extermination', 'great', 'american', 'bison', 'may', 'serve', 'cause', 'public', 'fully', 'realize', 'folly', 'allow', 'valuable', 'interesting', 'american', 'mammal', 'wantonly', 'destroy', 'manner', 'wild', 'buffalo', 'practically', 'go', 'forever', 'year', 'whiten', 'bone', 'last', 'bleaching', 'skeleton', 'shall', 'pick', 'ship', 'east', 'commercial', 'us', 'nothing', 'remain', 'save', 'old', 'wellworn', 'trail', 'along', 'watercourse', 'museum', 'specimens', 'regret', 'fate', 'untimely', 'end', 'fails', 'even', 'point', 'moral', 'shall', 'benefit', 'survive', 'specie', 'mammal', 'slaughter', 'like', 'manner', 'sad', 'indeed', 'a ...

# %%
# count vectorization function
def count_vectorize(tokenized_text):
    word_counts = {word:0 for word in sorted(set(tokenized_text))}
    
    for word in tokenized_text:
        word_counts[word] += 1
        
    return word_counts

# %%
# %%timeit
# testing our count function
count_vectorize(tokenized_texts[0])
# Out:
# {'0': 2,
#  '1': 57,
#  '10': 39,
#  '100': 16,
#  '1000': 6,
#  '10000': 3,
#  '100000': 3,
#  '101105': 1,
#  '101110': 2,
#  '1012': 2,
#  '1017600': 1,
#  '104': 1,
#  '104105': 1,
#  '105': 1,
#  '1062750': 1,
#  '107': 4,
#  '10793350': 1,
#  '108': 2,
#  '1089000': 1,
#  '1090': 1,
#  '1091': 1,
#  '10d': 1,
#  '10gallon': 1,
#  '10mile': 1,
#  '10th': 1,
#  '11': 12,
#  '110': 3,
#  '110420': 1,
#  '111': 1,
#  '1112': 2,
#  '112': 8,
#  '1135300': 2,
#  '114': 2,
#  '114000': 1,
#  '115': 3,
#  '116': 1,
#  '1160': 1,
#  '117': 1,
#  '118950': 1,
#  '119': 1,
#  '12': 22,
#  '120': 6,
#  '1200': 4,
#  '12000': 1,
#  '12000000': 1,
#  '121': 2,
#  '1210': 4,
#  '1213': 2,
#  '1217': 1,
#  '122': 1,
#  '1222': 1,
#  '1233070': 1,
#  '12371241': 1,
#  '124': 1,
#  '1240': 1,
#  '1246': 1,
#  '125': 3,
#  '126867': 1,
#  '127': 1,
#  '1280': 1,
#  '129': 1,
#  '129130': 1,
#  '12inch': 1,
#  '12mile': 1,
#  '12th': 1,
#  '13': 11,
#  '130000': 1,
#  '132': 2,
#  '132057': 1,
#  '134': 2,
#  '135': 1,
#  '1378359': 1,
#  '139144': 1,
#  '13th': 1,
#  '14': 9,
#  '1400': 2,
#  '14000': 1,
#  '144': 1,
#  '144147': 1,
#  '14520': 1,
#  '1460': 1,
#  '146250': 1,
#  '147': 1,
#  '1491489': 1,
#  '14oct': 2,
#  '15': 21,
#  '150': 6,
#  '1500': 1,
#  '150000': 1,
#  '150600': 1,
#  '1508658': 1,
#  '1516': 1,
#  '151800': 1,
#  '1521': 1,
#  '1530': 2,
#  '153941': 1,
#  '1542': 2,
#  '15464': 1,
#  '155': 2,
#  '15503': 1,
#  '15600': 1,
#  '15685': 1,
#  '15686': 1,
#  '15694': 1,
#  '157': 1,
#  '15703': 1,
#  '15767': 1,
#  '1584': 1,
#  '158583': 1,
#  '15th': 2,
#  '16': 9,
#  '1600': 3,
#  '16000': 1,
#  '1602': 1,
#  '1612': 2,
#  '1613': 1,
#  '1617600': 1,
#  '1620': 1,
#  '1624': 1,
#  '1625': 1,
#  '163': 1,
#  '1637': 2,
#  '165': 1,
#  '165107': 1,
#  '165721': 2,
#  '166': 2,
#  '1679': 1,
#  '1685': 1,
#  '1687': 1,
#  '1688': 1,
#  '1689': 1,
#  '1697': 1,
#  '1698': 2,
#  '1699': 1,
#  '17': 3,
#  '1700': 2,
#  '1701': 2,
#  '1719': 1,
#  '172': 1,
#  '1720': 1,
#  '1722': 1,
#  '1724': 1,
#  '1727': 1,
#  '1728': 1,
#  '1729': 2,
#  '1730': 1,
#  '1733': 2,
#  '1736': 1,
#  '1737': 1,
#  '17449': 1,
#  '174525': 1,
#  '1750': 2,
#  '1756': 1,
#  '176200': 1,
#  '1765': 1,
#  '1770': 1,
#  '1771': 1,
#  '1776': 3,
#  '178': 1,
#  '1780481': 1,
#  '1784': 1,
#  '1786': 1,
#  '17th': 1,
#  '18': 11,
#  '1800': 6,
#  '1806': 3,
#  '1808': 2,
#  '1815': 1,
#  '1820': 9,
#  '1821': 1,
#  '1823': 1,
#  '1824': 1,
#  '1825': 6,
#  '1826': 1,
#  '1828': 1,
#  '1830': 9,
#  '1832': 3,
#  '1834': 2,
#  '1835': 7,
#  '1838': 3,
#  '184': 1,
#  '1840': 15,
#  '184445': 1,
#  '1846': 1,
#  '1847': 1,
#  '1849': 3,
#  '1857': 2,
#  '1858': 2,
#  '1859': 1,
#  '1865': 2,
#  '1866': 2,
#  '1867': 5,
#  '1868': 2,
#  '1869': 5,
#  '187': 1,
#  '1870': 9,
#  '1871': 17,
#  '187172': 1,
#  '187174': 1,
#  '1872': 21,
#  '18721874': 1,
#  '1873': 11,
#  '1874': 18,
#  '1875': 7,
#  '187577': 1,
#  '1876': 19,
#  '1877': 8,
#  '187719': 1,
#  '1878': 5,
#  '1879': 5,
#  '1880': 15,
#  '188081': 1,
#  '188082': 1,
#  '188084the': 1,
#  '188086': 1,
#  '1881': 17,
#  '188182': 2,
#  '1882': 22,
#  '188283': 3,
#  '1883': 18,
#  '1884': 9,
#  '188485': 1,
#  '1885': 8,
#  '1886': 29,
#  '188687': 5,
#  '1887': 15,
#  '188788': 1,
#  '1888': 32,
#  '1889': 8,
#  '1897': 1,
#  '18oct': 1,
#  '19': 4,
#  '19000': 1,
#  '197': 1,
#  '199200': 1,
#  '1st': 6,
#  '2': 73,
#  '20': 23,
#  '200': 15,
#  '2000': 7,
#  '200000': 2,
#  '2000000': 1,
#  '2001': 1,
#  '202': 1,
#  '2026': 1,
#  '2067': 1,
#  '20th': 4,
#  '20°': 1,
#  '21': 2,
#  '2105': 1,
#  '2109': 1,
#  '212': 2,
#  '2124': 1,
#  '212550': 1,
#  '213': 1,
#  '214': 1,
#  '216': 1,
#  '216250': 1,
#  '21869': 1,
#  '22': 5,
#  '220': 1,
#  '2212': 2,
#  '225': 1,
#  '2250400': 1,
#  '228': 2,
#  '22d': 1,
#  '23': 8,
#  '231': 1,
#  '23355': 1,
#  '235': 1,
#  '24': 7,
#  '240': 2,
#  '242273': 1,
#  '245': 1,
#  '246175': 1,
#  '248': 1,
#  '249': 1,
#  '25': 24,
#  '250': 7,
#  '2500': 2,
#  '2500000': 1,
#  '251443': 3,
#  '2526': 1,
#  '253': 1,
#  '255': 1,
#  '256': 4,
#  '258850': 1,
#  '25th': 3,
#  '25°': 1,
#  '26': 5,
#  '260': 1,
#  '263': 1,
#  '265': 1,
#  '26601': 1,
#  '26th': 1,
#  '27': 3,
#  '2743100': 3,
#  '2756': 1,
#  '2767': 1,
#  '279280': 1,
#  '27th': 2,
#  '28': 5,
#  '283': 2,
#  '28613': 1,
#  '28th': 1,
#  '28°': 1,
#  '29': 2,
#  '29000': 1,
#  '29770': 1,
#  '2d': 2,
#  '3': 52,
#  '30': 15,
#  '300': 3,
#  '3000': 2,
#  '30561': 1,
#  '3098730': 1,
#  '31': 4,
#  '310000': 1,
#  '312': 2,
#  '314': 1,
#  '3158730': 2,
#  '31716': 1,
#  '31838': 1,
#  '31months': 1,
#  '31st': 1,
#  '32': 2,
#  '3226': 1,
#  '3261375': 1,
#  '33': 3,
#  '331442': 1,
#  '332': 1,
#  '33250': 1,
#  '334': 1,
#  '33739': 1,
#  '34': 5,
#  '342': 2,
#  '3477': 1,
#  '34901': 1,
#  '35': 3,
#  '350': 8,
#  '35000': 1,
#  '353': 1,
#  '35560': 1,
#  '358': 1,
#  '36': 4,
#  '360': 1,
#  '366401': 1,
#  '369548': 1,
#  '37': 1,
#  '371': 1,
#  '373': 6,
#  '374': 3,
#  '375': 6,
#  '376': 3,
#  '376383': 1,
#  '376388': 1,
#  '377': 3,
#  '378': 5,
#  '379': 8,
#  '38': 3,
#  '380': 3,
#  '381': 4,
#  '383': 6,
#  '384': 3,
#  '385': 7,
#  '385388': 1,
#  '386': 1,
#  '387': 5,
#  '387393': 2,
#  '388': 4,
#  '389': 7,
#  '38caliber': 1,
#  '39': 4,
#  '390': 1,
#  '390000': 2,
#  '391': 3,
#  '392': 2,
#  '393': 5,
#  '394': 6,
#  '395': 3,
#  '396': 6,
#  '39620': 1,
#  '396398': 1,
#  '396401': 1,
#  '396403': 1,
#  '397': 1,
#  '398': 1,
#  '3d': 3,
#  '4': 50,
#  '40': 12,
#  '400': 6,
#  '40000': 1,
#  '4000000': 1,
#  '400409': 1,
#  '401': 5,
#  '402': 2,
#  '402406': 1,
#  '403': 2,
#  '405': 5,
#  '406': 5,
#  '406436': 1,
#  '407': 4,
#  '407412': 4,
#  '408': 3,
#  '409': 3,
#  '4090': 2,
#  '41': 1,
#  '411': 5,
#  '412': 5,
#  '412414': 2,
#  '41268': 1,
#  '414': 2,
#  '415': 3,
#  '415426': 2,
#  '419': 1,
#  '42': 2,
#  '420': 7,
#  '421': 2,
#  '422': 2,
#  '42289': 2,
#  '423': 3,
#  '424': 3,
#  '424425': 1,
#  '424429': 1,
#  '425': 4,
#  '426': 3,
#  '426429': 1,
#  '426434': 1,
#  '427': 3,
#  '428': 5,
#  '4280': 1,
#  '429': 12,
#  '429430': 1,
#  '429434': 2,
#  '43': 1,
#  '430': 1,
#  '430431': 1,
#  '431': 1,
#  '432': 4,
#  '433': 6,
#  '434': 3,
#  '434451': 2,
#  '435': 4,
#  '436': 6,
#  '437': 2,
#  '439440': 1,
#  '44': 3,
#  '44140': 1,
#  '441415': 1,
#  '441445': 1,
#  '442': 3,
#  '443': 2,
#  '443587': 1,
#  '444': 2,
#  '445': 5,
#  '446': 2,
#  '447': 1,
#  '448': 2,
#  '449': 3,
#  '44°': 1,
#  '45': 3,
#  '450': 2,
#  '4500': 1,
#  '450pound': 1,
#  '451': 3,
#  '45120': 2,
#  '451458': 4,
#  '452': 3,
#  '452458': 2,
#  '453': 3,
#  '454': 2,
#  '454456': 1,
#  '454457': 1,
#  '456': 1,
#  '457': 1,
#  '4570': 1,
#  '457013140': 1,
#  '458': 4,
#  '458461': 1,
#  '458464': 2,
#  '459453': 2,
#  '46': 2,
#  '460': 3,
#  '461': 4,
#  '462': 4,
#  '463': 5,
#  '465': 2,
#  '465510': 1,
#  '466': 1,
#  '467': 2,
#  '47': 2,
#  '470': 8,
#  '470478': 1,
#  '471': 1,
#  '472': 1,
#  '474': 6,
#  '475': 1,
#  '476': 1,
#  '477': 3,
#  '47770': 1,
#  '478': 8,
#  '48': 3,
#  '480': 5,
#  '480000': 1,
#  '481': 1,
#  '483': 8,
#  '484': 7,
#  '485': 2,
#  '486': 1,
#  '486513': 2,
#  '487': 1,
#  '488': 5,
#  '489': 6,
#  '48th': 1,
#  '49': 3,
#  '490': 3,
#  '490493': 1,
#  '491': 3,
#  '492': 2,
#  '492502': 2,
#  '493': 2,
#  '494': 1,
#  '495': 1,
#  '496': 2,
#  '496498': 1,
#  '497': 1,
#  '497163': 1,
#  '498': 3,
#  '498502': 2,
#  '499': 1,
#  '4to': 1,
#  '5': 47,
#  '50': 27,
#  '500': 5,
#  '50000': 3,
#  '500000': 1,
#  '500pound': 1,
#  '501': 2,
#  '502': 4,
#  '502513': 3,
#  '502886': 1,
#  '503': 2,
#  '504': 5,
#  '505': 8,
#  '505507': 1,
#  '506': 4,
#  '507': 4,
#  '508': 2,
#  '509': 5,
#  '51': 4,
#  '510': 3,
#  '511': 3,
#  '512': 9,
#  '513': 2,
#  '513521': 1,
#  '514': 5,
#  '515': 2,
#  '516': 7,
#  '517': 6,
#  '518': 3,
#  '519': 2,
#  '52': 1,
#  '520': 2,
#  '521': 3,
#  '521525': 2,
#  '522': 8,
#  '523': 7,
#  '523524': 2,
#  '524': 4,
#  '525': 1,
#  '5254': 1,
#  '525527': 1,
#  '526': 5,
#  '527': 5,
#  '528': 4,
#  '529': 2,
#  '529546': 3,
#  '53': 2,
#  '530': 8,
#  '530545': 1,
#  '531': 7,
#  '532': 4,
#  '533': 1,
#  '534': 10,
#  '535': 6,
#  '536': 3,
#  '536542': 1,
#  '537': 3,
#  '538': 7,
#  '539': 3,
#  '54': 1,
#  '540': 5,
#  '541': 4,
#  '542': 5,
#  '543': 2,
#  '544': 4,
#  '545': 8,
#  '546': 2,
#  '546548': 6,
#  '547': 1,
#  '54758': 2,
#  '55': 3,
#  '550': 2,
#  '556': 2,
#  '56': 1,
#  '57': 4,
#  '57°': 1,
#  '58': 2,
#  '586': 1,
#  '58th': 1,
#  '59': 2,
#  '594750': 1,
#  '5th': 1,
#  '6': 45,
#  '60': 10,
#  '600': 4,
#  '6000': 1,
#  '603': 1,
#  '61': 1,
#  '610': 2,
#  '612': 2,
#  '62': 1,
#  '620': 3,
#  '624': 1,
#  '63': 1,
#  '632800': 1,
#  '634': 1,
#  '635': 1,
#  '64': 1,
#  '65': 5,
#  '650': 1,
#  '6501630': 1,
#  '652000': 1,
#  '652275': 1,
#  '655': 2,
#  '66': 2,
#  '668': 1,
#  '6690': 1,
#  '67': 3,
#  '67190': 1,
#  '68': 1,
#  '680': 2,
#  '69': 2,
#  '69033215220': 1,
#  '6914950': 2,
#  '6972': 1,
#  '6d': 2,
#  '6nov': 1,
#  '6th': 2,
#  '7': 25,
#  '70': 5,
#  '700': 2,
#  '7000': 2,
#  '71': 2,
#  '712': 2,
#  '72': 2,
#  '72001': 1,
#  '73': 2,
#  '731250': 1,
#  '74': 2,
#  '75': 11,
#  '750': 5,
#  '754329': 2,
#  '76': 2,
#  '77': 3,
#  '773': 1,
#  '78': 3,
#  '78°': 1,
#  '79': 3,
#  '8': 27,
#  '80': 2,
#  '8000': 3,
#  '812': 5,
#  '8160': 1,
#  '81°': 1,
#  '820': 2,
#  '83': 2,
#  '84578': 1,
#  '85': 1,
#  '850': 1,
#  '856': 1,
#  '872625': 1,
#  '8891': 1,
#  '89030': 1,
#  '895': 2,
#  '8th': 1,
#  '9': 9,
#  '90': 2,
#  '900': 1,
#  '900000': 1,
#  '912': 1,
#  '918906': 1,
#  '921': 2,
#  '923070': 1,
#  '924790': 1,
#  '93': 1,
#  '9353': 1,
#  '94': 1,
#  '97': 1,
#  '970': 2,
#  '978': 1,
#  '978412': 1,
#  '97°': 1,
#  '9847': 1,
#  '994326': 1,
#  '998': 1,
#  'abandon': 14,
#  'abate': 1,
#  'abbeville': 1,
#  'abdomen': 1,
#  'abide': 1,
#  'ability': 1,
#  'able': 17,
#  'abode': 1,
#  'abound': 1,
#  'aboundeth': 1,
#  'aboveregular': 1,
#  'abreast': 2,
#  'abruptly': 4,
#  'abruptness': 1,
#  'absence': 11,
#  'absent': 3,
#  'absolute': 5,
#  'absolutely': 15,
#  'absorb': 3,
#  'absurd': 1,
#  'abundance': 19,
#  'abundant': 18,
#  'abundantly': 3,
#  'accept': 4,
#  'access': 1,
#  'accessible': 4,
#  'accessory': 4,
#  'accident': 12,
#  'accidental': 1,
#  'acclamation': 1,
#  'accommodate': 1,
#  'accompany': 19,
#  'accomplish': 16,
#  'accomplished': 4,
#  'accomplishment': 3,
#  'accord': 21,
#  'accordingly': 5,
#  'account': 35,
#  'accountable': 1,
#  'accumulate': 1,
#  'accuracy': 2,
#  'accurate': 4,
#  'accurately': 1,
#  'accusation': 1,
#  'accuse': 2,
#  'accustom': 2,
#  'acknowledge': 5,
#  'acquaint': 3,
#  'acquaintance': 3,
#  'acquire': 2,
#  'acquires': 1,
#  'acquisition': 1,
#  'acre': 7,
#  'across': 32,
#  'act': 19,
#  'action': 4,
#  'active': 6,
#  'actively': 1,
#  'activity': 2,
#  'actual': 16,
#  'actually': 28,
#  'actuated': 1,
#  'adapt': 3,
#  'add': 20,
#  'added': 1,
#  'adder': 1,
#  'addition': 8,
#  'additional': 4,
#  'address': 4,
#  'adduce': 1,
#  'adhere': 3,
#  'adherent': 1,
#  'adjacent': 2,
#  'adjoin': 2,
#  'adjournment': 1,
#  'adjust': 1,
#  'adjutant': 1,
#  'admirable': 3,
#  'admiration': 1,
#  'admit': 6,
#  'adopt': 1,
#  'adorn': 1,
#  'adult': 50,
#  'advance': 19,
#  'advanced': 1,
#  'advantage': 4,
#  'advent': 1,
#  'adversary': 1,
#  'adversely': 1,
#  'advertisement': 1,
#  'advice': 1,
#  'advisable': 1,
#  'advise': 1,
#  'affair': 4,
#  'affect': 1,
#  'affection': 3,
#  'affectionately': 1,
#  'affectionwhile': 1,
#  'affidavit': 1,
#  'afford': 11,
#  'afforded': 1,
#  'affords': 7,
#  'affright': 3,
#  'affrighted': 1,
#  'affront': 1,
#  'aforesaid': 1,
#  'afraid': 2,
#  'africa': 2,
#  'african': 4,
#  'afternoon': 5,
#  'afterward': 6,
#  'afterwards': 3,
#  'age': 30,
#  'agency': 7,
#  'agent': 2,
#  'agglomeration': 1,
#  'aggregate': 2,
#  'aggressive': 1,
#  'agility': 2,
#  'ago': 16,
#  'agree': 6,
#  'agreeable': 3,
#  'agriculture': 2,
#  'agropyrum': 3,
#  'ahead': 3,
#  'aid': 4,
#  'aim': 2,
#  'aimless': 1,
#  'aimlessly': 1,
#  'air': 9,
#  'akin': 1,
#  'ala': 2,
#  'alabama': 5,
#  'alabamahaving': 1,
#  'alarm': 14,
#  'alarmed': 1,
#  'alarming': 1,
#  'alaska': 3,
#  'albert': 1,
#  'albinism': 3,
#  'albinismcases': 1,
#  'albino': 2,
#  'alert': 1,
#  'aleuts': 1,
#  'alexander': 3,
#  'alight': 1,
#  'alike': 2,
#  'alive': 18,
#  'alkali': 5,
#  'alkaline': 1,
#  'allard': 2,
#  'alleghanies': 1,
#  'alleghany': 2,
#  'allen': 27,
#  'allens': 2,
#  'allied': 1,
#  'allimportant': 1,
#  'allow': 21,
#  'allowance': 1,
#  'allude': 2,
#  'allusion': 3,
#  'alluvial': 1,
#  'almost': 86,
#  'alone': 20,
#  'alonew': 1,
#  'along': 53,
#  'alongside': 8,
#  'aloud': 2,
#  'already': 38,
#  'also': 99,
#  'altamaha': 1,
#  'alter': 1,
#  'alternate': 1,
#  'alters': 1,
#  'although': 54,
#  'altitude': 2,
#  'altogether': 4,
#  'alvar': 2,
#  'always': 65,
#  'amalgamate': 1,
#  'amaze': 1,
#  'amazement': 1,
#  'amazing': 1,
#  'amend': 1,
#  'amendment': 9,
#  'america': 19,
#  'american': 96,
#  'americanus': 20,
#  'amidst': 4,
#  'ammunition': 8,
#  'among': 11,
#  'amongst': 19,
#  'amount': 24,
#  'ample': 3,
#  'amply': 1,
#  'amuse': 1,
#  'amusement': 1,
#  'anacostian': 1,
#  'anahuac': 1,
#  'analyze': 1,
#  'anatomy': 2,
#  'anchor': 1,
#  'ancient': 1,
#  'andrew': 3,
#  'andrews': 3,
#  'andropogon': 4,
#  'andslaughtered': 1,
#  'angle': 5,
#  'angler': 1,
#  'animal': 220,
#  'animate': 1,
#  'annals': 1,
#  'annexed': 1,
#  'annihilate': 4,
#  'annihilated': 1,
#  'annihilation': 5,
#  'announce': 1,
#  'annoy': 1,
#  'annoyance': 2,
#  'annual': 17,
#  'annually': 18,
#  'annuity': 3,
#  'annum': 2,
#  'another': 53,
#  'answer': 2,
#  'antedate': 1,
#  'antelope': 17,
#  'anterior': 1,
#  'antler': 1,
#  'anxiety': 3,
#  'anxious': 1,
#  'anything': 9,
#  'anywhere': 11,
#  'apache': 1,
#  'apart': 3,
#  'apiece': 2,
#  'apologize': 1,
#  'appal': 1,
#  'apparel': 1,
#  'apparent': 8,
#  'apparently': 16,
#  'appeal': 1,
#  'appear': 32,
#  'appearance': 26,
#  'appendix': 2,
#  'appetite': 1,
#  'apple': 1,
#  'apply': 1,
#  'appoint': 3,
#  'appreciable': 1,
#  'appreciate': 7,
#  'apprehension': 1,
#  'approach': 19,
#  'appropriate': 1,
#  'approve': 2,
#  'approximate': 2,
#  'approximation': 1,
#  'april': 10,
#  'apt': 2,
#  'arapahoe': 4,
#  'arc': 1,
#  'arch': 1,
#  'ardent': 2,
#  'area': 9,
#  'argoll': 6,
#  'argoll3': 1,
#  'argonauts': 1,
#  'argument': 1,
#  'arickaree': 1,
#  'arid': 1,
#  'arise': 2,
#  'arises': 1,
#  'aristida': 3,
#  'arizona': 4,
#  'arkansas': 13,
#  'arm': 9,
#  'armament': 1,
#  'armed': 1,
#  'armslength': 1,
#  'army': 19,
#  'arose': 1,
#  'around': 55,
#  'arrange': 5,
#  'arranged': 1,
#  'arrangement': 1,
#  'arrest': 1,
#  'arrival': 8,
#  'arrive': 16,
#  'arrived': 2,
#  'arrives': 1,
#  'arrow': 7,
#  'arrows': 2,
#  'art': 1,
#  'arthur': 1,
#  ...}

# %% [markdown]
# The first iteration revealed that we left numbers in the text corpora, so we can safely drop those. However, that will be for a later version due to the current time constraints.
#
# It otherwise appears to be working as expected, so let's bag some words!

# %%
first_bag = count_vectorize(tokenized_texts[0])
bagged_text = pd.Series(data=[first_bag])
increment = 10
start = datetime.now()
for i in range(1, len(tokenized_texts), increment):
    print("Processing {}-{} out of {}...".format(i, i + increment, len(tokenized_texts)))
    bag_set = tokenized_texts[i:i+increment].apply(count_vectorize)
    bagged_text = pd.concat([bagged_text, bag_set])
    print("Elapsed time: {} seconds.".format((datetime.now() - start).total_seconds()))
    print("Last {}:\n{}".format(increment, bagged_text[-increment:]))
print("Complete.")
# Out:
# Processing 1-11 out of 2355...
# Elapsed time: 0.149318 seconds.
# Last 10:
# 1     {'0': 3, '020': 1, '075': 1, '1': 68, '10': 13...
# 2     {'0': 5, '0c': 8, '0i': 2, '0·22': 1, '0·30': ...
# 3     {'1': 2, '10th': 1, '12×18': 1, '15': 2, '150'...
# 4     {'0': 1, '002': 1, '004': 1, '007013': 1, '1':...
# 5     {'0': 1, '1': 24, '10': 14, '100': 5, '11': 5,...
# 6     {'1': 104, '10': 64, '100': 4, '101': 2, '1012...
# 7     {'0': 2, '1': 30, '10': 8, '100': 2, '1000': 1...
# 8     {'1': 191, '10': 48, '1000': 1, '101': 2, '103...
# 9     {'0': 1, '01': 3, '0112': 1, '02': 1, '03': 1,...
# 10    {'00': 27, '07': 2, '074': 1, '08': 1, '1': 18...
# dtype: object
# Processing 11-21 out of 2355...
# Elapsed time: 7.004172 seconds.
# Last 10:
# 11    {'1': 1, '10': 2, '100': 3, '101': 3, '102': 2...
# 12    {'1': 35, '10': 21, '100': 2, '101': 3, '102':...
# 13    {'0': 2, '1': 15, '10': 22, '100': 1, '1000': ...
# 14    {'1': 32, '10': 17, '100': 1, '100the': 1, '10...
# 15    {'003': 1, '004': 1, '005': 1, '007': 1, '008'...
# 16    {'1': 9, '10': 14, '100': 11, '1000': 5, '1000...
# 17    {'1': 2, '10': 3, '100': 6, '1000': 1, '101': ...
# 18    {'0': 4, '057': 2, '0641249': 1, '1': 188, '10...
# 19    {'0': 15, '1': 619, '10': 25, '100': 14, '1000...
# 20    {'0': 11, '01': 1, '012': 3, '017': 1, '021': ...
# dtype: object
# Processing 21-31 out of 2355...
# Elapsed time: 25.314882 seconds.
# Last 10:
# 21    {'1': 31, '10': 3, '100': 2, '101': 3, '101105...
# 22    {'1': 5, '10': 13, '100': 8, '1000': 1, '10000...
# 23    {'0': 7, '1': 27, '100': 1, '106': 1, '11': 4,...
# 24    {'1': 16, '10': 10, '100': 5, '101': 6, '1012'...
# 25    {'1897': 1, 'aaah': 1, 'aback': 1, 'abandonmen...
# 26    {'abide': 2, 'ability': 1, 'abode': 2, 'abroad...
# 27    {'1': 16, '10': 55, '100': 15, '1016ths': 1, '...
# 28    {'1': 5, '1000': 2, '1100': 7, '1210': 1, '125...
# 29    {'1': 1, '101': 1, '106': 1, '111': 1, '115': ...
# 30    {'16': 2, '1702': 1, '1916': 1, 'abandon': 1, ...
# dtype: object
# Processing 31-41 out of 2355...
# Elapsed time: 25.418721 seconds.
# Last 10:
# 31    {'1': 3, '10': 1, '100l': 1, '107': 1, '107bus...
# 32    {'1879': 2, '28': 1, '33': 1, '38': 1, '40': 1...
# 33    {'1': 12, '10': 4, '100': 2, '101': 3, '102': ...
# 34    {'1': 9, '10': 17, '100': 3, '1000': 2, '105':...
# 35    {'0': 3, '00': 2, '001': 1, '002': 3, '003': 4...
# 36    {'1': 1, '13': 2, '20': 1, '27': 1, '30': 1, '...
# 37    {'0': 65, '02': 1, '03': 1, '06': 1, '0·3': 1,...
# 38    {'1': 18, '10': 42, '100': 12, '100°': 1, '101...
# 39    {'1903': 1, '1904': 1, '1913': 2, 'abandon': 1...
# 40    {'10': 1, '101': 1, '106': 1, '109': 1, '11': ...
# dtype: object
# Processing 41-51 out of 2355...
# Elapsed time: 25.561554 seconds.
# Last 10:
# 41    {'100': 1, '106': 1, '108': 1, '11': 1, '111':...
# 42    {'0': 3, '0vis': 1, '0·0': 2, '0·01': 1, '0·02...
# 43    {'100': 9, '11': 1, '125': 3, '13': 1, '15': 1...
# 44    {'1': 2, '10': 2, '100': 5, '1045': 1, '12': 2...
# 45    {'1': 3, '10': 2, '100': 1, '103': 2, '104': 2...
# 46    {'10': 1, '11': 1, '119': 1, '12': 3, '127': 1...
# 47    {'1': 1, '1900': 1, '1stthe': 1, '1the': 1, '2...
# 48    {'1': 62, '10': 4, '100': 2, '101': 3, '102': ...
# 49    {'040': 1, '0°': 1, '1': 44, '10': 24, '100': ...
# 50    {'059': 1, '1': 3, '10': 2, '11': 3, '112': 1,...
# dtype: object
# Processing 51-61 out of 2355...
# Elapsed time: 25.660156 seconds.
# Last 10:
# 54    {'1': 8, '10': 1, '100': 3, '101': 1, '101103'...
# 55    {'1': 1, '10': 1, '1000': 1, '112': 1, '113': ...
# 56    {'1': 5, '103': 2, '109': 3, '128': 1, '155': ...
# 59    {'1': 1, '101': 1, '117': 1, '121': 1, '135': ...
# 61    {'10': 1, '100': 1, '101': 2, '102': 1, '104':...
# 62    {'1': 4, '10': 5, '100': 3, '101105': 1, '102'...
# 63    {'1': 1, '1276according': 1, '1504': 1, '1709'...
# 64    {'1': 27, '10': 20, '105': 1, '11': 11, '110':...
# 65    {'1': 1, '100': 1, '101': 3, '103': 2, '104': ...
# 66    {'0': 23, '00': 1, '000': 1, '1': 24, '10': 6,...
# dtype: object
# Processing 61-71 out of 2355...
# Elapsed time: 25.78904 seconds.
# Last 10:
# 67    {'103': 1, '11': 1, '116': 1, '139': 1, '158':...
# 68    {'1900': 2, 'ability': 1, 'abode': 1, 'abristl...
# 69    {'1': 11, '10': 6, '11': 8, '12': 7, '12mo': 2...
# 70    {'1': 22, '10': 3, '100': 1, '11': 2, '11150':...
# 71    {'1': 1, '10': 6, '100': 4, '102': 1, '104': 1...
# 72    {'1000': 1, '126': 1, '144': 1, '150': 1, '15t...
# 73    {'0': 1, '1': 25, '10': 2, '100': 2, '1000': 1...
# 74    {'1': 43, '10': 8, '100': 2, '10000': 1, '1001...
# 79    {'0125': 6, '025': 13, '0375': 17, '05': 23, '...
# 81    {'1': 4, '10': 2, '102': 5, '10497i': 1, '105'...
# dtype: object
# Processing 71-81 out of 2355...
# Elapsed time: 25.88144 seconds.
# Last 10:
# 84    {'1': 5, '1000': 2, '10000': 1, '100000': 1, '...
# 85    {'1': 44, '10': 11, '100': 8, '1000': 12, '102...
# 86    {'26': 1, 'a1': 1, 'abc': 1, 'alone': 1, 'andr...
# 87    {'0': 1, '1': 3, '100000l': 2, '120000l': 1, '...
# 88    {'0': 8, '1': 54, '10': 2, '100': 2, '101': 1,...
# 89    {'1': 2, '10': 2, '109': 1, '11': 2, '114': 1,...
# 90    {'1': 4, '10': 6, '100': 4, '1000': 2, '10000'...
# 91    {'1': 2, '10': 1, '12': 1, '136': 1, '15': 1, ...
# 92    {'1': 3, '10': 4, '100': 2, '107': 1, '11': 3,...
# 93    {'127': 1, '12gauge': 1, '14': 1, '140': 1, '1...
# dtype: object
# Processing 81-91 out of 2355...
# Elapsed time: 25.984349 seconds.
# Last 10:
# 94     {'400': 1, 'abhorred': 1, 'abide': 1, 'ability...
# 95     {'1': 2, '100': 2, '100000': 1, '1200': 1, '12...
# 96     {'0803241127': 1, '0803291124': 1, '1': 3, '10...
# 97     {'10000': 1, '12': 1, '1828': 1, '1836': 1, '1...
# 98     {'200th': 1, 'abhorrence': 1, 'abide': 1, 'abi...
# 99     {'1': 6, '10': 8, '100': 5, '1000': 2, '101': ...
# 102    {'024010004428': 1, '12': 1, '1849': 1, '18884...
# 103    {'18823': 1, '1890': 1, '189192': 1, '1893': 2...
# 104    {'1': 23, '10': 26, '100': 3, '1000': 1, '1000...
# 109    {'1': 4, '10': 2, '100': 2, '1000': 1, '10000'...
# dtype: object
# Processing 91-101 out of 2355...
# Elapsed time: 26.060125 seconds.
# Last 10:
# 110    {'1': 3, '10': 3, '100': 4, '1000': 1, '10000'...
# 111    {'1': 10, '1903': 1, '1925': 1, '4': 1, 'able'...
# 112    {'1': 1, '10': 1, '105': 1, '106': 1, '109': 1...
# 113    {'10': 3, '100': 3, '101': 6, '102': 4, '103':...
# 114    {'1': 2, '10': 8, '100': 10, '1000': 4, '10000...
# 115    {'1': 92, '10': 44, '100': 7, '10000': 1, '101...
# 116    {'0': 1, '1': 45, '10': 6, '100': 16, '101': 1...
# 117    {'1': 220, '10': 42, '100': 18, '1000': 2, '10...
# 118    {'1': 6, '10000': 2, '108': 1, '12000': 1, '13...
# 119    {'1': 2, '2': 2, '3': 2, '4': 2, '5': 2, 'abee...
# dtype: object
# Processing 101-111 out of 2355...
# Elapsed time: 26.134236 seconds.
# Last 10:
# 120    {'000': 1, '05': 1, '1': 79, '10': 51, '100': ...
# 121    {'1899': 2, 'abash': 1, 'abe': 1, 'abide': 1, ...
# 122    {'1': 7, '10': 7, '100': 1, '10000': 1, '10010...
# 123    {'1': 1, '15th': 1, '1801which': 1, '1837': 1,...
# 124    {'1903': 2, 'abide': 1, 'abrasion': 1, 'abroad...
# 125    {'001': 3, '01': 1, '039': 1, '1': 60, '10': 4...
# 126    {'1': 2, '10': 1, '100': 1, '10000': 1, '101':...
# 127    {'1': 11, '10': 1, '1014': 1, '1016': 1, '102'...
# 128    {'1': 17, '1923': 1, '2': 17, '200': 1, '3': 4...
# 132    {'1': 12, '10': 9, '100': 3, '100000': 1, '101...
# dtype: object
# Processing 111-121 out of 2355...
# Elapsed time: 26.214935 seconds.
# Last 10:
# 133    {'101': 1, '107': 1, '115': 1, '116': 1, '124'...
# 134    {'0': 1, '10th': 1, '1400': 1, '15': 2, '18091...
# 135    {'1': 19, '10': 11, '100': 4, '1001': 1, '1003...
# 136    {'019': 1, '026': 1, '039': 5, '058': 1, '078'...
# 137    {'039': 2, '078': 3, '1': 11, '10': 3, '11': 2...
# 138    {'078': 1, '1': 13, '10': 6, '1014': 1, '10tra...
# 139    {'12': 1, '1908': 1, '20000000': 1, '500': 1, ...
# 140    {'1': 60, '10': 9, '100': 3, '1000': 1, '101':...
# 141    {'120': 3, '12000': 1, '120000': 1, '15': 1, '...
# 142    {'1': 3, '103': 1, '11': 1, '114': 1, '122': 1...
# dtype: object
# Processing 121-131 out of 2355...
# Elapsed time: 26.28631 seconds.
# Last 10:
# 143    {'039': 2, '078': 2, '1': 6, '10': 2, '11': 3,...
# 144    {'104': 1, '108': 1, '1861': 1, '1906': 2, '19...
# 145    {'039': 2, '1': 15, '10': 13, '109': 1, '10th'...
# 146    {'1608': 1, '16th': 1, '19': 1, '1913': 1, 'aa...
# 147    {'062': 1, '1': 13, '10': 14, '10000': 1, '10°...
# 148    {'1': 8, '10': 4, '104': 1, '104°': 2, '105': ...
# 149    {'1': 7, '10': 6, '11': 4, '12': 3, '13': 3, '...
# 157    {'1': 185, '10': 69, '100': 40, '1000': 4, '10...
# 158    {'0': 9, '003020001190': 1, '015°': 1, '02138'...
# 159    {'1897': 1, 'acknowledge': 1, 'acquire': 1, 'a...
# dtype: object
# Processing 131-141 out of 2355...
# Elapsed time: 26.336903 seconds.
# Last 10:
# 160    {'0': 42, '000': 2, '01000': 9, '02000': 1, '0...
# 162    {'1': 1, '100': 1, '101': 3, '102': 1, '10255'...
# 163    {'1': 19, '10': 10, '100': 8, '1000': 10, '101...
# 164    {'0': 1, '1': 8, '10': 7, '10pit': 1, '11': 5,...
# 165    {'1': 60, '10': 13, '100': 1, '1030': 3, '104'...
# 166    {'0': 8, '012': 1, '1': 26, '10': 9, '100': 1,...
# 167    {'00': 1, '00´': 1, '03': 1, '1': 243, '10': 1...
# 168    {'125': 7, '16mo': 7, '1896': 1, '20th': 1, 'a...
# 169    {'0': 1, '00': 2, '00120': 1, '00128': 1, '002...
# 170    {'1': 138, '10': 21, '1000': 2, '10000': 2, '1...
# dtype: object
# Processing 141-151 out of 2355...
# Elapsed time: 26.420211 seconds.
# Last 10:
# 171    {'0': 5, '07': 1, '1': 54, '10': 29, '100': 4,...
# 172    {'1': 138, '10': 21, '100': 9, '1000': 3, '100...
# 173    {'1': 11, '10': 6, '100': 5, '101': 8, '102': ...
# 174    {'127': 1, '1899': 1, '1901': 1, '21': 1, '303...
# 176    {'0': 1, '006': 1, '006028': 1, '006035': 1, '...
# 177    {'0': 1, '02´': 2, '0608': 1, '07´': 1, '087':...
# 178    {'00': 1, '01': 2, '02': 7, '03': 2, '04': 1, ...
# 179    {'0': 3, '005sigmam': 2, '0155': 1, '076': 1, ...
# 180    {'0': 3, '005': 1, '0058': 1, '0065': 1, '009'...
# 181    {'015': 1, '016': 1, '023': 1, '034': 1, '036'...
# dtype: object
# Processing 151-161 out of 2355...
# Elapsed time: 26.458667 seconds.
# Last 10:
# 182    {'0': 9, '00': 15, '01': 2, '01000': 2, '02': ...
# 183    {'03': 1, '04': 1, '05': 1, '054': 1, '054070'...
# 184    {'1': 13, '10': 5, '104215233': 1, '112': 1, '...
# 185    {'1': 106, '10': 13, '100': 2, '1013': 1, '103...
# 186    {'1': 4, '102594': 2, '11': 4, '110': 1, '1143...
# 187    {'1': 14, '10': 3, '105': 1, '11': 4, '1119200...
# 188    {'028': 1, '030036': 1, '030037': 1, '031033':...
# 189    {'1': 5, '10': 2, '100th': 1, '1146': 1, '12':...
# 190    {'0': 47, '0001': 6, '0018': 1, '0025006': 1, ...
# 191    {'033': 1, '055': 1, '072': 1, '079': 1, '090'...
# dtype: object
# Processing 161-171 out of 2355...
# Elapsed time: 26.50408 seconds.
# Last 10:
# 192    {'1': 8, '10': 1, '1012': 1, '11': 5, '112': 2...
# 193    {'05': 5, '08': 1, '1': 8, '10': 15, '100': 3,...
# 194    {'1': 6, '10th': 2, '11': 2, '113': 1, '11th':...
# 195    {'1': 30, '10': 13, '1000': 1, '100048': 2, '1...
# 196    {'1': 3, '110': 2, '12': 2, '122': 1, '13': 1,...
# 197    {'0003': 1, '0005': 3, '0006': 1, '0007': 2, '...
# 198    {'1': 22, '10': 2, '104': 1, '108': 1, '11': 4...
# 199    {'025': 1, '05': 6, '053': 1, '062': 2, '0625'...
# 200    {'aa': 1, 'abandonment': 1, 'abasement': 1, 'a...
# 201    {'147': 2, '157': 1, 'abashed': 1, 'abe': 22, ...
# dtype: object
# Processing 171-181 out of 2355...
# Elapsed time: 26.637418 seconds.
# Last 10:
# 202    {'1': 2, '1763': 1, '1792': 1, '1840': 1, '20t...
# 203    {'1': 2, '10': 2, '11': 2, '12': 2, '13': 2, '...
# 204    {'11th': 1, '1870': 2, '18th': 1, '1913': 1, '...
# 205    {'abandon': 1, 'abash': 1, 'abate': 1, 'abbey'...
# 206    {'1130': 1, '730': 1, 'abel': 42, 'abet': 1, '...
# 207    {'1': 1, '1000': 1, '10000': 1, '12': 3, '1200...
# 208    {'100': 2, '10000': 1, '1030': 1, '11': 2, '14...
# 209    {'49': 1, 'aaron': 3, 'aback': 2, 'abash': 1, ...
# 210    {'1030': 1, '1839': 1, '1840': 2, '1874': 1, '...
# 211    {'0': 48, '1': 12, '10': 5, '100': 3, '1000': ...
# dtype: object
# Processing 181-191 out of 2355...
# Elapsed time: 26.74265 seconds.
# Last 10:
# 212    {'10': 1, '18741958': 1, '1907': 1, '1916': 1,...
# 213    {'1': 2, '15': 1, '1851': 2, '1st': 1, '20th':...
# 214    {'10': 2, '110': 4, '17': 1, '18': 2, '19': 1,...
# 215    {'12th': 2, '1874': 1, '1896': 1, '1901': 1, '...
# 216    {'16': 7, '1874': 1, '1896': 4, '1897': 3, '18...
# 217    {'0': 1, '1': 15, '10': 13, '100': 4, '1000': ...
# 218    {'abet': 1, 'ability': 1, 'able': 7, 'ablow': ...
# 219    {'1874': 1, '1896': 1, '1901': 1, '1902': 1, '...
# 220    {'1150': 1, '16': 1, '18': 5, '1874': 1, '1896...
# 221    {'abaissement': 1, 'abaissée': 2, 'abandon': 1...
# dtype: object
# Processing 191-201 out of 2355...
# Elapsed time: 26.806749 seconds.
# Last 10:
# 222    {'1': 3, '10': 3, '10th': 1, '11': 5, '1177': ...
# 223    {'0': 33, '1': 104, '10': 22, '100': 10, '1000...
# 224    {'1911': 1, '1914': 1, 'aa': 1, 'abandon': 1, ...
# 225    {'0395069521': 1, '0395643740': 1, '10003': 1,...
# 226    {'1902': 2, 'accident': 1, 'across': 1, 'alive...
# 227    {'1844': 1, '1848': 1, 'able': 2, 'advice': 1,...
# 228    {'1922': 1, 'afraid': 1, 'age': 1, 'alive': 3,...
# 229    {'1918': 1, 'absolutely': 1, 'accustom': 1, 'a...
# 230    {'103': 1, '109': 1, '114': 1, '122': 1, '125'...
# 231    {'18155hhtm': 1, '18155hzip': 1, 'afternoon': ...
# dtype: object
# Processing 201-211 out of 2355...
# Elapsed time: 26.852819 seconds.
# Last 10:
# 232    {'akron': 2, 'angry': 3, 'another': 3, 'answer...
# 233    {'1904': 1, '1932': 1, 'able': 1, 'afternoon':...
# 234    {'0594': 1, '12': 1, '13': 1, '14': 1, '15': 1...
# 235    {'1862': 1, 'accord': 1, 'act': 1, 'alvord': 1...
# 236    {'1': 4, '10': 3, '100': 1, '101': 1, '102': 1...
# 237    {'1844': 1, '1846': 1, '1871': 1, '3–6': 1, '4...
# 238    {'1903': 1, 'also': 1, 'amongst': 1, 'answer':...
# 239    {'1': 1, '100': 1, '10014': 1, '108': 1, '109'...
# 240    {'1907': 2, 'advance': 1, 'affront': 1, 'along...
# 241    {'15284hhtm': 1, '15284hzip': 1, '1918': 1, 'a...
# dtype: object
# Processing 211-221 out of 2355...
# Elapsed time: 26.895742 seconds.
# Last 10:
# 242    {'1': 1, '10': 2, '11': 1, '12345': 1, '1916':...
# 243    {'1888': 1, 'able': 1, 'accept': 1, 'ache': 1,...
# 244    {'1': 2, '13650hhtm': 1, '13650hzip': 1, '13th...
# 245    {'1906': 1, 'ab': 2, 'abc': 1, 'aber': 13, 'ab...
# 246    {'1906': 1, '1907': 2, 'ablinkin': 1, 'abroad'...
# 247    {'10': 1, '10010': 1, '182190': 1, '1905': 2, ...
# 248    {'1': 2, '10': 1, '11': 1, '13': 1, '15': 2, '...
# 249    {'14814hhtm': 1, '14814hzip': 1, '1908': 1, 'a...
# 250    {'1': 1, '107': 1, '1129': 2, '1154': 3, '1154...
# 251    {'1': 1, '108': 1, '111': 1, '112': 1, '116': ...
# dtype: object
# Processing 221-231 out of 2355...
# Elapsed time: 26.964844 seconds.
# Last 10:
# 252    {'1': 2, '10': 2, '11': 2, '12': 2, '13': 2, '...
# 253    {'10': 1, '1000': 1, '1884': 1, '20': 1, '3': ...
# 254    {'125': 2, '15': 1, '1867': 1, '1868': 1, '365...
# 255    {'1115': 1, '1905': 2, '2500': 1, '300': 3, '3...
# 256    {'1': 1, '1114': 1, '1917': 2, '2': 1, 'abando...
# 257    {'0486452816': 1, '11501': 1, '1918': 1, '2006...
# 258    {'060': 1, '100': 2, '105': 1, '113': 1, '122'...
# 259    {'1': 9, '10': 1, '115': 1, '127': 1, '131': 1...
# 260    {'00': 1, '1': 2, '10': 2, '11': 2, '12': 2, '...
# 261    {'1': 1, '10': 13, '10000': 1, '10c': 2, '11':...
# dtype: object
# Processing 231-241 out of 2355...
# Elapsed time: 27.088609 seconds.
# Last 10:
# 262    {'0': 1, '00': 2, '1': 2, '1851': 1, '1907': 1...
# 263    {'100': 3, '1000': 6, '10000': 1, '100000': 2,...
# 264    {'10': 1, '20': 1, '3': 1, '4': 1, '50': 1, '6...
# 265    {'10': 1, '1000': 1, '10000': 1, '120': 1, '12...
# 266    {'1': 2, '1015': 1, '15th': 1, '167': 1, '1850...
# 267    {'10': 1, '11': 1, '1913': 1, '300': 3, '4': 1...
# 268    {'1': 8, '100': 1, '150': 1, '1501': 1, '1505'...
# 269    {'2lst': 1, '55': 1, 'abash': 3, 'able': 19, '...
# 270    {'1': 2, '10': 2, '11': 2, '12': 2, '13': 2, '...
# 271    {'1': 9, '10': 2, '11': 2, '12': 2, '1227': 1,...
# dtype: object
# Processing 241-251 out of 2355...
# Elapsed time: 27.408741 seconds.
# Last 10:
# 272    {'151200': 1, '180': 1, '2': 2, '2520': 1, '4'...
# 274    {'10': 1, '16th': 1, '1st': 3, '2': 2, '207': ...
# 275    {'1': 6, '10': 7, '100': 2, '1000': 2, '10000'...
# 276    {'1': 27, '10': 26, '100': 19, '1000': 18, '10...
# 277    {'1': 5, '10': 1, '100': 1, '1000': 1, '10000'...
# 278    {'0': 56, '00': 15, '00delayd': 1, '00it': 1, ...
# 279    {'10': 1, '10my': 1, '10th': 2, '12': 1, '15th...
# 280    {'1': 2, '10': 2, '10th': 4, '11': 2, '11th': ...
# 281    {'1': 101, '10': 37, '100': 4, '1000': 1, '100...
# 282    {'1413': 1, '1905': 1, '20th': 1, 'abandon': 1...
# dtype: object
# Processing 251-261 out of 2355...
# Elapsed time: 27.573065 seconds.
# Last 10:
# 283    {'10': 1, '100': 2, '101': 3, '102': 5, '103':...
# 284    {'123': 1, '14th': 1, '150': 1, '16th': 1, '17...
# 285    {'1': 18, '10': 8, '100': 2, '100dynasty': 1, ...
# 286    {'1847': 1, '7': 1, 'abolitionist': 1, 'africa...
# 287    {'1': 4, '10': 1, '100': 3, '1000': 4, '1001':...
# 288    {'1': 22, '10': 12, '100': 5, '1000': 2, '1000...
# 289    {'0': 2, '035': 3, '048': 1, '060': 3, '1': 13...
# 290    {'1': 1, '10000': 1, '10less': 1, '11': 1, '12...
# 291    {'1': 43, '10': 14, '100': 25, '101': 2, '102'...
# 292    {'1': 6, '10': 2, '1000': 1, '10th': 4, '11': ...
# dtype: object
# Processing 261-271 out of 2355...
# Elapsed time: 27.738589 seconds.
# Last 10:
# 293    {'1': 3, '10': 1, '100': 7, '1000': 4, '10000'...
# 294    {'1': 2, '125': 1, '12mo': 3, '1502': 1, '1599...
# 295    {'1': 113, '10': 10, '100': 1, '1000': 1, '100...
# 296    {'1': 32, '10': 19, '100': 15, '1001': 1, '101...
# 297    {'1': 108, '10': 95, '100': 25, '1000': 8, '10...
# 298    {'03': 1, '1': 106, '10': 96, '100': 20, '1000...
# 299    {'1812': 1, '1895': 1, 'able': 2, 'acadia': 2,...
# 300    {'1': 1, '10': 1, '100': 1, '1130': 1, '25': 4...
# 301    {'abed': 3, 'abeen': 1, 'ablution': 1, 'aboard...
# 302    {'1': 1, '10': 1, '11': 1, '114120': 1, '12': ...
# dtype: object
# Processing 271-281 out of 2355...
# Elapsed time: 27.82405 seconds.
# Last 10:
# 303    {'account': 1, 'accuse': 2, 'acorn': 2, 'acros...
# 304    {'able': 6, 'ache': 2, 'across': 22, 'actually...
# 305    {'1': 4, '10': 1, '104': 1, '11': 1, '110': 1,...
# 306    {'12': 1, '13': 1, '19': 1, '21': 1, '4': 1, '...
# 307    {'10': 1, '105': 1, '109': 1, '11': 1, '113': ...
# 308    {'able': 11, 'abraham': 2, 'absence': 1, 'abus...
# 309    {'1': 1, '106': 1, '115': 1, '12': 1, '124': 1...
# 310    {'1920': 1, 'abruptly': 2, 'absolutely': 1, 'a...
# 311    {'1921': 1, '22': 1, '71': 1, 'able': 1, 'abro...
# 312    {'185': 1, '1872': 1, 'aa': 1, 'abashed': 1, '...
# dtype: object
# Processing 281-291 out of 2355...
# Elapsed time: 27.891488 seconds.
# Last 10:
# 313    {'1': 1, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 314    {'10': 1, '109': 1, '14375hhtm': 1, '14375hzip...
# 315    {'1917': 1, 'ability': 1, 'absence': 1, 'accen...
# 316    {'1000': 1, 'abandon': 1, 'abashed': 1, 'able'...
# 317    {'1': 1, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 318    {'13': 1, '15': 1, '16': 1, '18': 1, '1860': 1...
# 319    {'1': 1, '103': 1, '11': 1, '111': 1, '120': 1...
# 320    {'abandon': 1, 'able': 13, 'aboard': 1, 'absen...
# 321    {'103': 1, '117': 1, '120': 1, '124': 1, '131'...
# 322    {'1': 1, '103': 1, '11': 1, '110': 1, '113': 1...
# dtype: object
# Processing 291-301 out of 2355...
# Elapsed time: 27.984347 seconds.
# Last 10:
# 323    {'12mo': 2, '12th': 3, '15': 1, '19': 1, '1916...
# 324    {'1817': 1, '186000000': 1, 'ability': 2, 'abl...
# 325    {'14821513': 1, '1484': 1, '1490': 1, '1801': ...
# 327    {'1': 1, '1908': 2, '2': 2, 'aback': 1, 'aband...
# 328    {'538': 1, '624': 1, 'abandon': 1, 'abbot': 12...
# 329    {'1': 5, '100': 1, '1000': 1, '101': 1, '103':...
# 330    {'0020421001': 1, '1': 6, '10': 2, '10022': 1,...
# 331    {'1': 4, '10': 5, '100': 9, '101': 9, '102': 3...
# 332    {'1': 16, '10': 7, '100': 6, '101': 6, '101afa...
# 333    {'1': 2, '10': 2, '103': 1, '11': 2, '12': 1, ...
# dtype: object
# Processing 301-311 out of 2355...
# Elapsed time: 28.058654 seconds.
# Last 10:
# 334    {'12': 1, '16': 2, '1998': 5, '20': 5, '219': ...
# 335    {'1': 6, '10': 4, '100': 1, '1000': 2, '103': ...
# 336    {'accept': 1, 'acquaint': 1, 'across': 4, 'ada...
# 337    {'1621': 1, '1905': 2, 'abandon': 3, 'abash': ...
# 338    {'1': 1, '127': 1, '130a': 2, '130b': 2, '130c...
# 339    {'1': 1, '103': 1, '107': 1, '11': 1, '112': 1...
# 340    {'17034hhtm': 1, '17034hzip': 1, '190': 1, '19...
# 341    {'1': 4, '100': 3, '1001': 1, '100a': 1, '102'...
# 342    {'1': 1, '10': 1, '1012': 1, '103': 1, '103106...
# 343    {'1': 2, '101': 1, '1574': 1, '1890': 1, '2': ...
# dtype: object
# Processing 311-321 out of 2355...
# Elapsed time: 28.148992 seconds.
# Last 10:
# 344    {'1': 4, '10': 1, '10th': 1, '11': 1, '111011'...
# 345    {'10': 10, '11': 2, '12': 39, '144': 38, '144p...
# 346    {'1': 2, '10': 1, '103': 1, '11': 1, '1914': 1...
# 347    {'1': 1, '102': 1, '104': 1, '108': 1, '120': ...
# 348    {'1284': 1, '1906': 1, '540': 1, '800': 1, 'ab...
# 349    {'1': 1, '101': 1, '131': 1, '1469': 1, '1477'...
# 350    {'1': 2, '10': 2, '11': 2, '12': 2, '13': 2, '...
# 351    {'1': 1, '10': 1, '100': 1, '13th': 1, '18th':...
# 352    {'1': 1, '1066': 1, '10th': 5, '1100': 1, '112...
# 353    {'2': 1, '3': 1, '44': 1, '6': 1, '7': 1, '9':...
# dtype: object
# Processing 321-331 out of 2355...
# Elapsed time: 28.260161 seconds.
# Last 10:
# 354    {'1': 1, '100': 2, '13': 1, '1722': 1, '183': ...
# 355    {'1': 2, '10': 2, '11': 2, '12': 2, '13': 2, '...
# 356    {'0': 1, '113340': 1, '12': 1, '124': 1, '140'...
# 358    {'1': 2, '10': 2, '11': 2, '113340': 1, '12': ...
# 359    {'1904': 1, '200': 1, '206': 1, '26th': 1, 'ab...
# 360    {'001116': 1, '001331': 1, '001517': 1, '00162...
# 361    {'able': 4, 'absent': 1, 'absurd': 2, 'accept'...
# 363    {'1': 5, '10th': 1, '14': 1, '1869': 1, '19th'...
# 364    {'1': 5, '10': 2, '103': 2, '11': 2, '12': 2, ...
# 365    {'1': 1, '2': 1, '96': 1, 'abandon': 2, 'abate...
# dtype: object
# Processing 331-341 out of 2355...
# Elapsed time: 28.335018 seconds.
# Last 10:
# 366    {'1': 2, '10': 2, '11': 2, '12': 2, '13': 2, '...
# 367    {'1902': 1, '200': 1, '27': 1, '447': 1, '448'...
# 369    {'10th': 1, '16th': 1, '1905': 1, '22nd': 1, '...
# 370    {'1': 2, '10': 2, '100': 1, '10742': 1, '11': ...
# 371    {'1': 2, '10': 1, '106': 1, '126': 1, '13': 4,...
# 372    {'1': 19, '106': 1, '111': 1, '12': 2, '121': ...
# 373    {'0': 3, '1': 2, '10th': 1, '12': 1, '13': 1, ...
# 374    {'100': 1, '106': 1, '112': 1, '126': 1, '136'...
# 375    {'112': 1, '116': 1, '117': 1, '118': 1, '119'...
# 376    {'0': 1, '1': 2, '12': 1, '13': 1, '1879': 2, ...
# dtype: object
# Processing 341-351 out of 2355...
# Elapsed time: 28.435925 seconds.
# Last 10:
# 377    {'020': 2, '040': 2, '050': 4, '1': 63, '10': ...
# 378    {'1': 188, '10': 14, '100': 3, '105': 3, '110'...
# 379    {'0': 14, '00': 2, '000': 1, '075': 1, '088': ...
# 381    {'abert': 3, 'ability': 4, 'able': 12, 'aboutt...
# 383    {'0f': 1, '1': 63, '10': 26, '11': 19, '12': 1...
# 384    {'0': 1, '1': 76, '10': 44, '100': 1, '101': 2...
# 385    {'0': 2, '1': 124, '10': 58, '100': 1, '10000'...
# 386    {'1': 21, '10': 3, '100': 21, '1000': 1, '102'...
# 387    {'1': 95, '10': 72, '100': 1, '103': 2, '104':...
# 389    {'1': 58, '10': 6, '100': 5, '101': 2, '102': ...
# dtype: object
# Processing 351-361 out of 2355...
# Elapsed time: 28.510721 seconds.
# Last 10:
# 390    {'1': 1, '15': 2, '1650': 1, '1813': 1, '25': ...
# 391    {'1': 46, '10': 6, '101': 1, '106': 1, '107': ...
# 392    {'10': 1, '100': 1, '101': 1, '102': 1, '103':...
# 393    {'1': 40, '10': 37, '100': 1, '11': 45, '12': ...
# 394    {'1': 2, '1850': 1, '2': 3, '21': 3, '28': 1, ...
# 395    {'1': 2, '10': 4, '103': 1, '105': 14, '11': 2...
# 396    {'0': 3, '0001118': 1, '1': 44, '10': 9, '100'...
# 397    {'100': 1, '102': 1, '112': 1, '113': 1, '124'...
# 398    {'1': 78, '10': 38, '100': 4, '101': 1, '102':...
# 399    {'083': 1, '1': 26, '10': 8, '101': 1, '10have...
# dtype: object
# Processing 361-371 out of 2355...
# Elapsed time: 28.54527 seconds.
# Last 10:
# 401    {'1': 1, '10': 1, '100': 1, '101': 1, '102': 1...
# 402    {'13646hhtm': 1, '13646hzip': 1, '13th': 1, '1...
# 403    {'1916': 1, '19722hhtm': 1, '19722hzip': 1, 'a...
# 404    {'1': 1, '13647hhtm': 1, '13647hzip': 1, '18':...
# 405    {'1899': 1, 'already': 1, 'arbour': 1, 'archiv...
# 406    {'1': 28, '10': 4, '11': 3, '12': 5, '13': 1, ...
# 407    {'10': 2, '11': 1, '12': 3, '14': 3, '15': 1, ...
# 408    {'1668': 1, '1918': 1, '240': 1, '47': 1, 'abl...
# 409    {'104': 1, '110': 1, '162': 1, '1889': 2, '27t...
# 410    {'1212': 1, '164': 1, '16mo': 11, '1852': 2, '...
# dtype: object
# Processing 371-381 out of 2355...
# Elapsed time: 28.568839 seconds.
# Last 10:
# 411    {'0824023102': 1, '1': 2, '10': 1, '100': 1, '...
# 412    {'11': 1, '12': 1, '13': 1, '14': 1, '15': 1, ...
# 413    {'13648hhtm': 1, '13648hzip': 1, '1843': 1, '1...
# 414    {'1': 1, '102': 1, '103': 1, '105': 1, '107': ...
# 415    {'1': 1, '2': 1, 'aflame': 1, 'always': 1, 'am...
# 416    {'1': 6, '10': 1, '1614': 2, '1617': 2, '1626'...
# 417    {'10': 1, '12': 2, '13': 1, '23': 2, '26': 1, ...
# 418    {'1918': 2, 'aboard': 1, 'absurd': 1, 'across'...
# 420    {'1': 3, '10': 4, '11': 4, '12': 4, '13': 5, '...
# 421    {'1': 2, '10': 3, '11': 1, '12': 1, '13': 1, '...
# dtype: object
# Processing 381-391 out of 2355...
# Elapsed time: 28.592369 seconds.
# Last 10:
# 422    {'1': 4, '10': 4, '11': 5, '12': 4, '13': 5, '...
# 423    {'1': 2, '10': 2, '11': 1, '12': 1, '14': 1, '...
# 424    {'1': 4, '10': 4, '11': 4, '12': 4, '13': 5, '...
# 425    {'1': 6, '10': 5, '11': 4, '12': 6, '13': 5, '...
# 426    {'1': 2, '10': 2, '11': 2, '12': 1, '13': 1, '...
# 427    {'1': 4, '10': 3, '11': 3, '12': 4, '13': 3, '...
# 428    {'1': 4, '10': 4, '11': 3, '12': 3, '13': 3, '...
# 429    {'1': 3, '10': 3, '11': 3, '111': 1, '12': 5, ...
# 430    {'1': 4, '10': 6, '11': 4, '12': 4, '13': 4, '...
# 431    {'1': 6, '10': 4, '11': 4, '12': 4, '13': 4, '...
# dtype: object
# Processing 391-401 out of 2355...
# Elapsed time: 28.654815 seconds.
# Last 10:
# 432    {'1': 1, '105': 1, '109': 1, '111': 1, '114': ...
# 433    {'10': 2, '101': 1, '103': 1, '106': 1, '109':...
# 434    {'10': 1, '100': 1, '12': 1, '14': 1, '16': 1,...
# 435    {'1': 7, '10': 3, '100': 2, '102': 1, '103': 1...
# 436    {'1': 1, '10': 1, '100': 1, '12': 1, '14': 1, ...
# 437    {'1903': 1, 'aaron': 4, 'able': 3, 'aboard': 1...
# 438    {'1': 1, '13': 1, '1483': 1, '1656': 1, '1659'...
# 439    {'1': 7, '10': 37, '100': 1, '1000': 1, '103':...
# 440    {'12': 1, '15th': 1, '1853': 1, '1886': 1, '18...
# 441    {'1': 4, '15': 1, '16': 1, '1692': 1, '2': 3, ...
# dtype: object
# Processing 401-411 out of 2355...
# Elapsed time: 28.777864 seconds.
# Last 10:
# 442    {'10th': 2, '11821226': 1, '12401302': 1, '127...
# 444    {'11': 1, '121': 1, '13': 1, '141': 1, '147': ...
# 445    {'08': 1, '1': 2, '100': 1, '11': 2, '112': 1,...
# 446    {'1': 12, '10': 5, '100': 5, '104': 1, '1071':...
# 447    {'1': 7, '10': 12, '100': 12, '100pounder': 3,...
# 448    {'100': 3, '109': 1, '10th': 20, '110': 2, '11...
# 449    {'15': 1, '1769': 1, '1960': 1, '1961': 1, '19...
# 450    {'1': 1, '10': 1, '108': 1, '113': 1, '118': 1...
# 451    {'1': 21, '10': 3, '125—146994': 2, '12841328'...
# 452    {'14': 1, '1849': 1, '1859': 1, '1861': 1, '18...
# dtype: object
# Processing 411-421 out of 2355...
# Elapsed time: 28.982923 seconds.
# Last 10:
# 453    {'104k': 1, '105k': 1, '106k': 1, '1085': 1, '...
# 454    {'1': 3, '10': 1, '100': 2, '1000': 2, '101': ...
# 455    {'1': 1, '10': 1, '11': 1, '12': 1, '12d': 1, ...
# 456    {'1': 124, '10': 19, '1016': 1, '1017': 1, '10...
# 457    {'1': 8, '10': 8, '11': 8, '12': 10, '13': 9, ...
# 458    {'1': 7, '10': 3, '105': 1, '10648': 1, '10wha...
# 459    {'abbreviation': 1, 'abode': 1, 'abound': 2, '...
# 460    {'401': 1, 'abandon': 6, 'abandonedly': 1, 'ab...
# 461    {'0': 1, '1': 30, '10': 19, '100': 2, '1000': ...
# 462    {'1': 2, '10': 1, '100': 2, '101': 1, '102': 1...
# dtype: object
# Processing 421-431 out of 2355...
# Elapsed time: 29.212727 seconds.
# Last 10:
# 463    {'1': 14, '10': 6, '1000': 1, '11': 5, '11th':...
# 464    {'0': 430, '0d': 1, '0¹³': 1, '0¼': 4, '0½': 1...
# 465    {'014': 1, '1': 2, '10': 3, '100': 3, '1000': ...
# 466    {'1': 12, '10': 7, '100': 1, '10044': 1, '101'...
# 467    {'10': 1, '16': 1, '1604': 1, '1614': 1, '1615...
# 468    {'1478': 1, '1486': 1, '1499': 1, '1503': 1, '...
# 469    {'1': 2, '10': 5, '11': 2, '12': 5, '13': 2, '...
# 470    {'1': 2, '10': 2, '10th': 1, '11': 2, '12': 2,...
# 471    {'0525470182': 1, '1': 53, '10': 33, '100': 14...
# 472    {'1': 1, '10': 2, '100': 1, '101': 2, '102': 1...
# dtype: object
# Processing 431-441 out of 2355...
# Elapsed time: 29.359252 seconds.
# Last 10:
# 473    {'1': 59, '10': 2, '100': 1, '101': 2, '1010':...
# 474    {'1797': 1, '1828': 1, '1831': 1, '1856': 1, '...
# 475    {'1': 8, '10': 3, '100': 4, '100000': 1, '1004...
# 478    {'aba': 1, 'abantes': 3, 'abarbarea': 1, 'abat...
# 479    {'abandon': 1, 'able': 1, 'absence': 1, 'absen...
# 480    {'191': 1, '5': 1, '58': 1, '630': 1, '660': 1...
# 481    {'1': 2, '10': 1, '105': 1, '106': 1, '109': 1...
# 482    {'aba': 3, 'abandon': 13, 'abas': 2, 'abate': ...
# 483    {'1': 39, '10': 18, '100': 3, '101': 1, '105':...
# 484    {'1': 1, '1st': 6, '1vide': 1, '23': 1, '2nd':...
# dtype: object
# Processing 441-451 out of 2355...
# Elapsed time: 29.479792 seconds.
# Last 10:
# 485    {'1': 12, '10': 5, '1018': 1, '10alas': 1, '10...
# 486    {'1': 1, '10': 1, '102': 1, '105113': 1, '11':...
# 487    {'1': 1, '100': 4, '101': 5, '102': 4, '103': ...
# 488    {'1': 4, '10': 1, '100': 1, '101': 1, '102': 1...
# 489    {'09': 1, '1': 20, '10': 7, '100': 2, '100106'...
# 490    {'1': 14, '10': 11, '100': 6, '100000': 1, '10...
# 491    {'13': 1, '14': 1, '15': 1, '184': 1, '23': 1,...
# 492    {'1': 15, '10': 19, '100': 2, '10000': 2, '100...
# 493    {'1566': 2, '1639': 1, '17': 1, 'abandon': 3, ...
# 494    {'1': 13, '10th': 3, '11th': 1, '12th': 3, '13...
# dtype: object
# Processing 451-461 out of 2355...
# Elapsed time: 29.652201 seconds.
# Last 10:
# 495    {'5': 1, 'abandon': 6, 'abanian': 1, 'abate': ...
# 496    {'114': 1, '121152abas': 1, '122154forth': 1, ...
# 497    {'1': 22, '10': 8, '100': 4, '1006': 1, '101':...
# 498    {'1': 1, '10': 2, '106': 1, '11': 2, '12': 2, ...
# 499    {'1': 31, '10': 1, '1000': 1, '11': 1, '12': 1...
# 501    {'1085': 1, '1143': 1, '123648': 1, '1547': 1,...
# 502    {'1': 8, '10': 5, '100': 1, '101': 1, '103': 2...
# 503    {'1614': 1, '20th': 1, 'aback': 5, 'abajo': 1,...
# 504    {'': 1, '1': 350, '10': 6, '100': 1, '10000':...
# 505    {'1': 1, '107': 1, '115': 1, '123': 1, '135': ...
# dtype: object
# Processing 461-471 out of 2355...
# Elapsed time: 29.962769 seconds.
# Last 10:
# 506    {'1': 1, '10': 5, '100': 2, '11': 7, '12': 2, ...
# 507    {'1': 3, '10': 4, '100': 2, '1000': 2, '1005':...
# 508    {'1': 1, '15': 1, '1622': 1, '18': 1, '1836': ...
# 509    {'1554': 2, 'abajar': 2, 'abajara': 1, 'abajo'...
# 510    {'1': 1, '10': 1, '109': 1, '11': 1, '12': 1, ...
# 511    {'2001': 2, 'abadesa': 27, 'abadesa¿conque': 1...
# 512    {'10': 1, '1511': 1, '1792': 1, '1848': 2, '18...
# 513    {'1': 2, '10': 2, '100': 1, '101': 2, '102': 2...
# 514    {'101': 1, '109': 1, '113': 1, '117': 1, '121'...
# 515    {'1': 1, '10': 1, '100': 1, '101': 1, '102': 1...
# dtype: object
# Processing 471-481 out of 2355...
# Elapsed time: 30.186883 seconds.
# Last 10:
# 516    {'1511': 1, '1792': 1, '1848': 1, '1848a': 1, ...
# 517    {'1': 17, '10': 8, '102': 1, '108': 1, '11': 4...
# 518    {'105': 1, '115': 1, '125': 1, '132': 2, '137'...
# 520    {'abadesa': 2, 'abajo': 17, 'abanicos': 1, 'ab...
# 521    {'1': 2, '105': 1, '107': 1, '11': 1, '113': 1...
# 522    {'105': 1, '108': 1, '111': 1, '1200': 1, '128...
# 523    {'1': 5, '10': 9, '100': 1, '1030': 1, '1040':...
# 524    {'1': 2, '10': 6, '11': 2, '12': 1, '13': 2, '...
# 525    {'0': 1, '020jpg': 1, '021jpg': 1, '023ajpg': ...
# 526    {'0': 1, '006': 1, '008': 1, '019': 1, '022': ...
# dtype: object
# Processing 481-491 out of 2355...
# Elapsed time: 30.378479 seconds.
# Last 10:
# 528    {'0': 100, '00': 18, '05': 1, '07': 1, '1': 16...
# 529    {'1': 6, '10': 10, '10th': 1, '11': 4, '1130':...
# 530    {'1': 2, '121': 1, '145': 1, '163': 1, '182': ...
# 531    {'014': 1, '1': 5, '10': 3, '100': 10, '1000':...
# 532    {'1': 21, '10': 19, '100': 9, '100103': 2, '10...
# 533    {'006': 1, '008': 1, '019': 1, '022': 1, '026'...
# 534    {'1': 5, '10': 4, '100': 1, '1000': 8, '10000'...
# 535    {'1': 71, '10': 25, '100': 10, '1000': 1, '101...
# 536    {'1': 122, '10': 105, '100': 1, '1008': 1, '10...
# 537    {'1': 1, '10': 5, '100': 22, '1000': 7, '10000...
# dtype: object
# Processing 491-501 out of 2355...
# Elapsed time: 30.597929 seconds.
# Last 10:
# 538    {'015': 1, '1': 6, '10': 6, '100': 26, '1000':...
# 539    {'100': 1, '11': 1, '1130': 1, '127': 1, '140'...
# 540    {'1': 15, '101': 1, '102': 1, '11': 1, '112': ...
# 541    {'1': 5, '10': 1, '100': 2, '100000': 1, '102'...
# 542    {'0': 17, '0sbeckia': 2, '0°': 2, '0·0': 1, '0...
# 543    {'1': 34, '10': 26, '100': 14, '1000': 22, '10...
# 544    {'1': 14, '10': 11, '100': 18, '1000': 2, '100...
# 545    {'1': 2, '10': 4, '100': 3, '1000': 1, '101': ...
# 546    {'1': 8, '10': 5, '100': 11, '1000': 5, '102':...
# 547    {'0': 5, '1': 16, '10': 17, '100': 25, '1000':...
# dtype: object
# Processing 501-511 out of 2355...
# Elapsed time: 30.719768 seconds.
# Last 10:
# 548    {'0': 1, '1': 10, '10': 15, '100': 7, '1000': ...
# 549    {'0': 3, '1': 7, '10': 8, '100': 10, '1000': 9...
# 550    {'1843': 1, 'abed': 1, 'abel': 1, 'abject': 1,...
# 551    {'30': 1, 'abide': 1, 'able': 1, 'absence': 1,...
# 552    {'1': 2, '100': 1, '1861': 1, '18—': 1, '2': 4...
# 553    {'1': 1, '14': 2, '1911': 1, '1991': 1, '2': 1...
# 554    {'1': 3, '10': 2, '100': 1, '105': 1, '109': 1...
# 555    {'1900': 1, 'able': 10, 'abound': 1, 'abundanc...
# 557    {'1': 1, '1888': 1, '1889': 1, '1902': 1, '190...
# 558    {'11': 1, '14': 1, '1905': 1, '26': 1, '32': 1...
# dtype: object
# Processing 511-521 out of 2355...
# Elapsed time: 30.803846 seconds.
# Last 10:
# 559    {'aback': 1, 'abed': 1, 'abide': 3, 'able': 4,...
# 560    {'1842': 1, '39th': 2, 'aaarh': 1, 'aaassp': 1...
# 561    {'0397000332': 1, '100': 1, '111': 2, '114': 1...
# 563    {'1': 3, '10': 2, '11': 1, '17': 1, '2': 2, '2...
# 564    {'1': 1, '10': 1, '101': 1, '111': 1, '117': 1...
# 565    {'01': 2, '02': 2, '03': 2, '04': 2, '05': 2, ...
# 566    {'aback': 2, 'abandon': 5, 'abandonment': 1, '...
# 568    {'1916': 1, 'accusation': 1, 'accustomed': 1, ...
# 570    {'1': 1, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 573    {'12th': 1, '1700': 1, '1715': 1, '1733': 1, '...
# dtype: object
# Processing 521-531 out of 2355...
# Elapsed time: 30.879978 seconds.
# Last 10:
# 574    {'1': 67, '120': 1, '13th': 1, '1500l': 1, '16...
# 578    {'187': 2, '20': 1, '30': 1, '7': 1, '8': 2, '...
# 580    {'1': 2, '1850': 1, '1851': 1, '1852': 2, '185...
# 581    {'1': 6, '10': 2, '11': 2, '12': 2, '2': 6, '3...
# 582    {'1903': 1, 'able': 1, 'across': 2, 'act': 1, ...
# 583    {'14': 1, '1611': 1, '1620': 1, '1776': 2, '18...
# 586    {'abandon': 5, 'abear': 1, 'abhorrence': 2, 'a...
# 587    {'1895': 1, '1896': 1, 'abana': 1, 'abdus': 1,...
# 588    {'abandon': 1, 'able': 1, 'abode': 1, 'absent'...
# 590    {'1': 61, '10': 38, '100': 7, '1000': 1, '1002...
# dtype: object
# Processing 531-541 out of 2355...
# Elapsed time: 30.967027 seconds.
# Last 10:
# 591    {'105': 1, '109': 1, '113': 1, '125': 1, '13':...
# 592    {'100': 1, '103': 1, '106': 1, '13': 1, '170':...
# 593    {'able': 1, 'abroad': 1, 'absolutely': 1, 'acc...
# 594    {'1': 12, '10': 3, '100': 2, '1014': 1, '107':...
# 596    {'129': 1, '140': 1, '155': 2, '1912': 3, '39'...
# 597    {'1': 2, '12mo': 1, '1807': 1, '1847': 1, '186...
# 598    {'1': 10, '100': 179, '1000': 2, '109': 3, '11...
# 599    {'1905': 2, '1911': 1, '3': 1, '33': 1, '45': ...
# 600    {'abandon': 9, 'abati': 2, 'abbagliato': 1, 'a...
# 601    {'1': 3, '10': 1, '11': 1, '12': 1, '13': 1, '...
# dtype: object
# Processing 541-551 out of 2355...
# Elapsed time: 31.107138 seconds.
# Last 10:
# 602    {'1': 1, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 603    {'1': 1, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 604    {'1': 13, '1595': 1, '2': 8, '3': 3, 'abate': ...
# 605    {'322': 1, 'abandon': 2, 'abduction': 1, 'abil...
# 606    {'1': 1, '1584': 2, '2': 1, '3': 1, '4': 1, 'a...
# 607    {'1830a': 1, '1879': 1, '1880': 1, 'abash': 1,...
# 608    {'1': 1, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 609    {'1': 19, '10': 46, '100': 41, '101': 7, '102'...
# 610    {'1300': 1, '18071882': 1, 'abandon': 15, 'aba...
# 611    {'0': 4, '1': 63, '10': 27, '100': 1, '1008': ...
# dtype: object
# Processing 551-561 out of 2355...
# Elapsed time: 31.234191 seconds.
# Last 10:
# 612    {'1': 1, '10': 1, '103': 2, '104': 1, '11': 2,...
# 613    {'19': 1, '1912': 1, 'ab': 14, 'abals': 1, 'ab...
# 614    {'1876': 2, '4th': 2, '640': 2, 'aa': 3, 'aban...
# 615    {'0': 3, '012': 1, '012103': 1, '014': 1, '1':...
# 616    {'0': 1, '0f': 1, '0rso': 1, '1': 188, '10': 1...
# 617    {'1': 56, '10': 31, '100': 4, '1000': 1, '102'...
# 618    {'1': 181, '10': 1, '1085': 1, '1116': 1, '112...
# 619    {'abandon': 2, 'abandonest': 1, 'abasement': 1...
# 620    {'1': 5, '10': 7, '100': 4, '1000': 2, '10000'...
# 621    {'1300': 1, '18071882': 1, 'abandon': 4, 'abat...
# dtype: object
# Processing 561-571 out of 2355...
# Elapsed time: 31.403117 seconds.
# Last 10:
# 622    {'1': 5, '10': 7, '100': 3, '101': 1, '102': 3...
# 623    {'1': 9, '10': 6, '100': 7, '1000': 2, '101': ...
# 624    {'1': 4, '10': 1, '105': 1, '108': 1, '109': 1...
# 625    {'022': 1, '0333s': 1, '0375d': 1, '05s': 1, '...
# 626    {'1': 30, '10': 22, '100': 6, '10000': 3, '101...
# 628    {'1': 90, '10': 9, '11': 5, '12': 6, '123': 1,...
# 629    {'123249600': 1, '12th': 1, '1642': 1, '1660':...
# 630    {'1': 26, '10': 14, '100': 2, '10000': 1, '101...
# 631    {'1015': 1, '600': 2, 'abandon': 1, 'abash': 2...
# 632    {'1': 36, '10': 12, '100': 17, '100fleurie': 1...
# dtype: object
# Processing 571-581 out of 2355...
# Elapsed time: 31.653262 seconds.
# Last 10:
# 633    {'0': 25, '099': 1, '0½': 1, '1': 258, '10': 1...
# 634    {'1564': 1, '1649': 1, '1773': 1, '1775': 1, '...
# 635    {'1': 2, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 636    {'1': 1, '104': 1, '119': 1, '133': 1, '1397':...
# 637    {'0': 23, '1': 3, '10': 12, '100': 3, '1000': ...
# 638    {'0': 110, '00': 2, '0010': 1, '0013': 1, '001...
# 639    {'1': 5, '10': 2, '100': 1, '11': 4, '12': 2, ...
# 640    {'0': 1, '001': 2, '002': 2, '003': 2, '008': ...
# 641    {'1': 6, '10': 3, '100000': 1, '105000000': 1,...
# 642    {'1': 22, '10': 17, '100': 1, '1000': 1, '1000...
# dtype: object
# Processing 581-591 out of 2355...
# Elapsed time: 31.812138 seconds.
# Last 10:
# 643    {'1': 87, '10': 14, '100': 7, '1000': 4, '1000...
# 645    {'1': 25, '10': 21, '1000': 4, '10000': 3, '10...
# 646    {'0': 1, '035jpg': 1, '068jpg': 1, '081jpg': 1...
# 647    {'1': 5, '100': 2, '106': 1, '10th': 1, '11': ...
# 648    {'1': 48, '10': 42, '100': 5, '1003': 1, '1004...
# 649    {'1': 28, '10': 19, '100': 4, '101': 2, '102':...
# 650    {'1': 3, '100': 1, '1000': 2, '1030': 1, '1066...
# 652    {'1': 11, '10': 2, '100': 1, '10000': 1, '1000...
# 654    {'1000': 1, '1001': 1, '1002': 1, '1003': 1, '...
# 655    {'06': 1, '1': 22, '10': 4, '100': 3, '11': 4,...
# dtype: object
# Processing 591-601 out of 2355...
# Elapsed time: 31.917834 seconds.
# Last 10:
# 656    {'1': 2, '1536': 1, '1701': 1, '1816': 1, '183...
# 657    {'016': 1, '1': 16, '10': 15, '100': 8, '1000'...
# 658    {'1': 6, '10': 82, '100': 8, '10000': 1, '102'...
# 659    {'1': 3, '10': 4, '100': 1, '11': 2, '12': 2, ...
# 660    {'0': 4, '1': 57, '10': 6, '100': 1, '1000': 1...
# 661    {'1': 3, '10': 5, '100': 9, '1000': 3, '101': ...
# 662    {'1': 9, '10': 4, '100': 12, '1000': 6, '10000...
# 663    {'1': 3, '10': 1, '11': 1, '12': 1, '14': 1, '...
# 664    {'1': 1, '10': 4, '100': 6, '104': 1, '11': 7,...
# 665    {'10': 1, '12': 1, '120': 2, '1269': 1, '13': ...
# dtype: object
# Processing 601-611 out of 2355...
# Elapsed time: 31.980348 seconds.
# Last 10:
# 666    {'1': 1, '10historia': 1, '11': 1, '11la': 1, ...
# 667    {'0': 1, '00': 3, '00°': 7, '0°': 1, '1': 91, ...
# 668    {'1': 5, '10': 5, '11': 6, '12': 6, '13': 4, '...
# 669    {'0': 7, '00': 30, '01': 4, '02': 1, '03': 1, ...
# 670    {'1': 2, '10': 8, '100': 2, '10ª': 1, '11': 5,...
# 671    {'10': 3, '11': 1, '12': 2, '120': 1, '13': 1,...
# 672    {'1': 5, '10': 1, '11': 1, '112': 8, '12': 9, ...
# 673    {'1': 2, '10': 1, '100': 1, '12': 1, '120': 1,...
# 674    {'10': 3, '12': 1, '13': 1, '14': 1, '15': 1, ...
# 675    {'0': 13, '000': 1, '0002': 1, '0003': 1, '001...
# dtype: object
# Processing 611-621 out of 2355...
# Elapsed time: 32.149575 seconds.
# Last 10:
# 676    {'0': 4, '010': 1, '03': 2, '036': 1, '05': 1,...
# 677    {'0': 18, '0028': 1, '014': 1, '019': 2, '036'...
# 678    {'0': 12, '00': 3, '002alt': 1, '008alt': 1, '...
# 679    {'0': 1, '0017': 1, '0020': 3, '0021': 2, '002...
# 680    {'03': 1, '1': 14, '10': 8, '100': 2, '101': 2...
# 681    {'1': 2, '100': 1, '1532': 1, '1825': 1, '1841...
# 682    {'0': 8, '022': 1, '026': 1, '063': 1, '1': 82...
# 683    {'11000000': 1, '176': 1, '1801': 1, '1808': 1...
# 684    {'1': 4, '100': 6, '1000': 2, '10000': 2, '100...
# 685    {'1767': 1, '1835': 1, '1907': 1, 'aair': 1, '...
# dtype: object
# Processing 621-631 out of 2355...
# Elapsed time: 32.308515 seconds.
# Last 10:
# 686    {'0': 81, '000': 10, '095': 1, '1': 47, '10': ...
# 687    {'024': 1, '1': 43, '10': 9, '100': 17, '1000'...
# 688    {'1': 122, '10': 24, '100': 16, '1000': 10, '1...
# 689    {'1': 6, '103': 1, '11th': 1, '1888': 2, '1890...
# 690    {'0': 4, '1': 8, '10': 5, '100': 4, '1000': 5,...
# 691    {'1': 1, '10': 3, '1000': 1, '11': 2, '110': 1...
# 692    {'0': 1, '1': 15, '10': 7, '100': 2, '1000': 3...
# 693    {'1': 1, '1915': 1, '31': 1, '59': 1, 'aan': 5...
# 694    {'13th': 1, '14th': 1, '17th': 1, '1860': 4, '...
# 695    {'1': 1, '13': 1, '16': 1, '17': 1, '1861': 1,...
# dtype: object
# Processing 631-641 out of 2355...
# Elapsed time: 32.443492 seconds.
# Last 10:
# 696    {'1': 45, '10': 13, '100': 9, '100103': 1, '10...
# 697    {'10': 1, '100': 1, '10000': 1, '102105': 1, '...
# 698    {'6': 1, 'aardvark': 1, 'able': 11, 'abound': ...
# 699    {'1': 4, '102': 1, '11': 2, '113': 1, '124': 1...
# 700    {'1': 5, '1000': 1, '11': 1, '11th': 1, '13thd...
# 701    {'0': 1, '1': 16, '10': 8, '100': 6, '1000': 1...
# 702    {'1': 22, '10': 23, '100': 5, '1000': 1, '100l...
# 704    {'100000': 1, '109': 1, '13000': 1, '131': 1, ...
# 705    {'1': 8, '10': 6, '100': 1, '10000': 1, '103':...
# 706    {'1': 11, '10': 2, '11': 1, '123': 1, '124': 1...
# dtype: object
# Processing 641-651 out of 2355...
# Elapsed time: 32.611862 seconds.
# Last 10:
# 707    {'1': 3, '10': 5, '100': 4, '1000': 5, '10000'...
# 708    {'1': 2, '10': 3, '10th': 2, '1300': 1, '15': ...
# 709    {'1': 5, '10': 7, '100': 1, '102': 1, '103': 2...
# 710    {'27': 1, '28': 1, '3': 1, '4': 1, '8': 1, '9'...
# 712    {'1': 5, '100000': 1, '12': 1, '13': 2, '1800'...
# 714    {'able': 3, 'abnormally': 1, 'abominably': 1, ...
# 715    {'1': 28, '10': 15, '100': 4, '1000': 2, '1000...
# 716    {'0': 4, '1': 7, '10': 19, '100': 8, '10000': ...
# 717    {'0': 4, '0818': 1, '1': 263, '10': 51, '100':...
# 718    {'17': 1, '2': 1, '27000': 1, '31': 1, '7': 1,...
# dtype: object
# Processing 651-661 out of 2355...
# Elapsed time: 32.680052 seconds.
# Last 10:
# 719    {'10': 2, '10000': 1, '120': 1, '13th': 1, '14...
# 720    {'07': 1, '1': 42, '10': 11, '10000': 2, '1010...
# 721    {'1': 1, '10': 1, '11': 1, '1915': 2, '2': 2, ...
# 722    {'1': 1, '10': 8, '11': 6, '12': 6, '13': 4, '...
# 723    {'16': 1, '1849': 1, '1851': 1, '1905': 1, '1s...
# 724    {'1': 1, '103': 1, '104': 2, '11': 1, '126': 1...
# 725    {'0': 15, '1': 43, '10': 15, '1000': 3, '10000...
# 726    {'1': 12, '10': 8, '100th': 1, '10th': 4, '11'...
# 727    {'1': 11, '10': 6, '10081': 1, '105': 2, '109'...
# 728    {'0': 1, '1': 4, '10': 5, '10th': 24, '10°': 2...
# dtype: object
# Processing 661-671 out of 2355...
# Elapsed time: 32.864117 seconds.
# Last 10:
# 729    {'aaskin': 1, 'ab': 1, 'aback': 2, 'ability': ...
# 730    {'10': 1, '11': 1, '11th': 1, '12': 1, '13': 2...
# 731    {'1': 11, '10': 5, '10th': 7, '11': 10, '11th'...
# 732    {'1': 6, '10': 10, '100': 5, '1000': 2, '10000...
# 733    {'1': 16, '157': 2, '1910': 7, '1925': 2, '192...
# 734    {'0': 1, '005': 2, '006': 1, '007': 1, '009': ...
# 735    {'1': 24, '10': 7, '100': 5, '1000': 7, '10000...
# 736    {'0': 1, '1': 3, '10': 97, '1000': 1, '10000':...
# 737    {'1': 9, '10': 5, '100': 4, '1000': 1, '10000'...
# 738    {'1': 33, '10': 5, '100000': 2, '103': 1, '108...
# dtype: object
# Processing 671-681 out of 2355...
# Elapsed time: 33.042528 seconds.
# Last 10:
# 739    {'1': 4, '10': 1, '10th': 8, '11': 2, '11th': ...
# 740    {'1': 3, '15': 1, '16': 1, '17': 1, '1769': 2,...
# 741    {'1': 7, '10': 4, '102': 1, '10th': 18, '115':...
# 742    {'1': 1, '1000': 1, '11': 1, '11th': 1, '13th'...
# 743    {'1': 1, '10': 2, '11': 1, '12': 1, '13': 7, '...
# 744    {'00009': 1, '000095': 1, '000096': 3, '00021'...
# 745    {'1': 4, '10': 2, '1000': 2, '1006': 1, '101':...
# 746    {'1': 3, '10': 1, '100000': 1, '11': 1, '112':...
# 747    {'1': 4, '10': 2, '10th': 14, '11': 6, '11th':...
# 748    {'1': 4, '10': 1, '102': 1, '103': 1, '106': 1...
# dtype: object
# Processing 681-691 out of 2355...
# Elapsed time: 33.285645 seconds.
# Last 10:
# 749    {'1': 3, '10': 2, '100': 1, '101': 1, '102': 1...
# 750    {'02': 1, '1': 8, '10': 3, '100': 2, '1000': 2...
# 751    {'0': 1, '00': 11, '1': 137, '10': 26, '100': ...
# 752    {'1': 5, '10': 5, '100': 14, '1000': 4, '10000...
# 753    {'10': 2, '104': 1, '105': 1, '1051': 2, '1098...
# 754    {'0': 3, '1': 3, '10': 1, '103': 1, '104': 1, ...
# 755    {'1': 1, '10': 3, '103': 1, '10th': 2, '11': 1...
# 756    {'008large': 1, '008small': 1, '010png': 1, '0...
# 757    {'1': 30, '10': 1, '100': 3, '101': 2, '103': ...
# 758    {'08': 1, '1': 9, '10': 3, '100': 4, '1000': 1...
# dtype: object
# Processing 691-701 out of 2355...
# Elapsed time: 33.430243 seconds.
# Last 10:
# 759    {'1': 4, '10': 4, '100': 1, '1000': 2, '10000'...
# 760    {'1': 2, '10': 5, '100': 4, '101': 4, '102': 2...
# 762    {'1': 15, '10': 4, '100': 1, '103': 1, '108': ...
# 763    {'1': 71, '10': 11, '100': 6, '1000': 2, '1000...
# 764    {'1': 3, '10': 1, '100': 1, '10000': 2, '101':...
# 765    {'1': 5, '108': 1, '110': 1, '113': 1, '1910':...
# 766    {'1611': 1, '1616': 1, '1715': 1, '1726': 1, '...
# 767    {'1': 3, '10': 3, '100': 9, '1000': 13, '10000...
# 768    {'1': 4, '10': 3, '100': 3, '101': 1, '101201'...
# 769    {'1': 73, '10': 63, '100': 5, '1000': 2, '1000...
# dtype: object
# Processing 701-711 out of 2355...
# Elapsed time: 33.701046 seconds.
# Last 10:
# 770    {'1': 9, '10': 4, '100': 2, '101': 2, '102': 1...
# 771    {'1': 4, '10': 4, '100': 7, '1000': 3, '10000'...
# 772    {'000': 90, '1': 29, '10': 28, '100': 14, '100...
# 773    {'031': 1, '090': 1, '1': 7, '10': 5, '1000': ...
# 774    {'1': 3, '10': 1, '10000': 1, '101': 1, '104':...
# 775    {'1': 1, '13': 1, '137': 1, '14': 4, '15': 6, ...
# 776    {'1': 3, '10': 3, '100': 2, '101': 3, '103': 3...
# 777    {'000': 1, '1822': 1, '1825': 1, '2000': 1, '2...
# 778    {'1': 9, '10': 3, '100': 2, '104148': 1, '1081...
# 780    {'117': 1, '1910': 1, '54': 1, '69': 1, '70': ...
# dtype: object
# Processing 711-721 out of 2355...
# Elapsed time: 33.860457 seconds.
# Last 10:
# 781    {'1': 1, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 782    {'1': 46, '10': 2, '100': 1, '1012': 1, '1016'...
# 783    {'10': 2, '117': 1, '139': 1, '13th': 1, '14':...
# 784    {'1': 2, '10': 2, '11': 1, '12': 1, '13': 1, '...
# 785    {'1': 8, '10': 6, '100': 3, '100000': 1, '101'...
# 786    {'1': 19, '10': 5, '100': 2, '1000': 1, '10000...
# 787    {'1': 3, '10': 1, '11': 1, '12': 2, '12th': 1,...
# 789    {'1': 2, '10': 1, '11': 1, '12': 1, '13': 1, '...
# 790    {'1': 5, '10': 2, '1000': 1, '1014': 1, '1017'...
# 791    {'1': 16, '10': 112, '100': 4, '101': 3, '102'...
# dtype: object
# Processing 721-731 out of 2355...
# Elapsed time: 34.02393 seconds.
# Last 10:
# 792    {'1': 1, '1914': 1, '24': 1, '25': 1, '26': 1,...
# 793    {'12': 1, '12000': 1, '13': 1, '15': 1, '15th'...
# 794    {'1': 128, '10': 158, '100': 20, '1003179': 1,...
# 795    {'1': 7, '10': 2, '11': 2, '12': 1, '13': 2, '...
# 796    {'1': 5, '10': 2, '10goethe': 1, '11': 2, '113...
# 797    {'0fficiosalutatione': 1, '1': 172, '10': 22, ...
# 798    {'1': 17, '10': 9, '100': 17, '1000': 19, '100...
# 799    {'1': 10, '10': 5, '100': 1, '1000': 3, '105':...
# 800    {'1': 2, '100': 1, '10000': 1, '10tha': 1, '10...
# ...
# 2416    {'1': 2, '10': 6, '100': 4, '102': 1, '104': 1...
# 2417    {'025': 1, '040': 1, '060': 1, '075': 2, '08':...
# 2418    {'1': 8, '10': 12, '100': 3, '1000': 3, '10000...
# 2419    {'10th': 5, '11th': 2, '12th': 2, '13th': 2, '...
# 2420    {'1480': 1, '1640': 1, 'abashed': 1, 'abed': 1...
# 2421    {'0': 2, '005': 1, '0180': 1, '0186': 1, '0225...
# 2422    {'06': 1, '1': 37, '10': 24, '100': 9, '1000':...
# 2423    {'000003546': 1, '000004405': 1, '001': 1, '05...
# 2424    {'00001': 2, '00075': 1, '0174': 1, '0300': 1,...
# dtype: object
# Processing 2131-2141 out of 2355...
# Elapsed time: 56.670873 seconds.
# Last 10:
# 2425    {'050': 1, '1': 11, '10': 4, '100': 3, '1000':...
# 2426    {'1': 39, '10': 27, '100': 8, '1000': 7, '1000...
# 2427    {'0001': 1, '0005': 1, '002': 2, '0040': 1, '0...
# 2428    {'0': 1, '000': 1, '1': 43, '10': 26, '100': 1...
# 2429    {'0': 29, '0001': 3, '0002': 3, '0003': 1, '00...
# 2430    {'0': 5, '000': 2, '00084': 2, '00108': 1, '00...
# 2431    {'0': 30, '00': 2, '0007': 1, '001': 1, '0012'...
# 2432    {'000000052': 1, '0000000863': 1, '0000000898'...
# 2433    {'0': 3, '00': 26, '0002': 2, '0003': 2, '0004...
# 2434    {'0011': 1, '0017': 1, '00658': 5, '02': 1, '0...
# dtype: object
# Processing 2141-2151 out of 2355...
# Elapsed time: 56.745908 seconds.
# Last 10:
# 2435    {'0': 4, '0001': 3, '0002': 1, '001': 1, '002'...
# 2436    {'0029': 1, '00327': 1, '0033': 1, '00343': 1,...
# 2437    {'0': 15, '01': 1, '1': 40, '10': 34, '100': 2...
# 2438    {'0': 2, '001': 1, '0098': 1, '0104': 1, '0166...
# 2439    {'0000': 1, '001': 1, '0012': 1, '002': 1, '00...
# 2440    {'0': 1, '0011': 1, '0012': 1, '008': 1, '009'...
# 2441    {'0': 32, '01': 4, '016': 1, '06': 1, '0¾': 1,...
# 2442    {'0057': 1, '009': 1, '0524': 1, '0815': 1, '0...
# 2443    {'0': 2, '00': 1, '03': 3, '08': 2, '0·0000048...
# 2444    {'0000000': 2, '0000529': 1, '0001041': 1, '00...
# dtype: object
# Processing 2151-2161 out of 2355...
# Elapsed time: 56.937925 seconds.
# Last 10:
# 2445    {'00000112': 1, '0002': 1, '0004': 1, '0025': ...
# 2447    {'1': 4, '10': 3, '100': 7, '1000': 1, '101': ...
# 2448    {'1': 3, '10': 2, '100': 4, '1000': 1, '101': ...
# 2456    {'00': 1, '1': 126, '10': 26, '100': 1, '101':...
# 2458    {'00': 11, '1': 26, '10': 5, '101': 1, '105': ...
# 2460    {'1': 29, '10': 10, '100': 10, '1000': 2, '100...
# 2461    {'1': 18, '10': 6, '100': 12, '101': 4, '102':...
# 2462    {'1': 60, '10': 17, '100': 5, '1000': 3, '1000...
# 2463    {'1': 26, '10': 19, '100': 11, '1000': 5, '100...
# 2465    {'0': 1, '000': 15, '07': 1, '0mm': 2, '1': 8,...
# dtype: object
# Processing 2161-2171 out of 2355...
# Elapsed time: 57.057786 seconds.
# Last 10:
# 2466    {'1': 39, '10': 18, '100': 17, '1001': 1, '101...
# 2469    {'000000000000000001': 1, '0000000000000000062...
# 2470    {'0': 7, '01': 1, '1': 31, '10': 25, '100': 18...
# 2471    {'1': 2, '10': 5, '100': 3, '1000': 5, '100000...
# 2472    {'1': 27, '10': 6, '100': 4, '1000': 4, '10000...
# 2473    {'0': 15, '1': 9, '10': 4, '10th': 1, '11': 2,...
# 2474    {'1': 39, '10': 11, '100': 3, '1000': 2, '1000...
# 2476    {'1': 111, '10': 7, '100': 6, '101832': 1, '10...
# 2484    {'00': 4, '1': 162, '10': 17, '101': 3, '1012'...
# 2485    {'0': 149, '00': 586, '018typo': 1, '027fixed'...
# dtype: object
# Processing 2171-2181 out of 2355...
# Elapsed time: 57.227754 seconds.
# Last 10:
# 2488    {'1': 4, '10': 1, '100': 1, '106': 1, '10the':...
# 2489    {'1': 4, '10': 1, '10000': 2, '1012': 1, '106'...
# 2510    {'0': 3, '1': 14, '10': 2, '1000': 1, '10°': 1...
# 2513    {'0': 5, '1': 139, '10': 18, '100': 10, '1000'...
# 2516    {'0': 1, '02': 1, '05': 1, '1': 36, '10': 6, '...
# 2517    {'1': 1, '10': 1, '103': 1, '104': 1, '1076': ...
# 2519    {'1': 201, '10': 111, '100': 2, '100of': 1, '1...
# 2520    {'1': 11, '10': 1, '100': 2, '1000': 1, '1025'...
# 2521    {'1': 6, '10': 1, '100': 1, '101': 2, '103': 4...
# 2522    {'1': 37, '10': 28, '100': 4, '1000': 2, '1000...
# dtype: object
# Processing 2181-2191 out of 2355...
# Elapsed time: 57.32498 seconds.
# Last 10:
# 2523    {'10': 2, '12': 2, '14': 2, '15': 1, '151': 1,...
# 2524    {'1': 33, '10': 20, '100': 3, '101': 2, '102':...
# 2525    {'1': 11, '10': 21, '100': 2, '1000': 2, '101'...
# 2526    {'1': 1, '10': 2, '100': 2, '101': 1, '104': 1...
# 2527    {'1': 24, '10': 10, '100': 1, '1000': 5, '1001...
# 2528    {'025': 1, '1': 2, '10': 3, '11': 3, '12': 1, ...
# 2529    {'100': 1, '101': 2, '102': 1, '103': 2, '104'...
# 2530    {'1': 27, '10': 8, '100': 2, '101': 3, '102': ...
# 2531    {'1': 8, '10': 5, '103': 1, '104': 1, '108': 1...
# 2533    {'1': 8, '101': 1, '109': 1, '119': 1, '11½d':...
# dtype: object
# Processing 2191-2201 out of 2355...
# Elapsed time: 57.375072 seconds.
# Last 10:
# 2534    {'1': 5, '10': 1, '150': 1, '161': 1, '1908': ...
# 2535    {'1': 38, '10': 30, '100': 10, '1000': 2, '100...
# 2536    {'050': 1, '1': 3, '10': 1, '100': 14, '11': 1...
# 2537    {'1': 1, '1000': 1, '11': 1, '115': 1, '116326...
# 2538    {'1': 4, '10': 3, '100': 2, '110': 1, '1240': ...
# 2539    {'100': 1, '125': 2, '12mo': 1, '1919': 1, '50...
# 2542    {'0·6': 1, '0·7': 1, '1': 18, '10': 12, '1014'...
# 2543    {'1': 12, '10': 6, '100': 2, '1000': 4, '1000s...
# 2545    {'0': 1, '005': 2, '0051': 1, '0053': 1, '048'...
# 2546    {'1': 12, '10': 4, '100': 4, '1000': 4, '101':...
# dtype: object
# Processing 2201-2211 out of 2355...
# Elapsed time: 57.428128 seconds.
# Last 10:
# 2548    {'1': 152, '10': 39, '100': 29, '1000': 2, '10...
# 2549    {'1': 2, '10': 1, '100': 1, '12mo': 1, '14000'...
# 2551    {'00035': 1, '005': 1, '028': 1, '030': 1, '03...
# 2552    {'1000': 1, '100000': 1, '1171': 1, '1200': 1,...
# 2553    {'1': 6, '10': 5, '10383': 2, '106': 1, '107':...
# 2555    {'1': 33, '10': 8, '100mesh': 1, '10blowing': ...
# 2556    {'1': 15, '10': 12, '100': 1, '102': 1, '109':...
# 2557    {'1': 13, '112': 1, '133': 1, '137': 1, '151':...
# 2558    {'100': 3, '12': 1, '1800': 1, '1864': 1, '188...
# 2559    {'103': 1, '122': 1, '136': 1, '152': 1, '1600...
# dtype: object
# Processing 2211-2221 out of 2355...
# Elapsed time: 57.490769 seconds.
# Last 10:
# 2560    {'1': 5, '10': 2, '11': 2, '12': 3, '122500': ...
# 2561    {'1': 22, '10': 29, '100': 1, '1000': 1, '1000...
# 2562    {'1': 5, '10': 4, '100': 1, '107': 1, '10an': ...
# 2563    {'0': 1, '0°': 5, '0·00000059': 1, '0·0000007'...
# 2564    {'1': 4, '10': 1, '11': 1, '12': 3, '13': 1, '...
# 2565    {'01': 2, '015': 1, '018': 1, '02': 3, '021': ...
# 2566    {'02': 1, '07': 1, '08': 1, '1': 11, '10': 7, ...
# 2567    {'0': 35, '025': 2, '05': 1, '1': 24, '10': 1,...
# 2568    {'1': 8, '10': 5, '100': 4, '1000': 1, '100000...
# 2569    {'1': 32, '10': 7, '100': 1, '10000': 2, '1000...
# dtype: object
# Processing 2221-2231 out of 2355...
# Elapsed time: 57.597893 seconds.
# Last 10:
# 2570    {'1394': 1, '1867': 1, '1907': 1, '1908': 1, '...
# 2571    {'0': 120, '1': 39, '10': 26, '100': 24, '1000...
# 2572    {'0': 1, '1': 33, '10': 8, '100': 11, '1000': ...
# 2576    {'0': 2, '000366': 4, '000366t': 4, '00102': 1...
# 2577    {'1': 13, '10': 4, '1000': 1, '104': 1, '11': ...
# 2578    {'025': 1, '03': 1, '04': 1, '05': 3, '1': 4, ...
# 2579    {'0': 110, '000000a': 1, '000001': 1, '000002'...
# 2580    {'1': 8, '10': 3, '100': 1, '100°': 1, '101': ...
# 2581    {'0°': 1, '1': 49, '10': 9, '100': 11, '101': ...
# 2583    {'0': 13, '003': 1, '0035': 1, '00448': 1, '00...
# dtype: object
# Processing 2231-2241 out of 2355...
# Elapsed time: 57.70514 seconds.
# Last 10:
# 2584    {'0001': 1, '0056': 1, '015': 1, '1': 14, '10'...
# 2585    {'0002': 1, '03': 1, '06': 1, '1': 19, '10': 1...
# 2586    {'0': 26, '00': 10, '0000002': 1, '000003': 1,...
# 2587    {'0': 2, '00': 1, '000': 1, '0000': 1, '000000...
# 2588    {'02': 1, '035040': 1, '05': 1, '1': 10, '10':...
# 2589    {'0': 75, '006': 2, '02847': 1, '032': 1, '033...
# 2590    {'05': 1, '1': 8, '10': 3, '100': 12, '1000': ...
# 2591    {'1': 187, '10': 4, '100': 2, '101': 3, '102':...
# 2592    {'0°': 8, '0·01': 1, '0·017': 1, '0·05': 1, '0...
# 2593    {'0': 21, '00': 1, '000': 1, '00104': 1, '0013...
# dtype: object
# Processing 2241-2251 out of 2355...
# Elapsed time: 57.840656 seconds.
# Last 10:
# 2594    {'0': 1, '00': 2, '00001': 3, '0000161': 1, '0...
# 2595    {'0': 4, '006': 1, '0067': 1, '010': 2, '0102'...
# 2596    {'0560': 1, '075': 1, '1': 9, '10': 6, '100°':...
# 2597    {'1': 3, '10': 2, '1000': 1, '11': 1, '12': 1,...
# 2598    {'1': 2, '11th': 1, '15': 2, '17': 1, '1776': ...
# 2599    {'1': 37, '110': 1, '115116': 1, '13': 1, '14'...
# 2600    {'1': 3, '10': 3, '11': 3, '12': 2, '148': 1, ...
# 2601    {'1': 1, '10': 1, '1000000': 1, '1100': 1, '12...
# 2603    {'1': 3, '10': 1, '100': 5, '1000': 2, '101': ...
# 2605    {'1': 11, '10': 8, '100': 6, '1000': 2, '10000...
# dtype: object
# Processing 2251-2261 out of 2355...
# Elapsed time: 57.951333 seconds.
# Last 10:
# 2606    {'1': 15, '10': 13, '100': 3, '10000': 1, '101...
# 2607    {'able': 2, 'accident': 2, 'accidents': 1, 'ac...
# 2608    {'1': 6, '10': 4, '100': 15, '1000': 2, '101':...
# 2610    {'03': 1, '08': 1, '09': 1, '1': 12, '10': 8, ...
# 2611    {'1': 1, '125131': 1, '18': 1, '1838': 1, '186...
# 2612    {'1': 15, '10': 6, '100': 2, '10000': 1, '100d...
# 2613    {'1': 9, '10': 17, '100': 6, '1000': 5, '10000...
# 2614    {'1': 12, '10': 11, '100': 2, '1000': 4, '1020...
# 2615    {'1': 5, '10': 7, '100': 3, '1000': 1, '102': ...
# 2616    {'1': 5, '10': 13, '100': 3, '1000': 4, '10000...
# dtype: object
# Processing 2261-2271 out of 2355...
# Elapsed time: 58.074732 seconds.
# Last 10:
# 2617    {'1': 17, '10': 9, '100': 1, '1000': 1, '10018...
# 2618    {'1': 28, '10': 3, '100': 2, '100000': 2, '101...
# 2619    {'1': 51, '10': 9, '100': 5, '1000': 1, '10000...
# 2620    {'1': 2, '11': 1, '12': 1, '121': 1, '13': 2, ...
# 2621    {'0': 1, '072': 1, '078': 1, '1': 60, '10': 26...
# 2624    {'0': 6, '00000001': 2, '0000005': 1, '000002'...
# 2625    {'05': 1, '1': 2, '16': 1, '1817': 1, '1920': ...
# 2626    {'0': 21, '00': 2, '000': 7, '00000': 1, '0001...
# 2630    {'1775': 1, '1970s': 1, '23': 1, 'abandon': 2,...
# 2636    {'1': 46, '10': 34, '100': 2, '1000': 1, '1000...
# dtype: object
# Processing 2271-2281 out of 2355...
# Elapsed time: 58.294369 seconds.
# Last 10:
# 2637    {'0': 1, '1': 107, '10': 70, '100': 4, '1000':...
# 2638    {'00': 7, '1': 51, '10': 24, '100': 8, '1006':...
# 2639    {'1': 4, '18612': 1, '186265': 1, '1865': 2, '...
# 2640    {'1': 5, '10': 1, '100': 1, '101': 1, '11': 1,...
# 2641    {'1': 32, '10': 17, '10000': 4, '1005': 1, '10...
# 2642    {'000': 1, '1': 27, '10': 16, '100': 6, '1000'...
# 2644    {'1': 19, '10': 18, '100': 9, '1000': 2, '1000...
# 2645    {'1': 10, '10': 10, '100': 3, '1000': 2, '1000...
# 2646    {'1': 1, '105': 1, '122': 1, '13': 3, '133': 1...
# 2647    {'1': 3, '10': 2, '11': 1, '12': 2, '13': 1, '...
# dtype: object
# Processing 2281-2291 out of 2355...
# Elapsed time: 58.506789 seconds.
# Last 10:
# 2648    {'1': 3, '10': 2, '10th': 1, '11': 1, '12': 2,...
# 2649    {'0': 1, '1': 29, '10': 8, '100': 1, '10000': ...
# 2652    {'10': 2, '100': 2, '100000': 3, '105000': 1, ...
# 2653    {'1': 51, '10': 11, '100': 8, '10000': 2, '100...
# 2654    {'1': 15, '10': 6, '1000000000': 1, '10th': 1,...
# 2655    {'0c': 1, '1': 13, '10': 14, '100': 1, '100101...
# 2656    {'1': 1, '10': 1, '1620': 1, '1765': 1, '1797'...
# 2658    {'06': 1, '1': 46, '10': 23, '100': 13, '1000'...
# 2659    {'1': 13, '10': 20, '106': 3, '11': 17, '1163'...
# 2660    {'0': 3, '03': 1, '04': 3, '05': 6, '06': 9, '...
# dtype: object
# Processing 2291-2301 out of 2355...
# Elapsed time: 58.678423 seconds.
# Last 10:
# 2662    {'10th': 1, '117': 2, '12th': 1, '13': 1, '15t...
# 2663    {'1': 2, '10': 1, '100': 1, '100000': 1, '10th...
# 2664    {'06629': 1, '1': 27, '10': 12, '100': 5, '100...
# 2666    {'1': 37, '10': 9, '100': 1, '1000': 4, '1030'...
# 2667    {'0': 2, '1': 487, '10': 106, '100': 32, '1000...
# 2668    {'1': 20, '10000': 1, '105s': 1, '10th': 1, '1...
# 2669    {'0007': 1, '1': 20, '10': 14, '100': 16, '100...
# 2673    {'1': 46, '10': 24, '100': 11, '100000': 4, '1...
# 2674    {'1': 1, '11th': 2, '1258': 1, '13665hhtm': 1,...
# 2675    {'1': 29, '10': 21, '100': 11, '1000': 10, '10...
# dtype: object
# Processing 2301-2311 out of 2355...
# Elapsed time: 58.823942 seconds.
# Last 10:
# 2676    {'0': 2, '093': 1, '096': 2, '0°': 1, '1': 11,...
# 2677    {'1': 3, '10': 5, '100': 5, '10000': 1, '100po...
# 2678    {'1': 53, '10': 20, '100': 3, '1000': 1, '1000...
# 2679    {'1': 11, '10': 9, '100000': 1, '11': 9, '12':...
# 2680    {'1841': 1, '1860': 1, '1898the': 1, '1909': 1...
# 2681    {'1': 25, '10': 21, '100': 5, '1000': 7, '1000...
# 2682    {'0': 12, '00': 6, '0001': 2, '00022a': 1, '00...
# 2683    {'0': 3, '00': 2, '000': 2, '0001': 1, '001': ...
# 2684    {'00': 1, '02': 1, '04': 2, '09': 1, '1': 102,...
# 2685    {'0': 2, '03000pound': 2, '0500pound': 1, '0to...
# dtype: object
# Processing 2311-2321 out of 2355...
# Elapsed time: 58.905634 seconds.
# Last 10:
# 2686    {'0': 2, '00': 2, '0002in': 1, '0002inch': 4, ...
# 2687    {'0444b': 1, '0912504': 1, '1': 197, '10': 72,...
# 2688    {'00': 1, '003120': 1, '0200': 1, '0300': 1, '...
# 2689    {'10000': 1, '101': 1, '11': 1, '110': 1, '115...
# 2690    {'1': 8, '10': 2, '100': 1, '1000': 1, '100000...
# 2691    {'03': 1, '1': 5, '10': 2, '100': 1, '1000': 1...
# 2692    {'00': 1, '003137': 1, '1': 17, '10': 5, '100'...
# 2693    {'00': 1, '003135': 1, '0330': 1, '0406': 1, '...
# 2694    {'1': 3, '10': 5, '100': 15, '1000': 3, '10000...
# 2695    {'1': 1, '1000': 1, '10000': 1, '105': 1, '11'...
# dtype: object
# Processing 2321-2331 out of 2355...
# Elapsed time: 58.982942 seconds.
# Last 10:
# 2696    {'0': 1, '0300': 1, '0350': 1, '0500': 3, '053...
# 2697    {'00': 1, '003117': 1, '0130': 1, '0230': 1, '...
# 2698    {'002ps': 2, '004ps': 1, '015ps': 2, '03': 1, ...
# 2699    {'00': 1, '003131': 1, '0500': 1, '0645': 1, '...
# 2700    {'1': 2, '10000': 3, '100foot': 3, '10th': 1, ...
# 2701    {'1': 1, '1500': 1, '4': 1, '5': 1, '50': 1, '...
# 2702    {'00001': 1, '00005': 1, '0003': 1, '0004': 1,...
# 2703    {'0n': 2, '1': 13, '10': 12, '100': 16, '1000'...
# 2704    {'0': 5, '031': 1, '1': 29, '10': 25, '100': 4...
# 2705    {'1': 2, '114': 1, '127': 1, '137': 1, '156': ...
# dtype: object
# Processing 2331-2341 out of 2355...
# Elapsed time: 59.162402 seconds.
# Last 10:
# 2706    {'0': 1, '00': 1, '0047': 1, '013': 1, '016ps'...
# 2707    {'000': 3, '1': 6, '10': 9, '100': 9, '1000': ...
# 2708    {'1': 17, '10': 20, '100': 24, '1000': 11, '10...
# 2709    {'1': 131, '10': 24, '100': 25, '1000': 13, '1...
# 2710    {'1': 51, '10': 23, '100': 22, '1000': 6, '100...
# 2711    {'0': 17, '01': 1, '06': 1, '1': 29, '10': 11,...
# 2712    {'1': 17, '10': 9, '100': 1, '10th': 3, '11': ...
# 2713    {'1': 30, '10': 6, '100': 2, '1000': 1, '10000...
# 2714    {'1': 5, '10': 12, '100': 17, '1000': 4, '104'...
# 2716    {'0': 16, '012d': 1, '1': 21, '10': 18, '100':...
# dtype: object
# Processing 2341-2351 out of 2355...
# Elapsed time: 59.284337 seconds.
# Last 10:
# 2717    {'1': 16, '10': 15, '100': 5, '1000': 17, '100...
# 2718    {'1': 13, '10': 1, '100': 5, '10000': 3, '11':...
# 2719    {'0': 4, '01': 1, '02': 1, '03': 2, '04': 1, '...
# 2720    {'1': 7, '10': 6, '100': 7, '1000': 6, '10000'...
# 2722    {'06th': 1, '1': 4, '100': 7, '1000': 4, '1000...
# 2723    {'1': 11, '10': 8, '100': 4, '1000': 6, '101':...
# 2724    {'1': 11, '10': 19, '100': 1, '101': 5, '102':...
# 2725    {'0': 1, '1': 16, '10': 12, '100': 12, '1000':...
# 2726    {'1': 5, '10': 6, '100': 2, '10000': 4, '10000...
# 2727    {'1': 1, '10': 2, '1000': 2, '10101': 1, '104'...
# dtype: object
# Processing 2351-2361 out of 2355...
# Elapsed time: 59.349309 seconds.
# Last 10:
# 2722    {'06th': 1, '1': 4, '100': 7, '1000': 4, '1000...
# 2723    {'1': 11, '10': 8, '100': 4, '1000': 6, '101':...
# 2724    {'1': 11, '10': 19, '100': 1, '101': 5, '102':...
# 2725    {'0': 1, '1': 16, '10': 12, '100': 12, '1000':...
# 2726    {'1': 5, '10': 6, '100': 2, '10000': 4, '10000...
# 2727    {'1': 1, '10': 2, '1000': 2, '10101': 1, '104'...
# 2728    {'1': 27, '10': 14, '100': 4, '1000': 2, '1000...
# 2729    {'1': 4, '100': 2, '10000': 1, '105': 1, '10th...
# 2730    {'0': 18, '1': 2, '10': 4, '100': 3, '1000': 3...
# 2731    {'1': 9, '10': 13, '100': 10, '1000': 6, '1000...
# dtype: object
# Complete.

# %%
bagged_text
# Out:
# 0       {'0': 2, '1': 57, '10': 39, '100': 16, '1000':...
# 1       {'0': 3, '020': 1, '075': 1, '1': 68, '10': 13...
# 2       {'0': 5, '0c': 8, '0i': 2, '0·22': 1, '0·30': ...
# 3       {'1': 2, '10th': 1, '12×18': 1, '15': 2, '150'...
# 4       {'0': 1, '002': 1, '004': 1, '007013': 1, '1':...
#                               ...
# 2727    {'1': 1, '10': 2, '1000': 2, '10101': 1, '104'...
# 2728    {'1': 27, '10': 14, '100': 4, '1000': 2, '1000...
# 2729    {'1': 4, '100': 2, '10000': 1, '105': 1, '10th...
# 2730    {'0': 18, '1': 2, '10': 4, '100': 3, '1000': 3...
# 2731    {'1': 9, '10': 13, '100': 10, '1000': 6, '1000...
# Length: 2355, dtype: object

# %% [markdown]
# Well, the results are still messy, but the process appears to be working.

# %%
# TF count vectorization function
def count_vectorize(tokenized_text):
    word_counts = {word:0 for word in sorted(set(tokenized_text))}
    
    for word in tokenized_text:
        word_counts[word] += 1
        
    return word_counts

# IDF function
def inverse_document_frequency(list_of_token_texts):
    num_texts = len(list_of_token_texts)
    unique_words = set([word for text in list_of_token_texts for word in text])
    
    idf = {word:0 for word in sorted(unique_words)}
    
    for word in unique_words:
        num_texts_with_word = 0
        for text in list_of_token_texts:
            num_texts_with_word += (word in text)
        idf[word] = np.log( num_texts / num_texts_with_word)
    
    return idf

# TF-IDF
def tf_idf(list_of_token_texts):
    unique_words = set([item for sublist in list_of_token_texts for item in sublist])
    
    idf = inverse_document_frequency(list_of_token_texts)
    
    tf_idf_list_of_dicts = []
    for text_tokens in list_of_token_texts:
        text_tf = count_vectorize(text_tokens)
        doc_tf_idf = {word:0 for word in unique_words}
        for word in unique_words:
            if word in text_tokens:
                doc_tf_idf[word] = text_tf[word] * idf[word]
            else:
                doc_tf_idf[word] = 0
        tf_idf_list_of_dicts.append(doc_tf_idf)
        
    return tf_idf_list_of_dicts

# %% [markdown]
# With our functions ready to roll, it's time to finish the preparation process. Let's split our X (which is tokenized_texts) and y (which are the Bookshelf labels) into training and test sets.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# And now we set up our analysis pipeline.

# %%
def main(token_iterable, labels):
    tf_idf_all_docs = tf_idf(token_iterable)
    return tf_idf_all_docs

tf_idf_all_docs = main(X_train, y_train)
